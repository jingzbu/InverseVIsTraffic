# %%
# %run ../Python_files/util.py
# Out:
# No dicts found; please check load_dicts...

# %%
# number of links
m = 258

# %%
ini_node_dict, ter_node_dict, node_neighbors_dict, origi_dict, desti_dict = \
zload('../temp_files/origin_terminal_dict_journal.pkz')

# %%
node_neighbors_dict
# Out:
# defaultdict(list,
#             {'1': [3, 7, 9],
#              '10': [5, 11, 18, 20],
#              '11': [5, 8, 10, 19],
#              '12': [9],
#              '13': [6, 7, 9, 14, 15],
#              '14': [13, 17, 22],
#              '15': [13],
#              '16': [8, 17, 19, 22],
#              '17': [6, 14, 16, 22],
#              '18': [10, 19, 21],
#              '19': [11, 16, 18, 22],
#              '2': [3],
#              '20': [10, 21, 30, 58],
#              '21': [18, 20, 22, 23],
#              '22': [14, 16, 17, 19, 21, 23, 25, 28, 29, 40],
#              '23': [21, 22, 24, 31],
#              '24': [23, 25, 26, 33],
#              '25': [22, 24, 26],
#              '26': [24, 25, 27, 28],
#              '27': [26, 28, 33, 35],
#              '28': [22, 26, 27, 37],
#              '29': [22, 41, 49],
#              '3': [1, 2, 6, 7],
#              '30': [20, 31, 60],
#              '31': [23, 30, 32, 60],
#              '32': [31, 33, 34, 60],
#              '33': [24, 27, 32, 34],
#              '34': [32, 33, 35, 60],
#              '35': [27, 34, 36, 71],
#              '36': [35, 43, 44, 71],
#              '37': [28, 38, 42],
#              '38': [37, 39, 42],
#              '39': [38, 40, 48],
#              '4': [6, 8],
#              '40': [22, 39, 41, 48],
#              '41': [29, 40, 49],
#              '42': [37, 38, 43, 45],
#              '43': [36, 42, 44, 45],
#              '44': [36, 43, 46, 54],
#              '45': [42, 43, 46, 47],
#              '46': [44, 45, 47, 54],
#              '47': [45, 46, 48, 74],
#              '48': [39, 40, 47, 49, 51, 52, 53, 54, 74],
#              '49': [29, 41, 48, 50, 73],
#              '5': [10, 11],
#              '50': [49, 51, 73],
#              '51': [48, 50, 52],
#              '52': [48, 51, 53],
#              '53': [48, 52, 54],
#              '54': [44, 46, 48, 53],
#              '55': [57],
#              '56': [57],
#              '57': [55, 56, 58, 59],
#              '58': [20, 57, 59],
#              '59': [57, 58, 60, 72],
#              '6': [3, 4, 8, 13, 17],
#              '60': [30, 31, 32, 34, 59, 61, 63, 65, 67, 69, 71, 72],
#              '61': [60],
#              '62': [63],
#              '63': [60, 62, 65],
#              '64': [65],
#              '65': [60, 63, 64, 66],
#              '66': [65],
#              '67': [60, 68, 69],
#              '68': [67],
#              '69': [60, 67, 70, 71],
#              '7': [1, 3, 9, 13],
#              '70': [69],
#              '71': [35, 36, 60, 69],
#              '72': [59, 60],
#              '73': [49, 50],
#              '74': [47, 48],
#              '8': [4, 6, 11, 16],
#              '9': [1, 7, 12, 13]})

# %%
for i in node_neighbors_dict['1']:
    for j in node_neighbors_dict['6']:
        if j in node_neighbors_dict[str(i)]:
            print('1->%s->%s->6'%(i,j))
# Out:
# 1->7->3->6
# 1->7->13->6
# 1->9->13->6

# %%
OD_pair_label_dict_ = zload('../temp_files/OD_pair_label_dict__journal.pkz')
OD_pair_label_dict = zload('../temp_files/OD_pair_label_dict_journal.pkz')

# %%
od_pairs = OD_pair_label_dict_.values()

# %%
len(od_pairs)
# Out:
# 5402

# %%
with open('../temp_files/link_length_dict_journal.json', 'r') as json_file:
    link_length_dict = json.load(json_file)

# %%
link_length_dict
# Out:
# {u'0': 16.106816776132206,
#  u'1': 16.0571310848523,
#  u'10': 11.592971084625853,
#  u'100': 1.5696733948772232,
#  u'101': 1.5728465434794565,
#  u'102': 1.7921931243248002,
#  u'103': 1.545397171832275,
#  u'104': 2.382524537502082,
#  u'105': 2.3073150179731683,
#  u'106': 10.419637474239062,
#  u'107': 10.605611517111255,
#  u'108': 17.00667789124771,
#  u'109': 17.005567531531476,
#  u'11': 11.736038693223891,
#  u'110': 7.738237271080147,
#  u'111': 8.018881297358824,
#  u'112': 4.915496789928508,
#  u'113': 5.233681913815005,
#  u'114': 32.389346299632926,
#  u'115': 32.29912178266756,
#  u'116': 2.3217571453967474,
#  u'117': 2.266330384997213,
#  u'118': 7.996645946908461,
#  u'119': 8.006116830442075,
#  u'12': 3.509126600568283,
#  u'120': 4.247236648822414,
#  u'121': 4.232367939709893,
#  u'122': 6.729821226606654,
#  u'123': 6.734278378625871,
#  u'124': 4.981080208735738,
#  u'125': 4.952494030424852,
#  u'126': 1.8063791824496431,
#  u'127': 1.8885017904624508,
#  u'128': 5.513571423215228,
#  u'129': 5.443441332441691,
#  u'13': 3.509126600568283,
#  u'130': 4.95107287593183,
#  u'131': 4.890894307370019,
#  u'132': 9.33850861489713,
#  u'133': 9.213129333692125,
#  u'134': 10.077606455023595,
#  u'135': 14.807023608899685,
#  u'136': 6.58094478550051,
#  u'137': 6.854678791689908,
#  u'138': 3.665727763844527,
#  u'139': 3.666940974100353,
#  u'14': 6.269460973290362,
#  u'140': 8.551888911305294,
#  u'141': 8.474891543605422,
#  u'142': 8.148498440261513,
#  u'143': 7.709684470772214,
#  u'144': 7.348533101500685,
#  u'145': 7.33755088899544,
#  u'146': 3.1887183387192874,
#  u'147': 3.5295090326826957,
#  u'148': 7.634185601102102,
#  u'149': 7.710593954126597,
#  u'15': 6.412615007790549,
#  u'150': 3.1676684588046005,
#  u'151': 3.1037931271030206,
#  u'152': 6.153280159332355,
#  u'153': 6.951620719172372,
#  u'154': 1.2922793827309171,
#  u'155': 1.307138698549448,
#  u'156': 17.539958035464966,
#  u'157': 18.147037245956806,
#  u'158': 3.4865477048665956,
#  u'159': 3.2248665465213957,
#  u'16': 10.449604297996718,
#  u'160': 21.899349962468754,
#  u'161': 21.94744534860476,
#  u'162': 32.81990122339988,
#  u'163': 32.9246898029873,
#  u'164': 3.965880109114513,
#  u'165': 3.9711681253404634,
#  u'166': 6.06271854085921,
#  u'167': 6.25613103617367,
#  u'168': 3.491124610265934,
#  u'169': 3.5644758648597032,
#  u'17': 10.554493738448745,
#  u'170': 4.080103419181262,
#  u'171': 4.1413565089324536,
#  u'172': 3.2435085141145907,
#  u'173': 3.245762352246047,
#  u'174': 10.076887518256967,
#  u'175': 10.014429655353144,
#  u'176': 1.8894851551628444,
#  u'177': 1.9608573712479724,
#  u'178': 3.422107295358311,
#  u'179': 3.687148275091586,
#  u'18': 11.677804833484773,
#  u'180': 2.8600268376953015,
#  u'181': 2.8705604149549857,
#  u'182': 11.279297626695469,
#  u'183': 11.207469048728864,
#  u'184': 10.530470370465926,
#  u'185': 10.299169231892144,
#  u'186': 5.726137263076658,
#  u'187': 5.749451819524412,
#  u'188': 14.622121867102532,
#  u'189': 14.619950366402357,
#  u'19': 11.588227883418346,
#  u'190': 29.323020962557305,
#  u'191': 29.502821751201953,
#  u'192': 16.882699546358918,
#  u'193': 17.00857691433406,
#  u'194': 14.062638535550418,
#  u'195': 14.187330222588075,
#  u'196': 15.006139868358241,
#  u'197': 15.0838831742159,
#  u'198': 8.050590955395883,
#  u'199': 7.02598525107882,
#  u'2': 16.05873959325414,
#  u'20': 2.9598793253562294,
#  u'200': 13.039071832031006,
#  u'201': 13.189106086995176,
#  u'202': 8.533461086604408,
#  u'203': 8.539431940820199,
#  u'204': 15.449374097479238,
#  u'205': 16.020354087312494,
#  u'206': 8.473071773791418,
#  u'207': 8.473071773791418,
#  u'208': 14.949056707342207,
#  u'209': 14.93107074934216,
#  u'21': 2.6474081350775083,
#  u'210': 8.710908321724583,
#  u'211': 8.79125236081523,
#  u'212': 13.929966298450532,
#  u'213': 13.938592714275844,
#  u'214': 9.342478356225582,
#  u'215': 9.139465171566961,
#  u'216': 10.255872289680426,
#  u'217': 10.442468675148076,
#  u'218': 10.35896488381876,
#  u'219': 10.189567567019285,
#  u'22': 11.650116069123403,
#  u'220': 11.360159540684432,
#  u'221': 11.354891312700241,
#  u'222': 9.144294117537308,
#  u'223': 9.303474724445564,
#  u'224': 8.141116494849232,
#  u'225': 8.495865089008287,
#  u'226': 3.1132818057899,
#  u'227': 3.106375119580356,
#  u'228': 24.836978550057342,
#  u'229': 24.834966122473165,
#  u'23': 11.52261277140617,
#  u'230': 9.667444388047759,
#  u'231': 9.769816963660839,
#  u'232': 11.630475901297695,
#  u'233': 11.588988156239735,
#  u'234': 8.630658049113515,
#  u'235': 8.971461184940694,
#  u'236': 12.15780756485551,
#  u'237': 11.78968164578674,
#  u'238': 12.851940714738113,
#  u'239': 12.851940714738113,
#  u'24': 12.288557352370397,
#  u'240': 4.619146629694611,
#  u'241': 4.619146629694612,
#  u'242': 3.711356711363819,
#  u'243': 4.075201302752909,
#  u'244': 1.377317140397602,
#  u'245': 1.5122405042158162,
#  u'246': 3.2540474653927722,
#  u'247': 3.0778455954044426,
#  u'248': 6.352585110246855,
#  u'249': 6.913755830997218,
#  u'25': 12.326099188881543,
#  u'250': 2.647231401275409,
#  u'251': 2.867756518243679,
#  u'252': 11.765241519380718,
#  u'253': 11.76524151938072,
#  u'254': 5.334022101781262,
#  u'255': 5.893052485601581,
#  u'256': 8.99212380041901,
#  u'257': 8.985698553901845,
#  u'26': 4.074787945611246,
#  u'27': 4.074787945611246,
#  u'28': 6.485867780901202,
#  u'29': 6.868068220581124,
#  u'3': 15.865262888535515,
#  u'30': 5.919129198637823,
#  u'31': 5.949185706987245,
#  u'32': 12.635123628334222,
#  u'33': 12.545210344262669,
#  u'34': 5.229189442670594,
#  u'35': 5.395143248813242,
#  u'36': 2.9878294267241485,
#  u'37': 3.0363192873675278,
#  u'38': 1.8394670197689555,
#  u'39': 1.8042637065726894,
#  u'4': 17.45540071364456,
#  u'40': 10.528473866268591,
#  u'41': 10.484210894531167,
#  u'42': 11.754734628849423,
#  u'43': 11.782102622350303,
#  u'44': 12.511216004386194,
#  u'45': 12.212523357818304,
#  u'46': 8.285083413897453,
#  u'47': 7.5254129722949505,
#  u'48': 8.419361594011644,
#  u'49': 8.467006915248277,
#  u'5': 17.450098686512977,
#  u'50': 6.761203486814544,
#  u'51': 6.898849467081714,
#  u'52': 8.568055867803777,
#  u'53': 8.369572202736173,
#  u'54': 1.3497965538563128,
#  u'55': 1.3578419819538736,
#  u'56': 4.5827194135406,
#  u'57': 4.45251754235305,
#  u'58': 3.367287655687359,
#  u'59': 3.4291045722582214,
#  u'6': 3.874724530269769,
#  u'60': 5.321009354750141,
#  u'61': 5.315024551038685,
#  u'62': 2.349795721082121,
#  u'63': 3.54877076575886,
#  u'64': 5.45357321347981,
#  u'65': 5.457315958100921,
#  u'66': 5.818844268378241,
#  u'67': 5.791541992302648,
#  u'68': 16.46181693853618,
#  u'69': 15.442909121257038,
#  u'7': 3.9751211916735767,
#  u'70': 13.283224601182997,
#  u'71': 13.295709830800595,
#  u'72': 12.263937698311064,
#  u'73': 12.556028037175837,
#  u'74': 6.798868686026321,
#  u'75': 6.721773229487106,
#  u'76': 4.525774863609242,
#  u'77': 4.543420712189323,
#  u'78': 4.583763012769106,
#  u'79': 4.508857627340593,
#  u'8': 7.587822021450257,
#  u'80': 8.906272983117788,
#  u'81': 8.306623730212383,
#  u'82': 8.608118984864001,
#  u'83': 8.599900076007556,
#  u'84': 5.869561058374282,
#  u'85': 5.650088591209094,
#  u'86': 12.222220073668307,
#  u'87': 11.916417537932704,
#  u'88': 2.436259813782731,
#  u'89': 2.4039018496686513,
#  u'9': 7.4474498019926925,
#  u'90': 16.652993350514965,
#  u'91': 16.79991994921688,
#  u'92': 1.687603841599184,
#  u'93': 1.6784612543785689,
#  u'94': 1.6458649031812804,
#  u'95': 1.061605480190827,
#  u'96': 11.986122156591701,
#  u'97': 11.945303335792971,
#  u'98': 1.9283197482446497,
#  u'99': 1.812974401600048}

# %%
link_label_dict = zload('../temp_files/link_label_dict_journal.pkz')
link_label_dict_ = zload('../temp_files/link_label_dict_journal_.pkz')

# %%
# compute length of a route
def routeLength(route):
    link_list = []
    node_list = []
    for i in route.split('->'):
        node_list.append(int(i))
    for i in range(len(node_list))[:-1]:
        link_list.append('%d->%d' %(node_list[i], node_list[i+1]))
    length_of_route = sum([link_length_dict[str(link_label_dict_[link])] for link in link_list])
    return length_of_route

# %%
with open('../temp_files/path_link_incidence_journal.txt', 'w') as the_file:
    for od in od_pairs:
        origi = od[0]
        desti = od[1]
        the_file.write('O-D pair (%s, %s):\n'%(origi, desti))
        route_list = []
        if desti in node_neighbors_dict[str(origi)]:
            route_list.append('%s->%s\n'%(origi,desti))
        for i in node_neighbors_dict[str(origi)]:
            if i in node_neighbors_dict[str(desti)]:
                flag = [origi, i, desti]
                if len(set(flag)) == len(flag):
                    route_list.append('%s->%s->%s\n'%(origi,i,desti))
            for j in node_neighbors_dict[str(i)]:
                if j in node_neighbors_dict[str(desti)]:
                    flag = [origi, i, j, desti]
                    if len(set(flag)) == len(flag):
                        route_list.append('%s->%s->%s->%s\n'%(origi,i,j,desti))
                for k in node_neighbors_dict[str(j)]:
                    if k in node_neighbors_dict[str(desti)]:
                        flag = [origi, i, j, k, desti]
                        if len(set(flag)) == len(flag):
                            route_list.append('%s->%s->%s->%s->%s\n'%(origi,i,j,k,desti))
                    for l in node_neighbors_dict[str(k)]:
                        if l in node_neighbors_dict[str(desti)]:
                            flag = [origi, i, j, k, l, desti]
                            if len(set(flag)) == len(flag):
                                route_list.append('%s->%s->%s->%s->%s->%s\n'%(origi,i,j,k,l,desti))    
                        for m in node_neighbors_dict[str(l)]:
                            if m in node_neighbors_dict[str(desti)]:
                                flag = [origi, i, j, k, l, m, desti]
                                if len(set(flag)) == len(flag):
                                    route_list.append('%s->%s->%s->%s->%s->%s->%s\n'%(origi,i,j,k,l,m,desti))  
                            for n in node_neighbors_dict[str(m)]:
                                if n in node_neighbors_dict[str(desti)]:
                                    flag = [origi, i, j, k, l, m, n, desti]
                                    if len(set(flag)) == len(flag):
                                        route_list.append('%s->%s->%s->%s->%s->%s->%s->%s\n'%(origi,i,j,k,l,m,n,desti))
                                for o in node_neighbors_dict[str(n)]:
                                    if o in node_neighbors_dict[str(desti)]:
                                        flag = [origi, i, j, k, l, m, n, o, desti]
                                        if len(set(flag)) == len(flag):
                                            route_list.append('%s->%s->%s->%s->%s->%s->%s->%s->%s\n'%(origi,i,j,k,l,m,n,o,desti))
                                    for p in node_neighbors_dict[str(o)]:
                                        if p in node_neighbors_dict[str(desti)]:
                                            flag = [origi, i, j, k, l, m, n, o, p, desti]
                                            if len(set(flag)) == len(flag):
                                                route_list.append('%s->%s->%s->%s->%s->%s->%s->%s->%s->%s\n'%(origi,i,j,k,l,m,n,o,p,desti))
                                                for q in node_neighbors_dict[str(p)]:
                                                    if q in node_neighbors_dict[str(desti)]:
                                                        flag = [origi, i, j, k, l, m, n, o, p, q, desti]
                                                        if len(set(flag)) == len(flag):
                                                            route_list.append('%s->%s->%s->%s->%s->%s->%s->%s->%s->%s->%s\n'%(origi,i,j,k,l,m,n,o,p,q,desti))
       
        route_length_list = np.array([routeLength(route) for route in route_list])
    
        refined_route_list = []
        
        if len(route_list) <= 10:
            refined_route_list = route_list
        else:
            refined_idx_list = [np.argsort(route_length_list)[i] for i in range(10)]
            refined_route_list = [route_list[idx] for idx in refined_idx_list]
                
        for route in refined_route_list:
            the_file.write(route)
        the_file.write('\n')

# %%
with open('../temp_files/path_link_incidence_journal.txt', 'r') as the_file:
    # path counts
    i = 0  
    for row in the_file:
        if '->' in row:
            i = i + 1

# %%
i
# Out:
# 53165

# %%
link_label_dict_ = zload('../temp_files/link_label_dict_journal_.pkz')

# %%
od_nodes_dict = zload('../temp_files/od_nodes_dict_journal.pkz')

# %%
od_nodes_dict
# Out:
# {0: {1},
#  1: {2, 4, 5},
#  2: {3},
#  3: {6, 8},
#  4: {7, 9},
#  5: {10, 11},
#  6: {12, 15},
#  7: {13, 14},
#  8: {16, 17, 18, 19},
#  9: {20},
#  10: {21},
#  11: {22},
#  12: {23, 24, 25, 26, 27, 28},
#  13: {29},
#  14: {30, 31, 32, 33, 34},
#  15: {35, 71},
#  16: {36},
#  17: {37, 38, 39, 40, 41},
#  18: {42},
#  19: {43, 44, 45, 46, 47},
#  20: {48, 74},
#  21: {49, 73},
#  22: {50, 51},
#  23: {52},
#  24: {53},
#  25: {54, 68, 70},
#  26: {55, 56},
#  27: {57},
#  28: {58},
#  29: {59, 60, 72},
#  30: {61},
#  31: {62, 63, 64, 65, 66},
#  32: {67},
#  33: {69}}

# %%
node_to_OD_dict = {}

for key in od_nodes_dict.keys():
    for value in od_nodes_dict[key]:
        node_to_OD_dict[value] = key

# %%
node_to_OD_dict
# Out:
# {1: 0,
#  2: 1,
#  3: 2,
#  4: 1,
#  5: 1,
#  6: 3,
#  7: 4,
#  8: 3,
#  9: 4,
#  10: 5,
#  11: 5,
#  12: 6,
#  13: 7,
#  14: 7,
#  15: 6,
#  16: 8,
#  17: 8,
#  18: 8,
#  19: 8,
#  20: 9,
#  21: 10,
#  22: 11,
#  23: 12,
#  24: 12,
#  25: 12,
#  26: 12,
#  27: 12,
#  28: 12,
#  29: 13,
#  30: 14,
#  31: 14,
#  32: 14,
#  33: 14,
#  34: 14,
#  35: 15,
#  36: 16,
#  37: 17,
#  38: 17,
#  39: 17,
#  40: 17,
#  41: 17,
#  42: 18,
#  43: 19,
#  44: 19,
#  45: 19,
#  46: 19,
#  47: 19,
#  48: 20,
#  49: 21,
#  50: 22,
#  51: 22,
#  52: 23,
#  53: 24,
#  54: 25,
#  55: 26,
#  56: 26,
#  57: 27,
#  58: 28,
#  59: 29,
#  60: 29,
#  61: 30,
#  62: 31,
#  63: 31,
#  64: 31,
#  65: 31,
#  66: 31,
#  67: 32,
#  68: 25,
#  69: 33,
#  70: 25,
#  71: 15,
#  72: 29,
#  73: 21,
#  74: 20}

# %%
# build a dictionary containing route information that is easy to tackle

route_dict = {}
with open('../temp_files/path_link_incidence_journal.txt', 'r') as the_file:
    idx = 0
    for row in the_file:
        if '->' in row:
            link_list = []
            link_idx_list = []
            node_list = []
            for i in row.split('->'):
                node_list.append(int(i))
            for i in range(len(node_list))[:-1]:
                link_list.append('%d->%d' %(node_list[i], node_list[i+1]))
                link_idx_list.append(link_label_dict_[str(node_list[i]) + '->' + str(node_list[i+1])])
            length_of_route = sum([link_length_dict[str(link_label_dict_[link])] \
                                  for link in link_list])
            route_dict[idx] = {'node_list': node_list, 'origi': node_to_OD_dict[node_list[0]], \
                               'desti': node_to_OD_dict[node_list[-1]], 'link_idx_list': link_idx_list, \
                               'length_of_route': length_of_route}
            idx += 1
            
with open('../temp_files/route_dict_journal.json', 'w') as json_file:
    json.dump(route_dict, json_file)

# %%
route_dict
# Out:
# {0: {'desti': 17,
#   'length_of_route': 17.697817325312034,
#   'link_idx_list': [89, 79, 84, 112],
#   'node_list': [24, 23, 22, 29, 41],
#   'origi': 12},
#  1: {'desti': 17,
#   'length_of_route': 20.779285420114356,
#   'link_idx_list': [92, 81, 84, 112],
#   'node_list': [24, 25, 22, 29, 41],
#   'origi': 12},
#  2: {'desti': 17,
#   'length_of_route': 22.311509183707628,
#   'link_idx_list': [94, 102, 110, 146, 150, 154, 158],
#   'node_list': [24, 26, 28, 37, 38, 39, 40, 41],
#   'origi': 12},
#  3: {'desti': 17,
#   'length_of_route': 22.550520883296503,
#   'link_idx_list': [94, 99, 81, 84, 112],
#   'node_list': [24, 26, 25, 22, 29, 41],
#   'origi': 12},
#  4: {'desti': 17,
#   'length_of_route': 22.621527255544144,
#   'link_idx_list': [89, 79, 86, 158],
#   'node_list': [24, 23, 22, 40, 41],
#   'origi': 12},
#  5: {'desti': 17,
#   'length_of_route': 22.823015951816426,
#   'link_idx_list': [94, 102, 83, 84, 112],
#   'node_list': [24, 26, 28, 22, 29, 41],
#   'origi': 12},
#  6: {'desti': 17,
#   'length_of_route': 24.281567870370182,
#   'link_idx_list': [92, 98, 102, 110, 146, 150, 154, 158],
#   'node_list': [24, 25, 26, 28, 37, 38, 39, 40, 41],
#   'origi': 12},
#  7: {'desti': 17,
#   'length_of_route': 24.47151399176213,
#   'link_idx_list': [94, 100, 104, 110, 146, 150, 154, 158],
#   'node_list': [24, 26, 27, 28, 37, 38, 39, 40, 41],
#   'origi': 12},
#  8: {'desti': 17,
#   'length_of_route': 24.531249096187086,
#   'link_idx_list': [89, 77, 74, 84, 112],
#   'node_list': [24, 23, 21, 22, 29, 41],
#   'origi': 12},
#  9: {'desti': 17,
#   'length_of_route': 24.79307463847898,
#   'link_idx_list': [92, 98, 102, 83, 84, 112],
#   'node_list': [24, 25, 26, 28, 22, 29, 41],
#   'origi': 12},
#  10: {'desti': 19,
#   'length_of_route': 24.621620715887495,
#   'link_idx_list': [102, 110, 148, 164, 168],
#   'node_list': [26, 28, 37, 42, 43, 44],
#   'origi': 12},
#  11: {'desti': 19,
#   'length_of_route': 26.329433612837036,
#   'link_idx_list': [102, 110, 146, 152, 164, 168],
#   'node_list': [26, 28, 37, 38, 42, 43, 44],
#   'origi': 12},
#  12: {'desti': 19,
#   'length_of_route': 26.781625523942,
#   'link_idx_list': [100, 104, 110, 148, 164, 168],
#   'node_list': [26, 27, 28, 37, 42, 43, 44],
#   'origi': 12},
#  13: {'desti': 19,
#   'length_of_route': 28.362582044775152,
#   'link_idx_list': [102, 110, 148, 166, 176, 173],
#   'node_list': [26, 28, 37, 42, 45, 46, 44],
#   'origi': 12},
#  14: {'desti': 19,
#   'length_of_route': 28.48943842089154,
#   'link_idx_list': [100, 104, 110, 146, 152, 164, 168],
#   'node_list': [26, 27, 28, 37, 38, 42, 43, 44],
#   'origi': 12},
#  15: {'desti': 19,
#   'length_of_route': 30.070394941724693,
#   'link_idx_list': [102, 110, 146, 152, 166, 176, 173],
#   'node_list': [26, 28, 37, 38, 42, 45, 46, 44],
#   'origi': 12},
#  16: {'desti': 19,
#   'length_of_route': 30.345847032211715,
#   'link_idx_list': [102, 110, 148, 164, 170, 176, 173],
#   'node_list': [26, 28, 37, 42, 43, 45, 46, 44],
#   'origi': 12},
#  17: {'desti': 19,
#   'length_of_route': 30.522586852829654,
#   'link_idx_list': [100, 104, 110, 148, 166, 176, 173],
#   'node_list': [26, 27, 28, 37, 42, 45, 46, 44],
#   'origi': 12},
#  18: {'desti': 19,
#   'length_of_route': 30.85981565656465,
#   'link_idx_list': [102, 110, 148, 166, 171, 168],
#   'node_list': [26, 28, 37, 42, 45, 43, 44],
#   'origi': 12},
#  19: {'desti': 19,
#   'length_of_route': 32.053659929161256,
#   'link_idx_list': [102, 110, 146, 152, 164, 170, 176, 173],
#   'node_list': [26, 28, 37, 38, 42, 43, 45, 46, 44],
#   'origi': 12},
#  20: {'desti': 5,
#   'length_of_route': 23.38945072212437,
#   'link_idx_list': [36, 23, 20, 30],
#   'node_list': [9, 13, 6, 8, 11],
#   'origi': 4},
#  21: {'desti': 5,
#   'length_of_route': 30.208158970626783,
#   'link_idx_list': [36, 23, 13, 14, 30],
#   'node_list': [9, 13, 6, 4, 8, 11],
#   'origi': 4},
#  22: {'desti': 5,
#   'length_of_route': 30.96227702191267,
#   'link_idx_list': [27, 28, 23, 20, 30],
#   'node_list': [9, 7, 13, 6, 8, 11],
#   'origi': 4},
#  23: {'desti': 5,
#   'length_of_route': 32.27765718427945,
#   'link_idx_list': [27, 11, 8, 20, 30],
#   'node_list': [9, 7, 3, 6, 8, 11],
#   'origi': 4},
#  24: {'desti': 5,
#   'length_of_route': 36.18720108074893,
#   'link_idx_list': [36, 46, 50, 55, 56, 45],
#   'node_list': [9, 13, 14, 17, 16, 19, 11],
#   'origi': 4},
#  25: {'desti': 5,
#   'length_of_route': 37.78098527041509,
#   'link_idx_list': [27, 28, 23, 13, 14, 30],
#   'node_list': [9, 7, 13, 6, 4, 8, 11],
#   'origi': 4},
#  26: {'desti': 5,
#   'length_of_route': 37.84503405854633,
#   'link_idx_list': [36, 46, 52, 67, 45],
#   'node_list': [9, 13, 14, 22, 19, 11],
#   'origi': 4},
#  27: {'desti': 5,
#   'length_of_route': 37.85629785229052,
#   'link_idx_list': [36, 46, 50, 55, 33, 30],
#   'node_list': [9, 13, 14, 17, 16, 8, 11],
#   'origi': 4},
#  28: {'desti': 5,
#   'length_of_route': 38.058766885973476,
#   'link_idx_list': [36, 29, 11, 8, 20, 30],
#   'node_list': [9, 13, 7, 3, 6, 8, 11],
#   'origi': 4},
#  29: {'desti': 5,
#   'length_of_route': 39.096365432781866,
#   'link_idx_list': [27, 11, 8, 13, 14, 30],
#   'node_list': [9, 7, 3, 6, 4, 8, 11],
#   'origi': 4},
#  30: {'desti': 31,
#   'length_of_route': 36.93566363665298,
#   'link_idx_list': [105, 106, 125, 128, 230, 243],
#   'node_list': [28, 27, 33, 32, 60, 63, 62],
#   'origi': 12},
#  31: {'desti': 31,
#   'length_of_route': 37.74341918538931,
#   'link_idx_list': [103, 100, 106, 125, 128, 230, 243],
#   'node_list': [28, 26, 27, 33, 32, 60, 63, 62],
#   'origi': 12},
#  32: {'desti': 31,
#   'length_of_route': 38.80183595305555,
#   'link_idx_list': [103, 95, 96, 125, 128, 230, 243],
#   'node_list': [28, 26, 24, 33, 32, 60, 63, 62],
#   'origi': 12},
#  33: {'desti': 31,
#   'length_of_route': 38.82274427262241,
#   'link_idx_list': [105, 106, 130, 127, 128, 230, 243],
#   'node_list': [28, 27, 33, 34, 32, 60, 63, 62],
#   'origi': 12},
#  34: {'desti': 31,
#   'length_of_route': 39.63049982135874,
#   'link_idx_list': [103, 100, 106, 130, 127, 128, 230, 243],
#   'node_list': [28, 26, 27, 33, 34, 32, 60, 63, 62],
#   'origi': 12},
#  35: {'desti': 31,
#   'length_of_route': 40.41093565411873,
#   'link_idx_list': [105, 106, 125, 128, 232, 245, 243],
#   'node_list': [28, 27, 33, 32, 60, 65, 63, 62],
#   'origi': 12},
#  36: {'desti': 31,
#   'length_of_route': 40.68891658902498,
#   'link_idx_list': [103, 95, 96, 130, 127, 128, 230, 243],
#   'node_list': [28, 26, 24, 33, 34, 32, 60, 63, 62],
#   'origi': 12},
#  37: {'desti': 31,
#   'length_of_route': 41.1366003426759,
#   'link_idx_list': [105, 101, 95, 96, 125, 128, 230, 243],
#   'node_list': [28, 27, 26, 24, 33, 32, 60, 63, 62],
#   'origi': 12},
#  38: {'desti': 31,
#   'length_of_route': 41.21869120285506,
#   'link_idx_list': [103, 100, 106, 125, 128, 232, 245, 243],
#   'node_list': [28, 26, 27, 33, 32, 60, 65, 63, 62],
#   'origi': 12},
#  39: {'desti': 31,
#   'length_of_route': 41.231666128843344,
#   'link_idx_list': [103, 99, 93, 96, 125, 128, 230, 243],
#   'node_list': [28, 26, 25, 24, 33, 32, 60, 63, 62],
#   'origi': 12},
#  40: {'desti': 14,
#   'length_of_route': 28.682347496716602,
#   'link_idx_list': [55, 58, 78, 88, 96, 130],
#   'node_list': [17, 16, 22, 23, 24, 33, 34],
#   'origi': 8},
#  41: {'desti': 14,
#   'length_of_route': 29.27822721382551,
#   'link_idx_list': [60, 78, 88, 96, 130],
#   'node_list': [17, 22, 23, 24, 33, 34],
#   'origi': 8},
#  42: {'desti': 14,
#   'length_of_route': 30.331401112422462,
#   'link_idx_list': [55, 58, 78, 88, 94, 100, 106, 130],
#   'node_list': [17, 16, 22, 23, 24, 26, 27, 33, 34],
#   'origi': 8},
#  43: {'desti': 14,
#   'length_of_route': 30.490147833659268,
#   'link_idx_list': [55, 58, 78, 88, 96, 125, 126],
#   'node_list': [17, 16, 22, 23, 24, 33, 32, 34],
#   'origi': 8},
#  44: {'desti': 14,
#   'length_of_route': 30.92728082953137,
#   'link_idx_list': [60, 78, 88, 94, 100, 106, 130],
#   'node_list': [17, 22, 23, 24, 26, 27, 33, 34],
#   'origi': 8},
#  45: {'desti': 14,
#   'length_of_route': 31.011273990649293,
#   'link_idx_list': [55, 58, 82, 105, 106, 130],
#   'node_list': [17, 16, 22, 28, 27, 33, 34],
#   'origi': 8},
#  46: {'desti': 14,
#   'length_of_route': 31.086027550768176,
#   'link_idx_list': [60, 78, 88, 96, 125, 126],
#   'node_list': [17, 22, 23, 24, 33, 32, 34],
#   'origi': 8},
#  47: {'desti': 14,
#   'length_of_route': 31.6071537077582,
#   'link_idx_list': [60, 82, 105, 106, 130],
#   'node_list': [17, 22, 28, 27, 33, 34],
#   'origi': 8},
#  48: {'desti': 14,
#   'length_of_route': 31.819029539385625,
#   'link_idx_list': [55, 58, 82, 103, 100, 106, 130],
#   'node_list': [17, 16, 22, 28, 26, 27, 33, 34],
#   'origi': 8},
#  49: {'desti': 14,
#   'length_of_route': 32.015501832197366,
#   'link_idx_list': [55, 58, 78, 90, 120, 126],
#   'node_list': [17, 16, 22, 23, 31, 32, 34],
#   'origi': 8},
#  50: {'desti': 19,
#   'length_of_route': 21.13049610562156,
#   'link_idx_list': [102, 110, 148, 164],
#   'node_list': [26, 28, 37, 42, 43],
#   'origi': 12},
#  51: {'desti': 19,
#   'length_of_route': 22.8383090025711,
#   'link_idx_list': [102, 110, 146, 152, 164],
#   'node_list': [26, 28, 37, 38, 42, 43],
#   'origi': 12},
#  52: {'desti': 19,
#   'length_of_route': 23.290500913676066,
#   'link_idx_list': [100, 104, 110, 148, 164],
#   'node_list': [26, 27, 28, 37, 42, 43],
#   'origi': 12},
#  53: {'desti': 19,
#   'length_of_route': 24.998313810625604,
#   'link_idx_list': [100, 104, 110, 146, 152, 164],
#   'node_list': [26, 27, 28, 37, 38, 42, 43],
#   'origi': 12},
#  54: {'desti': 19,
#   'length_of_route': 27.368691046298714,
#   'link_idx_list': [102, 110, 148, 166, 171],
#   'node_list': [26, 28, 37, 42, 45, 43],
#   'origi': 12},
#  55: {'desti': 19,
#   'length_of_route': 29.076503943248255,
#   'link_idx_list': [102, 110, 146, 152, 166, 171],
#   'node_list': [26, 28, 37, 38, 42, 45, 43],
#   'origi': 12},
#  56: {'desti': 19,
#   'length_of_route': 29.528695854353217,
#   'link_idx_list': [100, 104, 110, 148, 166, 171],
#   'node_list': [26, 27, 28, 37, 42, 45, 43],
#   'origi': 12},
#  57: {'desti': 19,
#   'length_of_route': 31.236508751302758,
#   'link_idx_list': [100, 104, 110, 146, 152, 166, 171],
#   'node_list': [26, 27, 28, 37, 38, 42, 45, 43],
#   'origi': 12},
#  58: {'desti': 19,
#   'length_of_route': 31.927057909634854,
#   'link_idx_list': [102, 110, 148, 166, 176, 173, 169],
#   'node_list': [26, 28, 37, 42, 45, 46, 44, 43],
#   'origi': 12},
#  59: {'desti': 19,
#   'length_of_route': 33.634870806584395,
#   'link_idx_list': [102, 110, 146, 152, 166, 176, 173, 169],
#   'node_list': [26, 28, 37, 38, 42, 45, 46, 44, 43],
#   'origi': 12},
#  60: {'desti': 6,
#   'length_of_route': 80.59204474030676,
#   'link_idx_list': [216, 218, 73, 68, 74, 53, 47, 37, 34],
#   'node_list': [56, 57, 58, 20, 21, 22, 14, 13, 9, 12],
#   'origi': 26},
#  61: {'desti': 19,
#   'length_of_route': 25.116819692529106,
#   'link_idx_list': [102, 110, 148, 166, 176],
#   'node_list': [26, 28, 37, 42, 45, 46],
#   'origi': 12},
#  62: {'desti': 19,
#   'length_of_route': 26.824632589478647,
#   'link_idx_list': [102, 110, 146, 152, 166, 176],
#   'node_list': [26, 28, 37, 38, 42, 45, 46],
#   'origi': 12},
#  63: {'desti': 19,
#   'length_of_route': 27.10008467996567,
#   'link_idx_list': [102, 110, 148, 164, 170, 176],
#   'node_list': [26, 28, 37, 42, 43, 45, 46],
#   'origi': 12},
#  64: {'desti': 19,
#   'length_of_route': 27.276824500583608,
#   'link_idx_list': [100, 104, 110, 148, 166, 176],
#   'node_list': [26, 27, 28, 37, 42, 45, 46],
#   'origi': 12},
#  65: {'desti': 19,
#   'length_of_route': 27.865129230002086,
#   'link_idx_list': [102, 110, 148, 164, 168, 172],
#   'node_list': [26, 28, 37, 42, 43, 44, 46],
#   'origi': 12},
#  66: {'desti': 19,
#   'length_of_route': 28.80789757691521,
#   'link_idx_list': [102, 110, 146, 152, 164, 170, 176],
#   'node_list': [26, 28, 37, 38, 42, 43, 45, 46],
#   'origi': 12},
#  67: {'desti': 19,
#   'length_of_route': 28.98463739753315,
#   'link_idx_list': [100, 104, 110, 146, 152, 166, 176],
#   'node_list': [26, 27, 28, 37, 38, 42, 45, 46],
#   'origi': 12},
#  68: {'desti': 19,
#   'length_of_route': 29.260089488020174,
#   'link_idx_list': [100, 104, 110, 148, 164, 170, 176],
#   'node_list': [26, 27, 28, 37, 42, 43, 45, 46],
#   'origi': 12},
#  69: {'desti': 19,
#   'length_of_route': 29.52000224767956,
#   'link_idx_list': [102, 110, 148, 166, 178, 181],
#   'node_list': [26, 28, 37, 42, 45, 47, 46],
#   'origi': 12},
#  70: {'desti': 19,
#   'length_of_route': 29.572942126951627,
#   'link_idx_list': [102, 110, 146, 152, 164, 168, 172],
#   'node_list': [26, 28, 37, 38, 42, 43, 44, 46],
#   'origi': 12},
#  71: {'desti': 5,
#   'length_of_route': 44.952967833025326,
#   'link_idx_list': [216, 218, 73, 43],
#   'node_list': [56, 57, 58, 20, 10],
#   'origi': 26},
#  72: {'desti': 5,
#   'length_of_route': 55.25763721433656,
#   'link_idx_list': [216, 220, 223, 73, 43],
#   'node_list': [56, 57, 59, 58, 20, 10],
#   'origi': 26},
#  73: {'desti': 5,
#   'length_of_route': 62.43238954944234,
#   'link_idx_list': [216, 220, 226, 241, 119, 71, 43],
#   'node_list': [56, 57, 59, 72, 60, 30, 20, 10],
#   'origi': 26},
#  74: {'desti': 5,
#   'length_of_route': 62.84107760880706,
#   'link_idx_list': [216, 220, 224, 119, 71, 43],
#   'node_list': [56, 57, 59, 60, 30, 20, 10],
#   'origi': 26},
#  75: {'desti': 5,
#   'length_of_route': 63.42688148262335,
#   'link_idx_list': [216, 220, 226, 241, 123, 117, 71, 43],
#   'node_list': [56, 57, 59, 72, 60, 31, 30, 20, 10],
#   'origi': 26},
#  76: {'desti': 5,
#   'length_of_route': 63.83556954198807,
#   'link_idx_list': [216, 220, 224, 123, 117, 71, 43],
#   'node_list': [56, 57, 59, 60, 31, 30, 20, 10],
#   'origi': 26},
#  77: {'desti': 5,
#   'length_of_route': 65.57420900184329,
#   'link_idx_list': [216, 218, 73, 68, 65, 41],
#   'node_list': [56, 57, 58, 20, 21, 18, 10],
#   'origi': 26},
#  78: {'desti': 5,
#   'length_of_route': 66.36841237614907,
#   'link_idx_list': [216, 220, 226, 241, 129, 121, 117, 71, 43],
#   'node_list': [56, 57, 59, 72, 60, 32, 31, 30, 20, 10],
#   'origi': 26},
#  79: {'desti': 5,
#   'length_of_route': 66.77710043551379,
#   'link_idx_list': [216, 220, 224, 129, 121, 117, 71, 43],
#   'node_list': [56, 57, 59, 60, 32, 31, 30, 20, 10],
#   'origi': 26},
#  80: {'desti': 5,
#   'length_of_route': 70.57548901011398,
#   'link_idx_list': [216, 218, 222, 226, 241, 119, 71, 43],
#   'node_list': [56, 57, 58, 59, 72, 60, 30, 20, 10],
#   'origi': 26},
#  81: {'desti': 5,
#   'length_of_route': 46.79243485279428,
#   'link_idx_list': [216, 218, 73, 43, 38],
#   'node_list': [56, 57, 58, 20, 10, 11],
#   'origi': 26},
#  82: {'desti': 5,
#   'length_of_route': 57.097104234105515,
#   'link_idx_list': [216, 220, 223, 73, 43, 38],
#   'node_list': [56, 57, 59, 58, 20, 10, 11],
#   'origi': 26},
#  83: {'desti': 5,
#   'length_of_route': 64.2718565692113,
#   'link_idx_list': [216, 220, 226, 241, 119, 71, 43, 38],
#   'node_list': [56, 57, 59, 72, 60, 30, 20, 10, 11],
#   'origi': 26},
#  84: {'desti': 5,
#   'length_of_route': 64.68054462857602,
#   'link_idx_list': [216, 220, 224, 119, 71, 43, 38],
#   'node_list': [56, 57, 59, 60, 30, 20, 10, 11],
#   'origi': 26},
#  85: {'desti': 5,
#   'length_of_route': 65.2663485023923,
#   'link_idx_list': [216, 220, 226, 241, 123, 117, 71, 43, 38],
#   'node_list': [56, 57, 59, 72, 60, 31, 30, 20, 10, 11],
#   'origi': 26},
#  86: {'desti': 5,
#   'length_of_route': 65.67503656175703,
#   'link_idx_list': [216, 220, 224, 123, 117, 71, 43, 38],
#   'node_list': [56, 57, 59, 60, 31, 30, 20, 10, 11],
#   'origi': 26},
#  87: {'desti': 5,
#   'length_of_route': 67.18526640495884,
#   'link_idx_list': [216, 218, 73, 43, 17, 18],
#   'node_list': [56, 57, 58, 20, 10, 5, 11],
#   'origi': 26},
#  88: {'desti': 5,
#   'length_of_route': 67.41367602161225,
#   'link_idx_list': [216, 218, 73, 68, 65, 41, 38],
#   'node_list': [56, 57, 58, 20, 21, 18, 10, 11],
#   'origi': 26},
#  89: {'desti': 5,
#   'length_of_route': 68.61656745528275,
#   'link_idx_list': [216, 220, 224, 129, 121, 117, 71, 43, 38],
#   'node_list': [56, 57, 59, 60, 32, 31, 30, 20, 10, 11],
#   'origi': 26},
#  90: {'desti': 5,
#   'length_of_route': 69.65231718621256,
#   'link_idx_list': [216, 218, 73, 68, 65, 62, 45],
#   'node_list': [56, 57, 58, 20, 21, 18, 19, 11],
#   'origi': 26},
#  91: {'desti': 3,
#   'length_of_route': 52.74162055978152,
#   'link_idx_list': [216, 218, 73, 43, 38, 31],
#   'node_list': [56, 57, 58, 20, 10, 11, 8],
#   'origi': 26},
#  92: {'desti': 3,
#   'length_of_route': 63.04628994109276,
#   'link_idx_list': [216, 220, 223, 73, 43, 38, 31],
#   'node_list': [56, 57, 59, 58, 20, 10, 11, 8],
#   'origi': 26},
#  93: {'desti': 3,
#   'length_of_route': 70.22104227619855,
#   'link_idx_list': [216, 220, 226, 241, 119, 71, 43, 38, 31],
#   'node_list': [56, 57, 59, 72, 60, 30, 20, 10, 11, 8],
#   'origi': 26},
#  94: {'desti': 3,
#   'length_of_route': 70.62973033556327,
#   'link_idx_list': [216, 220, 224, 119, 71, 43, 38, 31],
#   'node_list': [56, 57, 59, 60, 30, 20, 10, 11, 8],
#   'origi': 26},
#  95: {'desti': 3,
#   'length_of_route': 71.62422226874428,
#   'link_idx_list': [216, 220, 224, 123, 117, 71, 43, 38, 31],
#   'node_list': [56, 57, 59, 60, 31, 30, 20, 10, 11, 8],
#   'origi': 26},
#  96: {'desti': 3,
#   'length_of_route': 72.40586575175841,
#   'link_idx_list': [216, 218, 73, 68, 74, 59, 33],
#   'node_list': [56, 57, 58, 20, 21, 22, 16, 8],
#   'origi': 26},
#  97: {'desti': 3,
#   'length_of_route': 73.13445211194609,
#   'link_idx_list': [216, 218, 73, 43, 17, 18, 31],
#   'node_list': [56, 57, 58, 20, 10, 5, 11, 8],
#   'origi': 26},
#  98: {'desti': 3,
#   'length_of_route': 73.3628617285995,
#   'link_idx_list': [216, 218, 73, 68, 65, 41, 38, 31],
#   'node_list': [56, 57, 58, 20, 21, 18, 10, 11, 8],
#   'origi': 26},
#  99: {'desti': 3,
#   'length_of_route': 73.3658311375536,
#   'link_idx_list': [216, 220, 226, 241, 123, 91, 79, 59, 33],
#   'node_list': [56, 57, 59, 72, 60, 31, 23, 22, 16, 8],
#   'origi': 26},
#  100: {'desti': 3,
#   'length_of_route': 73.77451919691832,
#   'link_idx_list': [216, 220, 224, 123, 91, 79, 59, 33],
#   'node_list': [56, 57, 59, 60, 31, 23, 22, 16, 8],
#   'origi': 26},
#  101: {'desti': 4,
#   'length_of_route': 70.07546405134997,
#   'link_idx_list': [216, 218, 73, 43, 38, 31, 21, 22, 37],
#   'node_list': [56, 57, 58, 20, 10, 11, 8, 6, 13, 9],
#   'origi': 26},
#  102: {'desti': 4,
#   'length_of_route': 75.36285529763617,
#   'link_idx_list': [216, 218, 73, 68, 74, 53, 47, 37],
#   'node_list': [56, 57, 58, 20, 21, 22, 14, 13, 9],
#   'origi': 26},
#  103: {'desti': 4,
#   'length_of_route': 76.73150874279608,
#   'link_idx_list': [216, 220, 224, 123, 91, 79, 53, 47, 37],
#   'node_list': [56, 57, 59, 60, 31, 23, 22, 14, 13, 9],
#   'origi': 26},
#  104: {'desti': 4,
#   'length_of_route': 77.5986191025597,
#   'link_idx_list': [216, 218, 73, 68, 76, 79, 53, 47, 37],
#   'node_list': [56, 57, 58, 20, 21, 23, 22, 14, 13, 9],
#   'origi': 26},
#  105: {'desti': 4,
#   'length_of_route': 77.9820009301748,
#   'link_idx_list': [216, 218, 73, 43, 38, 31, 21, 22, 29, 26],
#   'node_list': [56, 57, 58, 20, 10, 11, 8, 6, 13, 7, 9],
#   'origi': 26},
#  106: {'desti': 4,
#   'length_of_route': 79.2071571130204,
#   'link_idx_list': [216, 218, 73, 68, 74, 61, 51, 47, 37],
#   'node_list': [56, 57, 58, 20, 21, 22, 17, 14, 13, 9],
#   'origi': 26},
#  107: {'desti': 4,
#   'length_of_route': 83.26939217646101,
#   'link_idx_list': [216, 218, 73, 68, 74, 53, 47, 29, 26],
#   'node_list': [56, 57, 58, 20, 21, 22, 14, 13, 7, 9],
#   'origi': 26},
#  108: {'desti': 4,
#   'length_of_route': 84.63804562162092,
#   'link_idx_list': [216, 220, 224, 123, 91, 79, 53, 47, 29, 26],
#   'node_list': [56, 57, 59, 60, 31, 23, 22, 14, 13, 7, 9],
#   'origi': 26},
#  109: {'desti': 4,
#   'length_of_route': 85.50515598138453,
#   'link_idx_list': [216, 218, 73, 68, 76, 79, 53, 47, 29, 26],
#   'node_list': [56, 57, 58, 20, 21, 23, 22, 14, 13, 7, 9],
#   'origi': 26},
#  110: {'desti': 4,
#   'length_of_route': 85.66752467894742,
#   'link_idx_list': [216, 220, 223, 73, 68, 74, 53, 47, 37],
#   'node_list': [56, 57, 59, 58, 20, 21, 22, 14, 13, 9],
#   'origi': 26},
#  111: {'desti': 3,
#   'length_of_route': 55.38902869485903,
#   'link_idx_list': [216, 218, 73, 43, 38, 31, 21],
#   'node_list': [56, 57, 58, 20, 10, 11, 8, 6],
#   'origi': 26},
#  112: {'desti': 3,
#   'length_of_route': 62.66336216814035,
#   'link_idx_list': [216, 218, 73, 43, 38, 31, 15, 12],
#   'node_list': [56, 57, 58, 20, 10, 11, 8, 4, 6],
#   'origi': 26},
#  113: {'desti': 3,
#   'length_of_route': 65.69369807617026,
#   'link_idx_list': [216, 220, 223, 73, 43, 38, 31, 21],
#   'node_list': [56, 57, 59, 58, 20, 10, 11, 8, 6],
#   'origi': 26},
#  114: {'desti': 3,
#   'length_of_route': 72.9680315494516,
#   'link_idx_list': [216, 220, 223, 73, 43, 38, 31, 15, 12],
#   'node_list': [56, 57, 59, 58, 20, 10, 11, 8, 4, 6],
#   'origi': 26},
#  115: {'desti': 3,
#   'length_of_route': 73.27713847064078,
#   'link_idx_list': [216, 220, 224, 119, 71, 43, 38, 31, 21],
#   'node_list': [56, 57, 59, 60, 30, 20, 10, 11, 8, 6],
#   'origi': 26},
#  116: {'desti': 3,
#   'length_of_route': 73.5365511502336,
#   'link_idx_list': [216, 218, 73, 68, 74, 59, 54, 25],
#   'node_list': [56, 57, 58, 20, 21, 22, 16, 17, 6],
#   'origi': 26},
#  117: {'desti': 3,
#   'length_of_route': 74.07267457515775,
#   'link_idx_list': [216, 218, 73, 68, 74, 61, 25],
#   'node_list': [56, 57, 58, 20, 21, 22, 17, 6],
#   'origi': 26},
#  118: {'desti': 3,
#   'length_of_route': 74.90520459539351,
#   'link_idx_list': [216, 220, 224, 123, 91, 79, 59, 54, 25],
#   'node_list': [56, 57, 59, 60, 31, 23, 22, 16, 17, 6],
#   'origi': 26},
#  119: {'desti': 3,
#   'length_of_route': 75.03263996095293,
#   'link_idx_list': [216, 220, 226, 241, 123, 91, 79, 61, 25],
#   'node_list': [56, 57, 59, 72, 60, 31, 23, 22, 17, 6],
#   'origi': 26},
#  120: {'desti': 3,
#   'length_of_route': 75.05327388683592,
#   'link_idx_list': [216, 218, 73, 68, 74, 59, 33, 21],
#   'node_list': [56, 57, 58, 20, 21, 22, 16, 8, 6],
#   'origi': 26},
#  121: {'desti': 4,
#   'length_of_route': 73.90721298456356,
#   'link_idx_list': [216, 218, 73, 43, 38, 31, 21, 22, 29],
#   'node_list': [56, 57, 58, 20, 10, 11, 8, 6, 13, 7],
#   'origi': 26},
#  122: {'desti': 4,
#   'length_of_route': 74.15025199696122,
#   'link_idx_list': [216, 218, 73, 43, 38, 31, 21, 22, 37, 27],
#   'node_list': [56, 57, 58, 20, 10, 11, 8, 6, 13, 9, 7],
#   'origi': 26},
#  123: {'desti': 4,
#   'length_of_route': 74.42944958147757,
#   'link_idx_list': [216, 218, 73, 43, 38, 31, 21, 9, 10],
#   'node_list': [56, 57, 58, 20, 10, 11, 8, 6, 3, 7],
#   'origi': 26},
#  124: {'desti': 4,
#   'length_of_route': 79.19460423084976,
#   'link_idx_list': [216, 218, 73, 68, 74, 53, 47, 29],
#   'node_list': [56, 57, 58, 20, 21, 22, 14, 13, 7],
#   'origi': 26},
#  125: {'desti': 4,
#   'length_of_route': 79.43764324324742,
#   'link_idx_list': [216, 218, 73, 68, 74, 53, 47, 37, 27],
#   'node_list': [56, 57, 58, 20, 21, 22, 14, 13, 9, 7],
#   'origi': 26},
#  126: {'desti': 4,
#   'length_of_route': 80.56325767600967,
#   'link_idx_list': [216, 220, 224, 123, 91, 79, 53, 47, 29],
#   'node_list': [56, 57, 59, 60, 31, 23, 22, 14, 13, 7],
#   'origi': 26},
#  127: {'desti': 4,
#   'length_of_route': 80.80629668840733,
#   'link_idx_list': [216, 220, 224, 123, 91, 79, 53, 47, 37, 27],
#   'node_list': [56, 57, 59, 60, 31, 23, 22, 14, 13, 9, 7],
#   'origi': 26},
#  128: {'desti': 4,
#   'length_of_route': 81.43036803577328,
#   'link_idx_list': [216, 218, 73, 68, 76, 79, 53, 47, 29],
#   'node_list': [56, 57, 58, 20, 21, 23, 22, 14, 13, 7],
#   'origi': 26},
#  129: {'desti': 4,
#   'length_of_route': 81.67340704817094,
#   'link_idx_list': [216, 218, 73, 68, 76, 79, 53, 47, 37, 27],
#   'node_list': [56, 57, 58, 20, 21, 23, 22, 14, 13, 9, 7],
#   'origi': 26},
#  130: {'desti': 4,
#   'length_of_route': 83.03890604623399,
#   'link_idx_list': [216, 218, 73, 68, 74, 61, 51, 47, 29],
#   'node_list': [56, 57, 58, 20, 21, 22, 17, 14, 13, 7],
#   'origi': 26},
#  131: {'desti': 30,
#   'length_of_route': 72.64452484837345,
#   'link_idx_list': [36, 46, 52, 78, 90, 122, 228],
#   'node_list': [9, 13, 14, 22, 23, 31, 60, 61],
#   'origi': 4},
#  132: {'desti': 30,
#   'length_of_route': 74.15015769526633,
#   'link_idx_list': [36, 46, 52, 78, 88, 96, 125, 128, 228],
#   'node_list': [9, 13, 14, 22, 23, 24, 33, 32, 60, 61],
#   'origi': 4},
#  133: {'desti': 30,
#   'length_of_route': 75.56280210502545,
#   'link_idx_list': [36, 46, 50, 55, 58, 78, 90, 122, 228],
#   'node_list': [9, 13, 14, 17, 16, 22, 23, 31, 60, 61],
#   'origi': 4},
#  134: {'desti': 30,
#   'length_of_route': 75.67551169380444,
#   'link_idx_list': [36, 46, 52, 78, 90, 120, 128, 228],
#   'node_list': [9, 13, 14, 22, 23, 31, 32, 60, 61],
#   'origi': 4},
#  135: {'desti': 30,
#   'length_of_route': 76.15868182213435,
#   'link_idx_list': [36, 46, 50, 60, 78, 90, 122, 228],
#   'node_list': [9, 13, 14, 17, 22, 23, 31, 60, 61],
#   'origi': 4},
#  136: {'desti': 30,
#   'length_of_route': 76.17767995367247,
#   'link_idx_list': [36, 46, 52, 78, 90, 117, 118, 228],
#   'node_list': [9, 13, 14, 22, 23, 31, 30, 60, 61],
#   'origi': 4},
#  137: {'desti': 30,
#   'length_of_route': 76.47908418919903,
#   'link_idx_list': [36, 46, 52, 82, 105, 106, 125, 128, 228],
#   'node_list': [9, 13, 14, 22, 28, 27, 33, 32, 60, 61],
#   'origi': 4},
#  138: {'desti': 30,
#   'length_of_route': 77.71486910621086,
#   'link_idx_list': [36, 46, 52, 80, 93, 96, 125, 128, 228],
#   'node_list': [9, 13, 14, 22, 25, 24, 33, 32, 60, 61],
#   'origi': 4},
#  139: {'desti': 30,
#   'length_of_route': 78.71277157258167,
#   'link_idx_list': [36, 46, 52, 78, 88, 96, 130, 134, 228],
#   'node_list': [9, 13, 14, 22, 23, 24, 33, 34, 60, 61],
#   'origi': 4},
#  140: {'desti': 30,
#   'length_of_route': 79.18966866756534,
#   'link_idx_list': [36, 46, 50, 60, 78, 90, 120, 128, 228],
#   'node_list': [9, 13, 14, 17, 22, 23, 31, 32, 60, 61],
#   'origi': 4},
#  141: {'desti': 7,
#   'length_of_route': 64.8011230379737,
#   'link_idx_list': [216, 218, 73, 68, 74, 53],
#   'node_list': [56, 57, 58, 20, 21, 22, 14],
#   'origi': 26},
#  142: {'desti': 7,
#   'length_of_route': 65.76108842376888,
#   'link_idx_list': [216, 220, 226, 241, 123, 91, 79, 53],
#   'node_list': [56, 57, 59, 72, 60, 31, 23, 22, 14],
#   'origi': 26},
#  143: {'desti': 7,
#   'length_of_route': 66.1697764831336,
#   'link_idx_list': [216, 220, 224, 123, 91, 79, 53],
#   'node_list': [56, 57, 59, 60, 31, 23, 22, 14],
#   'origi': 26},
#  144: {'desti': 7,
#   'length_of_route': 67.03688684289722,
#   'link_idx_list': [216, 218, 73, 68, 76, 79, 53],
#   'node_list': [56, 57, 58, 20, 21, 23, 22, 14],
#   'origi': 26},
#  145: {'desti': 7,
#   'length_of_route': 67.4093048819299,
#   'link_idx_list': [216, 220, 224, 129, 124, 97, 89, 79, 53],
#   'node_list': [56, 57, 59, 60, 32, 33, 24, 23, 22, 14],
#   'origi': 26},
#  146: {'desti': 7,
#   'length_of_route': 68.10930142843378,
#   'link_idx_list': [216, 218, 73, 68, 74, 59, 54, 51],
#   'node_list': [56, 57, 58, 20, 21, 22, 16, 17, 14],
#   'origi': 26},
#  147: {'desti': 7,
#   'length_of_route': 68.64542485335792,
#   'link_idx_list': [216, 218, 73, 68, 74, 61, 51],
#   'node_list': [56, 57, 58, 20, 21, 22, 17, 14],
#   'origi': 26},
#  148: {'desti': 7,
#   'length_of_route': 68.70261931729459,
#   'link_idx_list': [216, 220, 226, 241, 129, 121, 91, 79, 53],
#   'node_list': [56, 57, 59, 72, 60, 32, 31, 23, 22, 14],
#   'origi': 26},
#  149: {'desti': 7,
#   'length_of_route': 69.11130737665931,
#   'link_idx_list': [216, 220, 224, 129, 121, 91, 79, 53],
#   'node_list': [56, 57, 59, 60, 32, 31, 23, 22, 14],
#   'origi': 26},
#  150: {'desti': 7,
#   'length_of_route': 69.35468402098184,
#   'link_idx_list': [216, 220, 226, 241, 119, 116, 91, 79, 53],
#   'node_list': [56, 57, 59, 72, 60, 30, 31, 23, 22, 14],
#   'origi': 26},
#  151: {'desti': 6,
#   'length_of_route': 75.45850635799408,
#   'link_idx_list': [216, 218, 73, 43, 38, 31, 21, 22, 48],
#   'node_list': [56, 57, 58, 20, 10, 11, 8, 6, 13, 15],
#   'origi': 26},
#  152: {'desti': 6,
#   'length_of_route': 80.74589760428029,
#   'link_idx_list': [216, 218, 73, 68, 74, 53, 47, 48],
#   'node_list': [56, 57, 58, 20, 21, 22, 14, 13, 15],
#   'origi': 26},
#  153: {'desti': 6,
#   'length_of_route': 94.1421522382928,
#   'link_idx_list': [216, 218, 73, 68, 74, 61, 25, 22, 48],
#   'node_list': [56, 57, 58, 20, 21, 22, 17, 6, 13, 15],
#   'origi': 26},
#  154: {'desti': 6,
#   'length_of_route': 84.59019941966451,
#   'link_idx_list': [216, 218, 73, 68, 74, 61, 51, 47, 48],
#   'node_list': [56, 57, 58, 20, 21, 22, 17, 14, 13, 15],
#   'origi': 26},
#  155: {'desti': 6,
#   'length_of_route': 82.98166140920381,
#   'link_idx_list': [216, 218, 73, 68, 76, 79, 53, 47, 48],
#   'node_list': [56, 57, 58, 20, 21, 23, 22, 14, 13, 15],
#   'origi': 26},
#  156: {'desti': 6,
#   'length_of_route': 91.05056698559153,
#   'link_idx_list': [216, 220, 223, 73, 68, 74, 53, 47, 48],
#   'node_list': [56, 57, 59, 58, 20, 21, 22, 14, 13, 15],
#   'origi': 26},
#  157: {'desti': 6,
#   'length_of_route': 82.1145510494402,
#   'link_idx_list': [216, 220, 224, 123, 91, 79, 53, 47, 48],
#   'node_list': [56, 57, 59, 60, 31, 23, 22, 14, 13, 15],
#   'origi': 26},
#  158: {'desti': 5,
#   'length_of_route': 25.19371442869706,
#   'link_idx_list': [36, 23, 20, 30, 39],
#   'node_list': [9, 13, 6, 8, 11, 10],
#   'origi': 4},
#  159: {'desti': 5,
#   'length_of_route': 32.012422677199474,
#   'link_idx_list': [36, 23, 13, 14, 30, 39],
#   'node_list': [9, 13, 6, 4, 8, 11, 10],
#   'origi': 4},
#  160: {'desti': 5,
#   'length_of_route': 32.76654072848536,
#   'link_idx_list': [27, 28, 23, 20, 30, 39],
#   'node_list': [9, 7, 13, 6, 8, 11, 10],
#   'origi': 4},
#  161: {'desti': 5,
#   'length_of_route': 34.08192089085214,
#   'link_idx_list': [27, 11, 8, 20, 30, 39],
#   'node_list': [9, 7, 3, 6, 8, 11, 10],
#   'origi': 4},
#  162: {'desti': 5,
#   'length_of_route': 37.99146478732162,
#   'link_idx_list': [36, 46, 50, 55, 56, 45, 39],
#   'node_list': [9, 13, 14, 17, 16, 19, 11, 10],
#   'origi': 4},
#  163: {'desti': 5,
#   'length_of_route': 38.00765938322065,
#   'link_idx_list': [36, 46, 50, 55, 56, 63, 41],
#   'node_list': [9, 13, 14, 17, 16, 19, 18, 10],
#   'origi': 4},
#  164: {'desti': 5,
#   'length_of_route': 39.58524897698778,
#   'link_idx_list': [27, 28, 23, 13, 14, 30, 39],
#   'node_list': [9, 7, 13, 6, 4, 8, 11, 10],
#   'origi': 4},
#  165: {'desti': 5,
#   'length_of_route': 39.64929776511902,
#   'link_idx_list': [36, 46, 52, 67, 45, 39],
#   'node_list': [9, 13, 14, 22, 19, 11, 10],
#   'origi': 4},
#  166: {'desti': 5,
#   'length_of_route': 39.66056155886321,
#   'link_idx_list': [36, 46, 50, 55, 33, 30, 39],
#   'node_list': [9, 13, 14, 17, 16, 8, 11, 10],
#   'origi': 4},
#  167: {'desti': 5,
#   'length_of_route': 39.66549236101805,
#   'link_idx_list': [36, 46, 52, 67, 63, 41],
#   'node_list': [9, 13, 14, 22, 19, 18, 10],
#   'origi': 4},
#  168: {'desti': 30,
#   'length_of_route': 48.02999649590966,
#   'link_idx_list': [105, 106, 125, 128, 228],
#   'node_list': [28, 27, 33, 32, 60, 61],
#   'origi': 12},
#  169: {'desti': 30,
#   'length_of_route': 48.83775204464598,
#   'link_idx_list': [103, 100, 106, 125, 128, 228],
#   'node_list': [28, 26, 27, 33, 32, 60, 61],
#   'origi': 12},
#  170: {'desti': 30,
#   'length_of_route': 49.896168812312226,
#   'link_idx_list': [103, 95, 96, 125, 128, 228],
#   'node_list': [28, 26, 24, 33, 32, 60, 61],
#   'origi': 12},
#  171: {'desti': 30,
#   'length_of_route': 49.91707713187908,
#   'link_idx_list': [105, 106, 130, 127, 128, 228],
#   'node_list': [28, 27, 33, 34, 32, 60, 61],
#   'origi': 12},
#  172: {'desti': 30,
#   'length_of_route': 50.724832680615414,
#   'link_idx_list': [103, 100, 106, 130, 127, 128, 228],
#   'node_list': [28, 26, 27, 33, 34, 32, 60, 61],
#   'origi': 12},
#  173: {'desti': 30,
#   'length_of_route': 51.78324944828165,
#   'link_idx_list': [103, 95, 96, 130, 127, 128, 228],
#   'node_list': [28, 26, 24, 33, 34, 32, 60, 61],
#   'origi': 12},
#  174: {'desti': 30,
#   'length_of_route': 52.23093320193257,
#   'link_idx_list': [105, 101, 95, 96, 125, 128, 228],
#   'node_list': [28, 27, 26, 24, 33, 32, 60, 61],
#   'origi': 12},
#  175: {'desti': 30,
#   'length_of_route': 52.32599898810002,
#   'link_idx_list': [103, 99, 93, 96, 125, 128, 228],
#   'node_list': [28, 26, 25, 24, 33, 32, 60, 61],
#   'origi': 12},
#  176: {'desti': 30,
#   'length_of_route': 52.592610373225,
#   'link_idx_list': [105, 106, 130, 134, 228],
#   'node_list': [28, 27, 33, 34, 60, 61],
#   'origi': 12},
#  177: {'desti': 30,
#   'length_of_route': 53.230697628870715,
#   'link_idx_list': [103, 95, 89, 90, 122, 228],
#   'node_list': [28, 26, 24, 23, 31, 60, 61],
#   'origi': 12},
#  178: {'desti': 6,
#   'length_of_route': 11.407191020735793,
#   'link_idx_list': [36, 48],
#   'node_list': [9, 13, 15],
#   'origi': 4},
#  179: {'desti': 6,
#   'length_of_route': 18.98001732052409,
#   'link_idx_list': [27, 28, 48],
#   'node_list': [9, 7, 13, 15],
#   'origi': 4},
#  180: {'desti': 6,
#   'length_of_route': 43.46812632342045,
#   'link_idx_list': [27, 11, 8, 22, 48],
#   'node_list': [9, 7, 3, 6, 13, 15],
#   'origi': 4},
#  181: {'desti': 6,
#   'length_of_route': 48.41406765467997,
#   'link_idx_list': [5, 2, 28, 48],
#   'node_list': [9, 1, 7, 13, 15],
#   'origi': 4},
#  182: {'desti': 6,
#   'length_of_route': 58.5308300460441,
#   'link_idx_list': [27, 11, 8, 24, 51, 47, 48],
#   'node_list': [9, 7, 3, 6, 17, 14, 13, 15],
#   'origi': 4},
#  183: {'desti': 6,
#   'length_of_route': 60.05511592218387,
#   'link_idx_list': [5, 0, 10, 28, 48],
#   'node_list': [9, 1, 3, 7, 13, 15],
#   'origi': 4},
#  184: {'desti': 6,
#   'length_of_route': 61.21421514723049,
#   'link_idx_list': [5, 0, 8, 22, 48],
#   'node_list': [9, 1, 3, 6, 13, 15],
#   'origi': 4},
#  185: {'desti': 6,
#   'length_of_route': 63.187072201220474,
#   'link_idx_list': [27, 11, 8, 20, 32, 54, 51, 47, 48],
#   'node_list': [9, 7, 3, 6, 8, 16, 17, 14, 13, 15],
#   'origi': 4},
#  186: {'desti': 6,
#   'length_of_route': 63.70416729486428,
#   'link_idx_list': [27, 3, 0, 8, 22, 48],
#   'node_list': [9, 7, 1, 3, 6, 13, 15],
#   'origi': 4},
#  187: {'desti': 6,
#   'length_of_route': 64.7266824193398,
#   'link_idx_list': [27, 11, 8, 24, 55, 58, 53, 47, 48],
#   'node_list': [9, 7, 3, 6, 17, 16, 22, 14, 13, 15],
#   'origi': 4},
#  188: {'desti': 8,
#   'length_of_route': 12.701764882309018,
#   'link_idx_list': [50, 55, 56],
#   'node_list': [14, 17, 16, 19],
#   'origi': 7},
#  189: {'desti': 8,
#   'length_of_route': 14.359597860106424,
#   'link_idx_list': [52, 67],
#   'node_list': [14, 22, 19],
#   'origi': 7},
#  190: {'desti': 8,
#   'length_of_route': 16.5798798536026,
#   'link_idx_list': [52, 59, 56],
#   'node_list': [14, 22, 16, 19],
#   'origi': 7},
#  191: {'desti': 8,
#   'length_of_route': 17.277875116758423,
#   'link_idx_list': [50, 55, 58, 67],
#   'node_list': [14, 17, 16, 22, 19],
#   'origi': 7},
#  192: {'desti': 8,
#   'length_of_route': 17.873754833867334,
#   'link_idx_list': [50, 60, 67],
#   'node_list': [14, 17, 22, 19],
#   'origi': 7},
#  193: {'desti': 8,
#   'length_of_route': 19.823641814336934,
#   'link_idx_list': [52, 61, 55, 56],
#   'node_list': [14, 22, 17, 16, 19],
#   'origi': 7},
#  194: {'desti': 8,
#   'length_of_route': 20.09403682736351,
#   'link_idx_list': [50, 60, 59, 56],
#   'node_list': [14, 17, 22, 16, 19],
#   'origi': 7},
#  195: {'desti': 8,
#   'length_of_route': 23.096940776473925,
#   'link_idx_list': [52, 75, 65, 62],
#   'node_list': [14, 22, 21, 18, 19],
#   'origi': 7},
#  196: {'desti': 8,
#   'length_of_route': 25.502351271945248,
#   'link_idx_list': [52, 78, 77, 65, 62],
#   'node_list': [14, 22, 23, 21, 18, 19],
#   'origi': 7},
#  197: {'desti': 8,
#   'length_of_route': 26.015218033125926,
#   'link_idx_list': [50, 55, 58, 75, 65, 62],
#   'node_list': [14, 17, 16, 22, 21, 18, 19],
#   'origi': 7},
#  198: {'desti': 31,
#   'length_of_route': 22.910918061907445,
#   'link_idx_list': [128, 230, 244, 248],
#   'node_list': [32, 60, 63, 65, 66],
#   'origi': 14},
#  199: {'desti': 31,
#   'length_of_route': 23.496632434759775,
#   'link_idx_list': [128, 232, 248],
#   'node_list': [32, 60, 65, 66],
#   'origi': 14},
#  200: {'desti': 31,
#   'length_of_route': 28.35953580500876,
#   'link_idx_list': [121, 122, 230, 244, 248],
#   'node_list': [32, 31, 60, 63, 65, 66],
#   'origi': 14},
#  201: {'desti': 31,
#   'length_of_route': 28.945250177861098,
#   'link_idx_list': [121, 122, 232, 248],
#   'node_list': [32, 31, 60, 65, 66],
#   'origi': 14},
#  202: {'desti': 31,
#   'length_of_route': 29.28133227616545,
#   'link_idx_list': [126, 134, 230, 244, 248],
#   'node_list': [32, 34, 60, 63, 65, 66],
#   'origi': 14},
#  203: {'desti': 31,
#   'length_of_route': 29.867046649017787,
#   'link_idx_list': [126, 134, 232, 248],
#   'node_list': [32, 34, 60, 65, 66],
#   'origi': 14},
#  204: {'desti': 31,
#   'length_of_route': 31.892690910307785,
#   'link_idx_list': [121, 117, 118, 230, 244, 248],
#   'node_list': [32, 31, 30, 60, 63, 65, 66],
#   'origi': 14},
#  205: {'desti': 31,
#   'length_of_route': 32.47840528316012,
#   'link_idx_list': [121, 117, 118, 232, 248],
#   'node_list': [32, 31, 30, 60, 65, 66],
#   'origi': 14},
#  206: {'desti': 31,
#   'length_of_route': 37.40710617838338,
#   'link_idx_list': [124, 130, 134, 230, 244, 248],
#   'node_list': [32, 33, 34, 60, 63, 65, 66],
#   'origi': 14},
#  207: {'desti': 31,
#   'length_of_route': 37.99282055123572,
#   'link_idx_list': [124, 130, 134, 232, 248],
#   'node_list': [32, 33, 34, 60, 65, 66],
#   'origi': 14},
#  208: {'desti': 25,
#   'length_of_route': 71.52229920093288,
#   'link_idx_list': [18, 44, 66, 82, 110, 148, 164, 168, 174],
#   'node_list': [5, 11, 19, 22, 28, 37, 42, 43, 44, 54],
#   'origi': 1},
#  209: {'desti': 25,
#   'length_of_route': 73.21990828601298,
#   'link_idx_list': [18, 44, 66, 82, 110, 148, 166, 176, 182],
#   'node_list': [5, 11, 19, 22, 28, 37, 42, 45, 46, 54],
#   'origi': 1},
#  210: {'desti': 25,
#   'length_of_route': 75.22217482976664,
#   'link_idx_list': [16, 40, 62, 66, 86, 155, 156, 196],
#   'node_list': [5, 10, 18, 19, 22, 40, 39, 48, 54],
#   'origi': 1},
#  211: {'desti': 25,
#   'length_of_route': 75.26326052982053,
#   'link_idx_list': [18, 44, 66, 82, 110, 148, 166, 176, 173, 174],
#   'node_list': [5, 11, 19, 22, 28, 37, 42, 45, 46, 44, 54],
#   'origi': 1},
#  212: {'desti': 25,
#   'length_of_route': 75.96821782348596,
#   'link_idx_list': [18, 44, 66, 82, 110, 148, 164, 168, 172, 182],
#   'node_list': [5, 11, 19, 22, 28, 37, 42, 43, 44, 46, 54],
#   'origi': 1},
#  213: {'desti': 25,
#   'length_of_route': 76.08332178229017,
#   'link_idx_list': [18, 44, 66, 86, 155, 156, 196],
#   'node_list': [5, 11, 19, 22, 40, 39, 48, 54],
#   'origi': 1},
#  214: {'desti': 25,
#   'length_of_route': 76.69458826657107,
#   'link_idx_list': [16, 38, 44, 66, 86, 155, 156, 196],
#   'node_list': [5, 10, 11, 19, 22, 40, 39, 48, 54],
#   'origi': 1},
#  215: {'desti': 25,
#   'length_of_route': 77.22313575942881,
#   'link_idx_list': [16, 40, 62, 57, 58, 86, 155, 156, 196],
#   'node_list': [5, 10, 18, 19, 16, 22, 40, 39, 48, 54],
#   'origi': 1},
#  216: {'desti': 25,
#   'length_of_route': 77.87102610344606,
#   'link_idx_list': [18, 44, 66, 84, 112, 159, 155, 156, 196],
#   'node_list': [5, 11, 19, 22, 29, 41, 40, 39, 48, 54],
#   'origi': 1},
#  217: {'desti': 25,
#   'length_of_route': 78.08428271195234,
#   'link_idx_list': [18, 44, 57, 58, 86, 155, 156, 196],
#   'node_list': [5, 11, 19, 16, 22, 40, 39, 48, 54],
#   'origi': 1},
#  218: {'desti': 26,
#   'length_of_route': 53.797309363743445,
#   'link_idx_list': [16, 42, 72, 219, 215],
#   'node_list': [5, 10, 20, 58, 57, 55],
#   'origi': 1},
#  219: {'desti': 26,
#   'length_of_route': 56.8297736058042,
#   'link_idx_list': [18, 39, 42, 72, 219, 215],
#   'node_list': [5, 11, 10, 20, 58, 57, 55],
#   'origi': 1},
#  220: {'desti': 26,
#   'length_of_route': 64.10692722696172,
#   'link_idx_list': [16, 42, 72, 222, 221, 215],
#   'node_list': [5, 10, 20, 58, 59, 57, 55],
#   'origi': 1},
#  221: {'desti': 26,
#   'length_of_route': 67.13939146902246,
#   'link_idx_list': [18, 39, 42, 72, 222, 221, 215],
#   'node_list': [5, 11, 10, 20, 58, 59, 57, 55],
#   'origi': 1},
#  222: {'desti': 26,
#   'length_of_route': 71.70408770847976,
#   'link_idx_list': [16, 42, 70, 118, 240, 227, 221, 215],
#   'node_list': [5, 10, 20, 30, 60, 72, 59, 57, 55],
#   'origi': 1},
#  223: {'desti': 26,
#   'length_of_route': 72.47443104821309,
#   'link_idx_list': [16, 42, 70, 118, 225, 221, 215],
#   'node_list': [5, 10, 20, 30, 60, 59, 57, 55],
#   'origi': 1},
#  224: {'desti': 26,
#   'length_of_route': 72.75902013357471,
#   'link_idx_list': [16, 42, 70, 116, 122, 240, 227, 221, 215],
#   'node_list': [5, 10, 20, 30, 31, 60, 72, 59, 57, 55],
#   'origi': 1},
#  225: {'desti': 26,
#   'length_of_route': 73.46753093589948,
#   'link_idx_list': [16, 40, 64, 69, 72, 219, 215],
#   'node_list': [5, 10, 18, 21, 20, 58, 57, 55],
#   'origi': 1},
#  226: {'desti': 26,
#   'length_of_route': 73.52936347330802,
#   'link_idx_list': [16, 42, 70, 116, 122, 225, 221, 215],
#   'node_list': [5, 10, 20, 30, 31, 60, 59, 57, 55],
#   'origi': 1},
#  227: {'desti': 26,
#   'length_of_route': 74.7365519505405,
#   'link_idx_list': [18, 39, 42, 70, 118, 240, 227, 221, 215],
#   'node_list': [5, 11, 10, 20, 30, 60, 72, 59, 57, 55],
#   'origi': 1},
#  228: {'desti': 26,
#   'length_of_route': 55.10031286732456,
#   'link_idx_list': [16, 42, 72, 219, 217],
#   'node_list': [5, 10, 20, 58, 57, 56],
#   'origi': 1},
#  229: {'desti': 26,
#   'length_of_route': 58.132777109385316,
#   'link_idx_list': [18, 39, 42, 72, 219, 217],
#   'node_list': [5, 11, 10, 20, 58, 57, 56],
#   'origi': 1},
#  230: {'desti': 26,
#   'length_of_route': 65.40993073054283,
#   'link_idx_list': [16, 42, 72, 222, 221, 217],
#   'node_list': [5, 10, 20, 58, 59, 57, 56],
#   'origi': 1},
#  231: {'desti': 26,
#   'length_of_route': 68.44239497260357,
#   'link_idx_list': [18, 39, 42, 72, 222, 221, 217],
#   'node_list': [5, 11, 10, 20, 58, 59, 57, 56],
#   'origi': 1},
#  232: {'desti': 26,
#   'length_of_route': 73.00709121206089,
#   'link_idx_list': [16, 42, 70, 118, 240, 227, 221, 217],
#   'node_list': [5, 10, 20, 30, 60, 72, 59, 57, 56],
#   'origi': 1},
#  233: {'desti': 26,
#   'length_of_route': 73.7774345517942,
#   'link_idx_list': [16, 42, 70, 118, 225, 221, 217],
#   'node_list': [5, 10, 20, 30, 60, 59, 57, 56],
#   'origi': 1},
#  234: {'desti': 26,
#   'length_of_route': 74.06202363715582,
#   'link_idx_list': [16, 42, 70, 116, 122, 240, 227, 221, 217],
#   'node_list': [5, 10, 20, 30, 31, 60, 72, 59, 57, 56],
#   'origi': 1},
#  235: {'desti': 26,
#   'length_of_route': 74.77053443948058,
#   'link_idx_list': [16, 40, 64, 69, 72, 219, 217],
#   'node_list': [5, 10, 18, 21, 20, 58, 57, 56],
#   'origi': 1},
#  236: {'desti': 26,
#   'length_of_route': 74.83236697688915,
#   'link_idx_list': [16, 42, 70, 116, 122, 225, 221, 217],
#   'node_list': [5, 10, 20, 30, 31, 60, 59, 57, 56],
#   'origi': 1},
#  237: {'desti': 26,
#   'length_of_route': 76.03955545412163,
#   'link_idx_list': [18, 39, 42, 70, 118, 240, 227, 221, 217],
#   'node_list': [5, 11, 10, 20, 30, 60, 72, 59, 57, 56],
#   'origi': 1},
#  238: {'desti': 27,
#   'length_of_route': 44.65784419217648,
#   'link_idx_list': [16, 42, 72, 219],
#   'node_list': [5, 10, 20, 58, 57],
#   'origi': 1},
#  239: {'desti': 27,
#   'length_of_route': 47.69030843423724,
#   'link_idx_list': [18, 39, 42, 72, 219],
#   'node_list': [5, 11, 10, 20, 58, 57],
#   'origi': 1},
#  240: {'desti': 27,
#   'length_of_route': 54.96746205539475,
#   'link_idx_list': [16, 42, 72, 222, 221],
#   'node_list': [5, 10, 20, 58, 59, 57],
#   'origi': 1},
#  241: {'desti': 27,
#   'length_of_route': 57.999926297455495,
#   'link_idx_list': [18, 39, 42, 72, 222, 221],
#   'node_list': [5, 11, 10, 20, 58, 59, 57],
#   'origi': 1},
#  242: {'desti': 27,
#   'length_of_route': 62.56462253691281,
#   'link_idx_list': [16, 42, 70, 118, 240, 227, 221],
#   'node_list': [5, 10, 20, 30, 60, 72, 59, 57],
#   'origi': 1},
#  243: {'desti': 27,
#   'length_of_route': 63.33496587664613,
#   'link_idx_list': [16, 42, 70, 118, 225, 221],
#   'node_list': [5, 10, 20, 30, 60, 59, 57],
#   'origi': 1},
#  244: {'desti': 27,
#   'length_of_route': 63.61955496200775,
#   'link_idx_list': [16, 42, 70, 116, 122, 240, 227, 221],
#   'node_list': [5, 10, 20, 30, 31, 60, 72, 59, 57],
#   'origi': 1},
#  245: {'desti': 27,
#   'length_of_route': 64.32806576433251,
#   'link_idx_list': [16, 40, 64, 69, 72, 219],
#   'node_list': [5, 10, 18, 21, 20, 58, 57],
#   'origi': 1},
#  246: {'desti': 27,
#   'length_of_route': 64.38989830174107,
#   'link_idx_list': [16, 42, 70, 116, 122, 225, 221],
#   'node_list': [5, 10, 20, 30, 31, 60, 59, 57],
#   'origi': 1},
#  247: {'desti': 27,
#   'length_of_route': 65.59708677897355,
#   'link_idx_list': [18, 39, 42, 70, 118, 240, 227, 221],
#   'node_list': [5, 11, 10, 20, 30, 60, 72, 59, 57],
#   'origi': 1},
#  248: {'desti': 22,
#   'length_of_route': 80.44469734376389,
#   'link_idx_list': [16, 40, 62, 66, 84, 114, 200],
#   'node_list': [5, 10, 18, 19, 22, 29, 49, 50],
#   'origi': 1},
#  249: {'desti': 22,
#   'length_of_route': 81.3058442962874,
#   'link_idx_list': [18, 44, 66, 84, 114, 200],
#   'node_list': [5, 11, 19, 22, 29, 49, 50],
#   'origi': 1},
#  250: {'desti': 22,
#   'length_of_route': 81.91711078056832,
#   'link_idx_list': [16, 38, 44, 66, 84, 114, 200],
#   'node_list': [5, 10, 11, 19, 22, 29, 49, 50],
#   'origi': 1},
#  251: {'desti': 22,
#   'length_of_route': 82.44565827342606,
#   'link_idx_list': [16, 40, 62, 57, 58, 84, 114, 200],
#   'node_list': [5, 10, 18, 19, 16, 22, 29, 49, 50],
#   'origi': 1},
#  252: {'desti': 22,
#   'length_of_route': 83.30680522594957,
#   'link_idx_list': [18, 44, 57, 58, 84, 114, 200],
#   'node_list': [5, 11, 19, 16, 22, 29, 49, 50],
#   'origi': 1},
#  253: {'desti': 22,
#   'length_of_route': 83.47716158582463,
#   'link_idx_list': [18, 39, 40, 62, 66, 84, 114, 200],
#   'node_list': [5, 11, 10, 18, 19, 22, 29, 49, 50],
#   'origi': 1},
#  254: {'desti': 22,
#   'length_of_route': 83.91807171023049,
#   'link_idx_list': [16, 38, 44, 57, 58, 84, 114, 200],
#   'node_list': [5, 10, 11, 19, 16, 22, 29, 49, 50],
#   'origi': 1},
#  255: {'desti': 22,
#   'length_of_route': 84.4121583721287,
#   'link_idx_list': [16, 40, 62, 66, 84, 114, 202, 207],
#   'node_list': [5, 10, 18, 19, 22, 29, 49, 73, 50],
#   'origi': 1},
#  256: {'desti': 22,
#   'length_of_route': 84.52849925380966,
#   'link_idx_list': [16, 40, 64, 74, 84, 114, 200],
#   'node_list': [5, 10, 18, 21, 22, 29, 49, 50],
#   'origi': 1},
#  257: {'desti': 22,
#   'length_of_route': 84.92738101453182,
#   'link_idx_list': [18, 31, 32, 58, 84, 114, 200],
#   'node_list': [5, 11, 8, 16, 22, 29, 49, 50],
#   'origi': 1},
#  258: {'desti': 22,
#   'length_of_route': 89.5390559239657,
#   'link_idx_list': [16, 40, 62, 66, 86, 155, 156, 190],
#   'node_list': [5, 10, 18, 19, 22, 40, 39, 48, 51],
#   'origi': 1},
#  259: {'desti': 22,
#   'length_of_route': 90.40020287648923,
#   'link_idx_list': [18, 44, 66, 86, 155, 156, 190],
#   'node_list': [5, 11, 19, 22, 40, 39, 48, 51],
#   'origi': 1},
#  260: {'desti': 22,
#   'length_of_route': 91.01146936077014,
#   'link_idx_list': [16, 38, 44, 66, 86, 155, 156, 190],
#   'node_list': [5, 10, 11, 19, 22, 40, 39, 48, 51],
#   'origi': 1},
#  261: {'desti': 22,
#   'length_of_route': 91.54001685362788,
#   'link_idx_list': [16, 40, 62, 57, 58, 86, 155, 156, 190],
#   'node_list': [5, 10, 18, 19, 16, 22, 40, 39, 48, 51],
#   'origi': 1},
#  262: {'desti': 22,
#   'length_of_route': 92.02980525710947,
#   'link_idx_list': [16, 40, 62, 66, 86, 155, 156, 192, 209],
#   'node_list': [5, 10, 18, 19, 22, 40, 39, 48, 52, 51],
#   'origi': 1},
#  263: {'desti': 22,
#   'length_of_route': 92.18790719764512,
#   'link_idx_list': [18, 44, 66, 84, 112, 159, 155, 156, 190],
#   'node_list': [5, 11, 19, 22, 29, 41, 40, 39, 48, 51],
#   'origi': 1},
#  264: {'desti': 22,
#   'length_of_route': 92.4011638061514,
#   'link_idx_list': [18, 44, 57, 58, 86, 155, 156, 190],
#   'node_list': [5, 11, 19, 16, 22, 40, 39, 48, 51],
#   'origi': 1},
#  265: {'desti': 22,
#   'length_of_route': 92.57152016602645,
#   'link_idx_list': [18, 39, 40, 62, 66, 86, 155, 156, 190],
#   'node_list': [5, 11, 10, 18, 19, 22, 40, 39, 48, 51],
#   'origi': 1},
#  266: {'desti': 22,
#   'length_of_route': 92.59130915242004,
#   'link_idx_list': [16, 40, 62, 66, 86, 160, 190],
#   'node_list': [5, 10, 18, 19, 22, 40, 48, 51],
#   'origi': 1},
#  267: {'desti': 22,
#   'length_of_route': 92.890952209633,
#   'link_idx_list': [18, 44, 66, 86, 155, 156, 192, 209],
#   'node_list': [5, 11, 19, 22, 40, 39, 48, 52, 51],
#   'origi': 1},
#  268: {'desti': 23,
#   'length_of_route': 77.09873450776732,
#   'link_idx_list': [16, 40, 62, 66, 86, 155, 156, 192],
#   'node_list': [5, 10, 18, 19, 22, 40, 39, 48, 52],
#   'origi': 1},
#  269: {'desti': 23,
#   'length_of_route': 77.95988146029084,
#   'link_idx_list': [18, 44, 66, 86, 155, 156, 192],
#   'node_list': [5, 11, 19, 22, 40, 39, 48, 52],
#   'origi': 1},
#  270: {'desti': 23,
#   'length_of_route': 78.57114794457175,
#   'link_idx_list': [16, 38, 44, 66, 86, 155, 156, 192],
#   'node_list': [5, 10, 11, 19, 22, 40, 39, 48, 52],
#   'origi': 1},
#  271: {'desti': 23,
#   'length_of_route': 79.09969543742949,
#   'link_idx_list': [16, 40, 62, 57, 58, 86, 155, 156, 192],
#   'node_list': [5, 10, 18, 19, 16, 22, 40, 39, 48, 52],
#   'origi': 1},
#  272: {'desti': 23,
#   'length_of_route': 79.74758578144673,
#   'link_idx_list': [18, 44, 66, 84, 112, 159, 155, 156, 192],
#   'node_list': [5, 11, 19, 22, 29, 41, 40, 39, 48, 52],
#   'origi': 1},
#  273: {'desti': 23,
#   'length_of_route': 79.96084238995302,
#   'link_idx_list': [18, 44, 57, 58, 86, 155, 156, 192],
#   'node_list': [5, 11, 19, 16, 22, 40, 39, 48, 52],
#   'origi': 1},
#  274: {'desti': 23,
# ...
#   'link_idx_list': [12, 20, 30, 39, 42, 70, 118, 240, 227],
#   'node_list': [4, 6, 8, 11, 10, 20, 30, 60, 72, 59],
#   'origi': 1},
#  911: {'desti': 29,
#   'length_of_route': 55.523324144450044,
#   'link_idx_list': [14, 30, 39, 42, 70, 118, 225],
#   'node_list': [4, 8, 11, 10, 20, 30, 60, 59],
#   'origi': 1},
#  912: {'desti': 29,
#   'length_of_route': 55.7228690970842,
#   'link_idx_list': [12, 20, 30, 39, 42, 70, 118, 225],
#   'node_list': [4, 6, 8, 11, 10, 20, 30, 60, 59],
#   'origi': 1},
#  913: {'desti': 29,
#   'length_of_route': 55.80791322981166,
#   'link_idx_list': [14, 30, 39, 42, 70, 116, 122, 240, 227],
#   'node_list': [4, 8, 11, 10, 20, 30, 31, 60, 72, 59],
#   'origi': 1},
#  914: {'desti': 29,
#   'length_of_route': 56.007458182445816,
#   'link_idx_list': [12, 20, 30, 39, 42, 70, 116, 122, 240, 227],
#   'node_list': [4, 6, 8, 11, 10, 20, 30, 31, 60, 72, 59],
#   'origi': 1},
#  915: {'desti': 29,
#   'length_of_route': 56.21491292974561,
#   'link_idx_list': [12, 24, 55, 58, 78, 90, 122, 240, 227],
#   'node_list': [4, 6, 17, 16, 22, 23, 31, 60, 72, 59],
#   'origi': 1},
#  916: {'desti': 29,
#   'length_of_route': 56.578256569544976,
#   'link_idx_list': [14, 30, 39, 42, 70, 116, 122, 225],
#   'node_list': [4, 8, 11, 10, 20, 30, 31, 60, 59],
#   'origi': 1},
#  917: {'desti': 29,
#   'length_of_route': 47.02745905544175,
#   'link_idx_list': [14, 30, 39, 42, 70, 118],
#   'node_list': [4, 8, 11, 10, 20, 30, 60],
#   'origi': 1},
#  918: {'desti': 29,
#   'length_of_route': 47.22700400807591,
#   'link_idx_list': [12, 20, 30, 39, 42, 70, 118],
#   'node_list': [4, 6, 8, 11, 10, 20, 30, 60],
#   'origi': 1},
#  919: {'desti': 29,
#   'length_of_route': 48.08239148053669,
#   'link_idx_list': [14, 30, 39, 42, 70, 116, 122],
#   'node_list': [4, 8, 11, 10, 20, 30, 31, 60],
#   'origi': 1},
#  920: {'desti': 29,
#   'length_of_route': 48.28193643317085,
#   'link_idx_list': [12, 20, 30, 39, 42, 70, 116, 122],
#   'node_list': [4, 6, 8, 11, 10, 20, 30, 31, 60],
#   'origi': 1},
#  921: {'desti': 29,
#   'length_of_route': 48.48939118047064,
#   'link_idx_list': [12, 24, 55, 58, 78, 90, 122],
#   'node_list': [4, 6, 17, 16, 22, 23, 31, 60],
#   'origi': 1},
#  922: {'desti': 29,
#   'length_of_route': 49.08527089757954,
#   'link_idx_list': [12, 24, 60, 78, 90, 122],
#   'node_list': [4, 6, 17, 22, 23, 31, 60],
#   'origi': 1},
#  923: {'desti': 29,
#   'length_of_route': 49.99502402736353,
#   'link_idx_list': [12, 24, 55, 58, 78, 88, 96, 125, 128],
#   'node_list': [4, 6, 17, 16, 22, 23, 24, 33, 32, 60],
#   'origi': 1},
#  924: {'desti': 29,
#   'length_of_route': 50.238449847202666,
#   'link_idx_list': [14, 32, 58, 78, 90, 122],
#   'node_list': [4, 8, 16, 22, 23, 31, 60],
#   'origi': 1},
#  925: {'desti': 29,
#   'length_of_route': 50.43799479983682,
#   'link_idx_list': [12, 20, 32, 58, 78, 90, 122],
#   'node_list': [4, 6, 8, 16, 22, 23, 31, 60],
#   'origi': 1},
#  926: {'desti': 29,
#   'length_of_route': 50.590903744472435,
#   'link_idx_list': [12, 24, 60, 78, 88, 96, 125, 128],
#   'node_list': [4, 6, 17, 22, 23, 24, 33, 32, 60],
#   'origi': 1},
#  927: {'desti': 30,
#   'length_of_route': 71.86443760549909,
#   'link_idx_list': [14, 30, 39, 42, 70, 118, 228],
#   'node_list': [4, 8, 11, 10, 20, 30, 60, 61],
#   'origi': 1},
#  928: {'desti': 30,
#   'length_of_route': 72.06398255813325,
#   'link_idx_list': [12, 20, 30, 39, 42, 70, 118, 228],
#   'node_list': [4, 6, 8, 11, 10, 20, 30, 60, 61],
#   'origi': 1},
#  929: {'desti': 30,
#   'length_of_route': 72.91937003059404,
#   'link_idx_list': [14, 30, 39, 42, 70, 116, 122, 228],
#   'node_list': [4, 8, 11, 10, 20, 30, 31, 60, 61],
#   'origi': 1},
#  930: {'desti': 30,
#   'length_of_route': 73.1189149832282,
#   'link_idx_list': [12, 20, 30, 39, 42, 70, 116, 122, 228],
#   'node_list': [4, 6, 8, 11, 10, 20, 30, 31, 60, 61],
#   'origi': 1},
#  931: {'desti': 30,
#   'length_of_route': 73.32636973052799,
#   'link_idx_list': [12, 24, 55, 58, 78, 90, 122, 228],
#   'node_list': [4, 6, 17, 16, 22, 23, 31, 60, 61],
#   'origi': 1},
#  932: {'desti': 30,
#   'length_of_route': 73.92224944763689,
#   'link_idx_list': [12, 24, 60, 78, 90, 122, 228],
#   'node_list': [4, 6, 17, 22, 23, 31, 60, 61],
#   'origi': 1},
#  933: {'desti': 30,
#   'length_of_route': 75.07542839726001,
#   'link_idx_list': [14, 32, 58, 78, 90, 122, 228],
#   'node_list': [4, 8, 16, 22, 23, 31, 60, 61],
#   'origi': 1},
#  934: {'desti': 30,
#   'length_of_route': 75.27497334989417,
#   'link_idx_list': [12, 20, 32, 58, 78, 90, 122, 228],
#   'node_list': [4, 6, 8, 16, 22, 23, 31, 60, 61],
#   'origi': 1},
#  935: {'desti': 30,
#   'length_of_route': 75.42788229452978,
#   'link_idx_list': [12, 24, 60, 78, 88, 96, 125, 128, 228],
#   'node_list': [4, 6, 17, 22, 23, 24, 33, 32, 60, 61],
#   'origi': 1},
#  936: {'desti': 30,
#   'length_of_route': 75.95035687602503,
#   'link_idx_list': [14, 30, 39, 42, 70, 116, 120, 128, 228],
#   'node_list': [4, 8, 11, 10, 20, 30, 31, 32, 60, 61],
#   'origi': 1},
#  937: {'desti': 31,
#   'length_of_route': 60.77010474624242,
#   'link_idx_list': [14, 30, 39, 42, 70, 118, 230, 243],
#   'node_list': [4, 8, 11, 10, 20, 30, 60, 63, 62],
#   'origi': 1},
#  938: {'desti': 31,
#   'length_of_route': 60.96964969887657,
#   'link_idx_list': [12, 20, 30, 39, 42, 70, 118, 230, 243],
#   'node_list': [4, 6, 8, 11, 10, 20, 30, 60, 63, 62],
#   'origi': 1},
#  939: {'desti': 31,
#   'length_of_route': 61.825037171337364,
#   'link_idx_list': [14, 30, 39, 42, 70, 116, 122, 230, 243],
#   'node_list': [4, 8, 11, 10, 20, 30, 31, 60, 63, 62],
#   'origi': 1},
#  940: {'desti': 31,
#   'length_of_route': 62.23203687127131,
#   'link_idx_list': [12, 24, 55, 58, 78, 90, 122, 230, 243],
#   'node_list': [4, 6, 17, 16, 22, 23, 31, 60, 63, 62],
#   'origi': 1},
#  941: {'desti': 31,
#   'length_of_route': 62.82791658838021,
#   'link_idx_list': [12, 24, 60, 78, 90, 122, 230, 243],
#   'node_list': [4, 6, 17, 22, 23, 31, 60, 63, 62],
#   'origi': 1},
#  942: {'desti': 31,
#   'length_of_route': 63.98109553800334,
#   'link_idx_list': [14, 32, 58, 78, 90, 122, 230, 243],
#   'node_list': [4, 8, 16, 22, 23, 31, 60, 63, 62],
#   'origi': 1},
#  943: {'desti': 31,
#   'length_of_route': 64.1806404906375,
#   'link_idx_list': [12, 20, 32, 58, 78, 90, 122, 230, 243],
#   'node_list': [4, 6, 8, 16, 22, 23, 31, 60, 63, 62],
#   'origi': 1},
#  944: {'desti': 31,
#   'length_of_route': 64.24537676370818,
#   'link_idx_list': [14, 30, 39, 42, 70, 118, 232, 245, 243],
#   'node_list': [4, 8, 11, 10, 20, 30, 60, 65, 63, 62],
#   'origi': 1},
#  945: {'desti': 31,
#   'length_of_route': 65.85890343381121,
#   'link_idx_list': [12, 24, 60, 78, 90, 120, 128, 230, 243],
#   'node_list': [4, 6, 17, 22, 23, 31, 32, 60, 63, 62],
#   'origi': 1},
#  946: {'desti': 31,
#   'length_of_route': 66.30318860584596,
#   'link_idx_list': [12, 24, 60, 78, 90, 122, 232, 245, 243],
#   'node_list': [4, 6, 17, 22, 23, 31, 60, 65, 63, 62],
#   'origi': 1},
#  947: {'desti': 33,
#   'length_of_route': 25.638981239880167,
#   'link_idx_list': [242, 231, 236],
#   'node_list': [62, 63, 60, 69],
#   'origi': 31},
#  948: {'desti': 33,
#   'length_of_route': 28.835469572856667,
#   'link_idx_list': [242, 244, 233, 236],
#   'node_list': [62, 63, 65, 60, 69],
#   'origi': 31},
#  949: {'desti': 33,
#   'length_of_route': 33.877073243518886,
#   'link_idx_list': [242, 231, 234, 252],
#   'node_list': [62, 63, 60, 67, 69],
#   'origi': 31},
#  950: {'desti': 33,
#   'length_of_route': 35.31881294366461,
#   'link_idx_list': [242, 231, 238, 257],
#   'node_list': [62, 63, 60, 71, 69],
#   'origi': 31},
#  951: {'desti': 33,
#   'length_of_route': 37.073561576495386,
#   'link_idx_list': [242, 244, 233, 234, 252],
#   'node_list': [62, 63, 65, 60, 67, 69],
#   'origi': 31},
#  952: {'desti': 33,
#   'length_of_route': 38.51530127664111,
#   'link_idx_list': [242, 244, 233, 238, 257],
#   'node_list': [62, 63, 65, 60, 71, 69],
#   'origi': 31},
#  953: {'desti': 33,
#   'length_of_route': 42.7209291225595,
#   'link_idx_list': [242, 231, 129, 126, 132, 138, 257],
#   'node_list': [62, 63, 60, 32, 34, 35, 71, 69],
#   'origi': 31},
#  954: {'desti': 33,
#   'length_of_route': 45.917417455536,
#   'link_idx_list': [242, 244, 233, 129, 126, 132, 138, 257],
#   'node_list': [62, 63, 65, 60, 32, 34, 35, 71, 69],
#   'origi': 31},
#  955: {'desti': 33,
#   'length_of_route': 48.259002817566085,
#   'link_idx_list': [242, 231, 123, 120, 126, 132, 138, 257],
#   'node_list': [62, 63, 60, 31, 32, 34, 35, 71, 69],
#   'origi': 31},
#  956: {'desti': 33,
#   'length_of_route': 50.27813221656784,
#   'link_idx_list': [242, 231, 135, 132, 138, 257],
#   'node_list': [62, 63, 60, 34, 35, 71, 69],
#   'origi': 31},
#  957: {'desti': 30,
#   'length_of_route': 39.68001417168985,
#   'link_idx_list': [246, 233, 228],
#   'node_list': [64, 65, 60, 61],
#   'origi': 31},
#  958: {'desti': 30,
#   'length_of_route': 39.373083483326766,
#   'link_idx_list': [246, 245, 231, 228],
#   'node_list': [64, 65, 63, 60, 61],
#   'origi': 31},
#  959: {'desti': 29,
#   'length_of_route': 14.843035621632506,
#   'link_idx_list': [246, 233],
#   'node_list': [64, 65, 60],
#   'origi': 31},
#  960: {'desti': 29,
#   'length_of_route': 14.536104933269428,
#   'link_idx_list': [246, 245, 231],
#   'node_list': [64, 65, 63, 60],
#   'origi': 31},
#  961: {'desti': 17,
#   'length_of_route': 58.46108932772552,
#   'link_idx_list': [249, 245, 231, 123, 91, 79, 86],
#   'node_list': [66, 65, 63, 60, 31, 23, 22, 40],
#   'origi': 31},
#  962: {'desti': 17,
#   'length_of_route': 58.7680200160886,
#   'link_idx_list': [249, 233, 123, 91, 79, 86],
#   'node_list': [66, 65, 60, 31, 23, 22, 40],
#   'origi': 31},
#  963: {'desti': 17,
#   'length_of_route': 59.70061772652183,
#   'link_idx_list': [249, 245, 231, 129, 124, 97, 89, 79, 86],
#   'node_list': [66, 65, 63, 60, 32, 33, 24, 23, 22, 40],
#   'origi': 31},
#  964: {'desti': 17,
#   'length_of_route': 60.00754841488491,
#   'link_idx_list': [249, 233, 129, 124, 97, 89, 79, 86],
#   'node_list': [66, 65, 60, 32, 33, 24, 23, 22, 40],
#   'origi': 31},
#  965: {'desti': 17,
#   'length_of_route': 60.24879364888139,
#   'link_idx_list': [249, 245, 231, 123, 91, 79, 84, 112, 159],
#   'node_list': [66, 65, 63, 60, 31, 23, 22, 29, 41, 40],
#   'origi': 31},
#  966: {'desti': 17,
#   'length_of_route': 60.55572433724447,
#   'link_idx_list': [249, 233, 123, 91, 79, 84, 112, 159],
#   'node_list': [66, 65, 60, 31, 23, 22, 29, 41, 40],
#   'origi': 31},
#  967: {'desti': 17,
#   'length_of_route': 61.40262022125124,
#   'link_idx_list': [249, 245, 231, 129, 121, 91, 79, 86],
#   'node_list': [66, 65, 63, 60, 32, 31, 23, 22, 40],
#   'origi': 31},
#  968: {'desti': 17,
#   'length_of_route': 61.70955090961432,
#   'link_idx_list': [249, 233, 129, 121, 91, 79, 86],
#   'node_list': [66, 65, 60, 32, 31, 23, 22, 40],
#   'origi': 31},
#  969: {'desti': 17,
#   'length_of_route': 61.723741695968826,
#   'link_idx_list': [249, 233, 129, 126, 131, 97, 89, 79, 86],
#   'node_list': [66, 65, 60, 32, 34, 33, 24, 23, 22, 40],
#   'origi': 31},
#  970: {'desti': 17,
#   'length_of_route': 62.05468492493847,
#   'link_idx_list': [249, 245, 231, 119, 116, 91, 79, 86],
#   'node_list': [66, 65, 63, 60, 30, 31, 23, 22, 40],
#   'origi': 31},
#  971: {'desti': 29,
#   'length_of_route': 43.999641155698214,
#   'link_idx_list': [30, 39, 42, 72, 222, 226],
#   'node_list': [8, 11, 10, 20, 58, 59, 72],
#   'origi': 3},
#  972: {'desti': 29,
#   'length_of_route': 45.377144711846,
#   'link_idx_list': [30, 39, 42, 70, 118, 240],
#   'node_list': [8, 11, 10, 20, 30, 60, 72],
#   'origi': 3},
#  973: {'desti': 29,
#   'length_of_route': 46.43207713694094,
#   'link_idx_list': [30, 39, 42, 70, 116, 122, 240],
#   'node_list': [8, 11, 10, 20, 30, 31, 60, 72],
#   'origi': 3},
#  974: {'desti': 29,
#   'length_of_route': 48.588135503606914,
#   'link_idx_list': [32, 58, 78, 90, 122, 240],
#   'node_list': [8, 16, 22, 23, 31, 60, 72],
#   'origi': 3},
#  975: {'desti': 29,
#   'length_of_route': 49.46306398237193,
#   'link_idx_list': [30, 39, 42, 70, 116, 120, 128, 240],
#   'node_list': [8, 11, 10, 20, 30, 31, 32, 60, 72],
#   'origi': 3},
#  976: {'desti': 29,
#   'length_of_route': 50.09376835049981,
#   'link_idx_list': [32, 58, 78, 88, 96, 125, 128, 240],
#   'node_list': [8, 16, 22, 23, 24, 33, 32, 60, 72],
#   'origi': 3},
#  977: {'desti': 29,
#   'length_of_route': 51.6191223490379,
#   'link_idx_list': [32, 58, 78, 90, 120, 128, 240],
#   'node_list': [8, 16, 22, 23, 31, 32, 60, 72],
#   'origi': 3},
#  978: {'desti': 29,
#   'length_of_route': 51.89165375652602,
#   'link_idx_list': [32, 54, 60, 78, 90, 122, 240],
#   'node_list': [8, 16, 17, 22, 23, 31, 60, 72],
#   'origi': 3},
#  979: {'desti': 29,
#   'length_of_route': 51.98084898646923,
#   'link_idx_list': [32, 58, 78, 88, 96, 130, 127, 128, 240],
#   'node_list': [8, 16, 22, 23, 24, 33, 34, 32, 60, 72],
#   'origi': 3},
#  980: {'desti': 29,
#   'length_of_route': 52.12129060890593,
#   'link_idx_list': [32, 58, 78, 90, 117, 118, 240],
#   'node_list': [8, 16, 22, 23, 31, 30, 60, 72],
#   'origi': 3},
#  981: {'desti': 32,
#   'length_of_route': 53.45037492070547,
#   'link_idx_list': [46, 52, 78, 90, 122, 234],
#   'node_list': [13, 14, 22, 23, 31, 60, 67],
#   'origi': 7},
#  982: {'desti': 32,
#   'length_of_route': 54.95600776759836,
#   'link_idx_list': [46, 52, 78, 88, 96, 125, 128, 234],
#   'node_list': [13, 14, 22, 23, 24, 33, 32, 60, 67],
#   'origi': 7},
#  983: {'desti': 32,
#   'length_of_route': 56.368652177357475,
#   'link_idx_list': [46, 50, 55, 58, 78, 90, 122, 234],
#   'node_list': [13, 14, 17, 16, 22, 23, 31, 60, 67],
#   'origi': 7},
#  984: {'desti': 32,
#   'length_of_route': 56.48136176613646,
#   'link_idx_list': [46, 52, 78, 90, 120, 128, 234],
#   'node_list': [13, 14, 22, 23, 31, 32, 60, 67],
#   'origi': 7},
#  985: {'desti': 32,
#   'length_of_route': 56.84308840356778,
#   'link_idx_list': [46, 52, 78, 88, 96, 130, 127, 128, 234],
#   'node_list': [13, 14, 22, 23, 24, 33, 34, 32, 60, 67],
#   'origi': 7},
#  986: {'desti': 32,
#   'length_of_route': 56.964531894466376,
#   'link_idx_list': [46, 50, 60, 78, 90, 122, 234],
#   'node_list': [13, 14, 17, 22, 23, 31, 60, 67],
#   'origi': 7},
#  987: {'desti': 32,
#   'length_of_route': 56.98353002600449,
#   'link_idx_list': [46, 52, 78, 90, 117, 118, 234],
#   'node_list': [13, 14, 22, 23, 31, 30, 60, 67],
#   'origi': 7},
#  988: {'desti': 32,
#   'length_of_route': 57.28493426153105,
#   'link_idx_list': [46, 52, 82, 105, 106, 125, 128, 234],
#   'node_list': [13, 14, 22, 28, 27, 33, 32, 60, 67],
#   'origi': 7},
#  989: {'desti': 32,
#   'length_of_route': 58.09268981026738,
#   'link_idx_list': [46, 52, 82, 103, 100, 106, 125, 128, 234],
#   'node_list': [13, 14, 22, 28, 26, 27, 33, 32, 60, 67],
#   'origi': 7},
#  990: {'desti': 32,
#   'length_of_route': 58.47016474135927,
#   'link_idx_list': [46, 50, 60, 78, 88, 96, 125, 128, 234],
#   'node_list': [13, 14, 17, 22, 23, 24, 33, 32, 60, 67],
#   'origi': 7},
#  991: {'desti': 22,
#   'length_of_route': 79.77421273176986,
#   'link_idx_list': [6, 8, 24, 55, 58, 84, 114, 200],
#   'node_list': [2, 3, 6, 17, 16, 22, 29, 49, 50],
#   'origi': 1},
#  992: {'desti': 22,
#   'length_of_route': 80.37009244887878,
#   'link_idx_list': [6, 8, 24, 60, 84, 114, 200],
#   'node_list': [2, 3, 6, 17, 22, 29, 49, 50],
#   'origi': 1},
#  993: {'desti': 22,
#   'length_of_route': 81.72281635113606,
#   'link_idx_list': [6, 8, 20, 32, 58, 84, 114, 200],
#   'node_list': [2, 3, 6, 8, 16, 22, 29, 49, 50],
#   'origi': 1},
#  994: {'desti': 22,
#   'length_of_route': 83.74167376013469,
#   'link_idx_list': [6, 8, 24, 55, 58, 84, 114, 202, 207],
#   'node_list': [2, 3, 6, 17, 16, 22, 29, 49, 73, 50],
#   'origi': 1},
#  995: {'desti': 22,
#   'length_of_route': 84.3375534772436,
#   'link_idx_list': [6, 8, 24, 60, 84, 114, 202, 207],
#   'node_list': [2, 3, 6, 17, 22, 29, 49, 73, 50],
#   'origi': 1},
#  996: {'desti': 22,
#   'length_of_route': 85.02633460405514,
#   'link_idx_list': [6, 8, 20, 32, 54, 60, 84, 114, 200],
#   'node_list': [2, 3, 6, 8, 16, 17, 22, 29, 49, 50],
#   'origi': 1},
#  997: {'desti': 22,
#   'length_of_route': 85.12026444546532,
#   'link_idx_list': [6, 8, 24, 55, 58, 84, 112, 162, 200],
#   'node_list': [2, 3, 6, 17, 16, 22, 29, 41, 49, 50],
#   'origi': 1},
#  998: {'desti': 22,
#   'length_of_route': 85.69027737950087,
#   'link_idx_list': [6, 8, 20, 32, 58, 84, 114, 202, 207],
#   'node_list': [2, 3, 6, 8, 16, 22, 29, 49, 73, 50],
#   'origi': 1},
#  999: {'desti': 22,
#   'length_of_route': 85.71614416257424,
#   'link_idx_list': [6, 8, 24, 60, 84, 112, 162, 200],
#   'node_list': [2, 3, 6, 17, 22, 29, 41, 49, 50],
#   'origi': 1},
#  ...}

# %%
link_label_dict_['24->23'], link_label_dict_['23->22'], link_label_dict_['22->29']
# Out:
# (89, 79, 84)
