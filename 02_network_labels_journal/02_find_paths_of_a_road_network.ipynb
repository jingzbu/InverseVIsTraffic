# %%
# %run ../Python_files/util.py
# Out:
# No dicts found; please check load_dicts...

# %%
# number of links
m = 258

# %%
ini_node_dict, ter_node_dict, node_neighbors_dict, origi_dict, desti_dict = \
zload('../temp_files/origin_terminal_dict_journal.pkz')

# %%
node_neighbors_dict
# Out:
# defaultdict(list,
#             {'1': [3, 7, 9],
#              '10': [5, 11, 18, 20],
#              '11': [5, 8, 10, 19],
#              '12': [9],
#              '13': [6, 7, 9, 14, 15],
#              '14': [13, 17, 22],
#              '15': [13],
#              '16': [8, 17, 19, 22],
#              '17': [6, 14, 16, 22],
#              '18': [10, 19, 21],
#              '19': [11, 16, 18, 22],
#              '2': [3],
#              '20': [10, 21, 30, 58],
#              '21': [18, 20, 22, 23],
#              '22': [14, 16, 17, 19, 21, 23, 25, 28, 29, 40],
#              '23': [21, 22, 24, 31],
#              '24': [23, 25, 26, 33],
#              '25': [22, 24, 26],
#              '26': [24, 25, 27, 28],
#              '27': [26, 28, 33, 35],
#              '28': [22, 26, 27, 37],
#              '29': [22, 41, 49],
#              '3': [1, 2, 6, 7],
#              '30': [20, 31, 60],
#              '31': [23, 30, 32, 60],
#              '32': [31, 33, 34, 60],
#              '33': [24, 27, 32, 34],
#              '34': [32, 33, 35, 60],
#              '35': [27, 34, 36, 71],
#              '36': [35, 43, 44, 71],
#              '37': [28, 38, 42],
#              '38': [37, 39, 42],
#              '39': [38, 40, 48],
#              '4': [6, 8],
#              '40': [22, 39, 41, 48],
#              '41': [29, 40, 49],
#              '42': [37, 38, 43, 45],
#              '43': [36, 42, 44, 45],
#              '44': [36, 43, 46, 54],
#              '45': [42, 43, 46, 47],
#              '46': [44, 45, 47, 54],
#              '47': [45, 46, 48, 74],
#              '48': [39, 40, 47, 49, 51, 52, 53, 54, 74],
#              '49': [29, 41, 48, 50, 73],
#              '5': [10, 11],
#              '50': [49, 51, 73],
#              '51': [48, 50, 52],
#              '52': [48, 51, 53],
#              '53': [48, 52, 54],
#              '54': [44, 46, 48, 53],
#              '55': [57],
#              '56': [57],
#              '57': [55, 56, 58, 59],
#              '58': [20, 57, 59],
#              '59': [57, 58, 60, 72],
#              '6': [3, 4, 8, 13, 17],
#              '60': [30, 31, 32, 34, 59, 61, 63, 65, 67, 69, 71, 72],
#              '61': [60],
#              '62': [63],
#              '63': [60, 62, 65],
#              '64': [65],
#              '65': [60, 63, 64, 66],
#              '66': [65],
#              '67': [60, 68, 69],
#              '68': [67],
#              '69': [60, 67, 70, 71],
#              '7': [1, 3, 9, 13],
#              '70': [69],
#              '71': [35, 36, 60, 69],
#              '72': [59, 60],
#              '73': [49, 50],
#              '74': [47, 48],
#              '8': [4, 6, 11, 16],
#              '9': [1, 7, 12, 13]})

# %%
for i in node_neighbors_dict['1']:
    for j in node_neighbors_dict['6']:
        if j in node_neighbors_dict[str(i)]:
            print('1->%s->%s->6'%(i,j))
# Out:
# 1->7->3->6
# 1->7->13->6
# 1->9->13->6

# %%
OD_pair_label_dict_ = zload('../temp_files/OD_pair_label_dict__journal.pkz')
OD_pair_label_dict = zload('../temp_files/OD_pair_label_dict_journal.pkz')

# %%
od_pairs = OD_pair_label_dict_.values()

# %%
len(od_pairs)
# Out:
# 5402

# %%
with open('../temp_files/link_length_dict_journal.json', 'r') as json_file:
    link_length_dict = json.load(json_file)

# %%
link_length_dict
# Out:
# {u'0': 16.106816776132206,
#  u'1': 16.0571310848523,
#  u'10': 11.592971084625853,
#  u'100': 1.5696733948772232,
#  u'101': 1.5728465434794565,
#  u'102': 1.7921931243248002,
#  u'103': 1.545397171832275,
#  u'104': 2.382524537502082,
#  u'105': 2.3073150179731683,
#  u'106': 10.419637474239062,
#  u'107': 10.605611517111255,
#  u'108': 17.00667789124771,
#  u'109': 17.005567531531476,
#  u'11': 11.736038693223891,
#  u'110': 7.738237271080147,
#  u'111': 8.018881297358824,
#  u'112': 4.915496789928508,
#  u'113': 5.233681913815005,
#  u'114': 32.389346299632926,
#  u'115': 32.29912178266756,
#  u'116': 2.3217571453967474,
#  u'117': 2.266330384997213,
#  u'118': 7.996645946908461,
#  u'119': 8.006116830442075,
#  u'12': 3.509126600568283,
#  u'120': 4.247236648822414,
#  u'121': 4.232367939709893,
#  u'122': 6.729821226606654,
#  u'123': 6.734278378625871,
#  u'124': 4.981080208735738,
#  u'125': 4.952494030424852,
#  u'126': 1.8063791824496431,
#  u'127': 1.8885017904624508,
#  u'128': 5.513571423215228,
#  u'129': 5.443441332441691,
#  u'13': 3.509126600568283,
#  u'130': 4.95107287593183,
#  u'131': 4.890894307370019,
#  u'132': 9.33850861489713,
#  u'133': 9.213129333692125,
#  u'134': 10.077606455023595,
#  u'135': 14.807023608899685,
#  u'136': 6.58094478550051,
#  u'137': 6.854678791689908,
#  u'138': 3.665727763844527,
#  u'139': 3.666940974100353,
#  u'14': 6.269460973290362,
#  u'140': 8.551888911305294,
#  u'141': 8.474891543605422,
#  u'142': 8.148498440261513,
#  u'143': 7.709684470772214,
#  u'144': 7.348533101500685,
#  u'145': 7.33755088899544,
#  u'146': 3.1887183387192874,
#  u'147': 3.5295090326826957,
#  u'148': 7.634185601102102,
#  u'149': 7.710593954126597,
#  u'15': 6.412615007790549,
#  u'150': 3.1676684588046005,
#  u'151': 3.1037931271030206,
#  u'152': 6.153280159332355,
#  u'153': 6.951620719172372,
#  u'154': 1.2922793827309171,
#  u'155': 1.307138698549448,
#  u'156': 17.539958035464966,
#  u'157': 18.147037245956806,
#  u'158': 3.4865477048665956,
#  u'159': 3.2248665465213957,
#  u'16': 10.449604297996718,
#  u'160': 21.899349962468754,
#  u'161': 21.94744534860476,
#  u'162': 32.81990122339988,
#  u'163': 32.9246898029873,
#  u'164': 3.965880109114513,
#  u'165': 3.9711681253404634,
#  u'166': 6.06271854085921,
#  u'167': 6.25613103617367,
#  u'168': 3.491124610265934,
#  u'169': 3.5644758648597032,
#  u'17': 10.554493738448745,
#  u'170': 4.080103419181262,
#  u'171': 4.1413565089324536,
#  u'172': 3.2435085141145907,
#  u'173': 3.245762352246047,
#  u'174': 10.076887518256967,
#  u'175': 10.014429655353144,
#  u'176': 1.8894851551628444,
#  u'177': 1.9608573712479724,
#  u'178': 3.422107295358311,
#  u'179': 3.687148275091586,
#  u'18': 11.677804833484773,
#  u'180': 2.8600268376953015,
#  u'181': 2.8705604149549857,
#  u'182': 11.279297626695469,
#  u'183': 11.207469048728864,
#  u'184': 10.530470370465926,
#  u'185': 10.299169231892144,
#  u'186': 5.726137263076658,
#  u'187': 5.749451819524412,
#  u'188': 14.622121867102532,
#  u'189': 14.619950366402357,
#  u'19': 11.588227883418346,
#  u'190': 29.323020962557305,
#  u'191': 29.502821751201953,
#  u'192': 16.882699546358918,
#  u'193': 17.00857691433406,
#  u'194': 14.062638535550418,
#  u'195': 14.187330222588075,
#  u'196': 15.006139868358241,
#  u'197': 15.0838831742159,
#  u'198': 8.050590955395883,
#  u'199': 7.02598525107882,
#  u'2': 16.05873959325414,
#  u'20': 2.9598793253562294,
#  u'200': 13.039071832031006,
#  u'201': 13.189106086995176,
#  u'202': 8.533461086604408,
#  u'203': 8.539431940820199,
#  u'204': 15.449374097479238,
#  u'205': 16.020354087312494,
#  u'206': 8.473071773791418,
#  u'207': 8.473071773791418,
#  u'208': 14.949056707342207,
#  u'209': 14.93107074934216,
#  u'21': 2.6474081350775083,
#  u'210': 8.710908321724583,
#  u'211': 8.79125236081523,
#  u'212': 13.929966298450532,
#  u'213': 13.938592714275844,
#  u'214': 9.342478356225582,
#  u'215': 9.139465171566961,
#  u'216': 10.255872289680426,
#  u'217': 10.442468675148076,
#  u'218': 10.35896488381876,
#  u'219': 10.189567567019285,
#  u'22': 11.650116069123403,
#  u'220': 11.360159540684432,
#  u'221': 11.354891312700241,
#  u'222': 9.144294117537308,
#  u'223': 9.303474724445564,
#  u'224': 8.141116494849232,
#  u'225': 8.495865089008287,
#  u'226': 3.1132818057899,
#  u'227': 3.106375119580356,
#  u'228': 24.836978550057342,
#  u'229': 24.834966122473165,
#  u'23': 11.52261277140617,
#  u'230': 9.667444388047759,
#  u'231': 9.769816963660839,
#  u'232': 11.630475901297695,
#  u'233': 11.588988156239735,
#  u'234': 8.630658049113515,
#  u'235': 8.971461184940694,
#  u'236': 12.15780756485551,
#  u'237': 11.78968164578674,
#  u'238': 12.851940714738113,
#  u'239': 12.851940714738113,
#  u'24': 12.288557352370397,
#  u'240': 4.619146629694611,
#  u'241': 4.619146629694612,
#  u'242': 3.711356711363819,
#  u'243': 4.075201302752909,
#  u'244': 1.377317140397602,
#  u'245': 1.5122405042158162,
#  u'246': 3.2540474653927722,
#  u'247': 3.0778455954044426,
#  u'248': 6.352585110246855,
#  u'249': 6.913755830997218,
#  u'25': 12.326099188881543,
#  u'250': 2.647231401275409,
#  u'251': 2.867756518243679,
#  u'252': 11.765241519380718,
#  u'253': 11.76524151938072,
#  u'254': 5.334022101781262,
#  u'255': 5.893052485601581,
#  u'256': 8.99212380041901,
#  u'257': 8.985698553901845,
#  u'26': 4.074787945611246,
#  u'27': 4.074787945611246,
#  u'28': 6.485867780901202,
#  u'29': 6.868068220581124,
#  u'3': 15.865262888535515,
#  u'30': 5.919129198637823,
#  u'31': 5.949185706987245,
#  u'32': 12.635123628334222,
#  u'33': 12.545210344262669,
#  u'34': 5.229189442670594,
#  u'35': 5.395143248813242,
#  u'36': 2.9878294267241485,
#  u'37': 3.0363192873675278,
#  u'38': 1.8394670197689555,
#  u'39': 1.8042637065726894,
#  u'4': 17.45540071364456,
#  u'40': 10.528473866268591,
#  u'41': 10.484210894531167,
#  u'42': 11.754734628849423,
#  u'43': 11.782102622350303,
#  u'44': 12.511216004386194,
#  u'45': 12.212523357818304,
#  u'46': 8.285083413897453,
#  u'47': 7.5254129722949505,
#  u'48': 8.419361594011644,
#  u'49': 8.467006915248277,
#  u'5': 17.450098686512977,
#  u'50': 6.761203486814544,
#  u'51': 6.898849467081714,
#  u'52': 8.568055867803777,
#  u'53': 8.369572202736173,
#  u'54': 1.3497965538563128,
#  u'55': 1.3578419819538736,
#  u'56': 4.5827194135406,
#  u'57': 4.45251754235305,
#  u'58': 3.367287655687359,
#  u'59': 3.4291045722582214,
#  u'6': 3.874724530269769,
#  u'60': 5.321009354750141,
#  u'61': 5.315024551038685,
#  u'62': 2.349795721082121,
#  u'63': 3.54877076575886,
#  u'64': 5.45357321347981,
#  u'65': 5.457315958100921,
#  u'66': 5.818844268378241,
#  u'67': 5.791541992302648,
#  u'68': 16.46181693853618,
#  u'69': 15.442909121257038,
#  u'7': 3.9751211916735767,
#  u'70': 13.283224601182997,
#  u'71': 13.295709830800595,
#  u'72': 12.263937698311064,
#  u'73': 12.556028037175837,
#  u'74': 6.798868686026321,
#  u'75': 6.721773229487106,
#  u'76': 4.525774863609242,
#  u'77': 4.543420712189323,
#  u'78': 4.583763012769106,
#  u'79': 4.508857627340593,
#  u'8': 7.587822021450257,
#  u'80': 8.906272983117788,
#  u'81': 8.306623730212383,
#  u'82': 8.608118984864001,
#  u'83': 8.599900076007556,
#  u'84': 5.869561058374282,
#  u'85': 5.650088591209094,
#  u'86': 12.222220073668307,
#  u'87': 11.916417537932704,
#  u'88': 2.436259813782731,
#  u'89': 2.4039018496686513,
#  u'9': 7.4474498019926925,
#  u'90': 16.652993350514965,
#  u'91': 16.79991994921688,
#  u'92': 1.687603841599184,
#  u'93': 1.6784612543785689,
#  u'94': 1.6458649031812804,
#  u'95': 1.061605480190827,
#  u'96': 11.986122156591701,
#  u'97': 11.945303335792971,
#  u'98': 1.9283197482446497,
#  u'99': 1.812974401600048}

# %%
link_label_dict = zload('../temp_files/link_label_dict_journal.pkz')
link_label_dict_ = zload('../temp_files/link_label_dict_journal_.pkz')

# %%
# compute length of a route
def routeLength(route):
    link_list = []
    node_list = []
    for i in route.split('->'):
        node_list.append(int(i))
    for i in range(len(node_list))[:-1]:
        link_list.append('%d->%d' %(node_list[i], node_list[i+1]))
    length_of_route = sum([link_length_dict[str(link_label_dict_[link])] for link in link_list])
    return length_of_route

# %%
with open('../temp_files/path_link_incidence_journal.txt', 'w') as the_file:
    for od in od_pairs:
        origi = od[0]
        desti = od[1]
        the_file.write('O-D pair (%s, %s):\n'%(origi, desti))
        route_list = []
        if desti in node_neighbors_dict[str(origi)]:
            route_list.append('%s->%s\n'%(origi,desti))
        for i in node_neighbors_dict[str(origi)]:
            if i in node_neighbors_dict[str(desti)]:
                flag = [origi, i, desti]
                if len(set(flag)) == len(flag):
                    route_list.append('%s->%s->%s\n'%(origi,i,desti))
            for j in node_neighbors_dict[str(i)]:
                if j in node_neighbors_dict[str(desti)]:
                    flag = [origi, i, j, desti]
                    if len(set(flag)) == len(flag):
                        route_list.append('%s->%s->%s->%s\n'%(origi,i,j,desti))
                for k in node_neighbors_dict[str(j)]:
                    if k in node_neighbors_dict[str(desti)]:
                        flag = [origi, i, j, k, desti]
                        if len(set(flag)) == len(flag):
                            route_list.append('%s->%s->%s->%s->%s\n'%(origi,i,j,k,desti))
                    for l in node_neighbors_dict[str(k)]:
                        if l in node_neighbors_dict[str(desti)]:
                            flag = [origi, i, j, k, l, desti]
                            if len(set(flag)) == len(flag):
                                route_list.append('%s->%s->%s->%s->%s->%s\n'%(origi,i,j,k,l,desti))    
                        for m in node_neighbors_dict[str(l)]:
                            if m in node_neighbors_dict[str(desti)]:
                                flag = [origi, i, j, k, l, m, desti]
                                if len(set(flag)) == len(flag):
                                    route_list.append('%s->%s->%s->%s->%s->%s->%s\n'%(origi,i,j,k,l,m,desti))  
                            for n in node_neighbors_dict[str(m)]:
                                if n in node_neighbors_dict[str(desti)]:
                                    flag = [origi, i, j, k, l, m, n, desti]
                                    if len(set(flag)) == len(flag):
                                        route_list.append('%s->%s->%s->%s->%s->%s->%s->%s\n'%(origi,i,j,k,l,m,n,desti))
                                for o in node_neighbors_dict[str(n)]:
                                    if o in node_neighbors_dict[str(desti)]:
                                        flag = [origi, i, j, k, l, m, n, o, desti]
                                        if len(set(flag)) == len(flag):
                                            route_list.append('%s->%s->%s->%s->%s->%s->%s->%s->%s\n'%(origi,i,j,k,l,m,n,o,desti))
                                    for p in node_neighbors_dict[str(o)]:
                                        if p in node_neighbors_dict[str(desti)]:
                                            flag = [origi, i, j, k, l, m, n, o, p, desti]
                                            if len(set(flag)) == len(flag):
                                                route_list.append('%s->%s->%s->%s->%s->%s->%s->%s->%s->%s\n'%(origi,i,j,k,l,m,n,o,p,desti))
                                                for q in node_neighbors_dict[str(p)]:
                                                    if q in node_neighbors_dict[str(desti)]:
                                                        flag = [origi, i, j, k, l, m, n, o, p, q, desti]
                                                        if len(set(flag)) == len(flag):
                                                            route_list.append('%s->%s->%s->%s->%s->%s->%s->%s->%s->%s->%s\n'%(origi,i,j,k,l,m,n,o,p,q,desti))
       
        route_length_list = np.array([routeLength(route) for route in route_list])
    
        refined_route_list = []
        
        number_of_routes_per_OD_pair = 5
        if len(route_list) <= number_of_routes_per_OD_pair:
            refined_route_list = route_list
        else:
            refined_idx_list = [np.argsort(route_length_list)[i] for i in range(number_of_routes_per_OD_pair)]
            refined_route_list = [route_list[idx] for idx in refined_idx_list]
                
        for route in refined_route_list:
            the_file.write(route)
        the_file.write('\n')

# %%
with open('../temp_files/path_link_incidence_journal.txt', 'r') as the_file:
    # path counts
    i = 0  
    for row in the_file:
        if '->' in row:
            i = i + 1

# %%
i
# Out:
# 26690

# %%
link_label_dict_ = zload('../temp_files/link_label_dict_journal_.pkz')

# %%
od_nodes_dict = zload('../temp_files/od_nodes_dict_journal.pkz')

# %%
od_nodes_dict
# Out:
# {0: {1},
#  1: {2, 4, 5},
#  2: {3},
#  3: {6, 8},
#  4: {7, 9},
#  5: {10, 11},
#  6: {12, 15},
#  7: {13, 14},
#  8: {16, 17, 18, 19},
#  9: {20},
#  10: {21},
#  11: {22},
#  12: {23, 24, 25, 26, 27, 28},
#  13: {29},
#  14: {30, 31, 32, 33, 34},
#  15: {35, 71},
#  16: {36},
#  17: {37, 38, 39, 40, 41},
#  18: {42},
#  19: {43, 44, 45, 46, 47},
#  20: {48, 74},
#  21: {49, 73},
#  22: {50, 51},
#  23: {52},
#  24: {53},
#  25: {54, 68, 70},
#  26: {55, 56},
#  27: {57},
#  28: {58},
#  29: {59, 60, 72},
#  30: {61},
#  31: {62, 63, 64, 65, 66},
#  32: {67},
#  33: {69}}

# %%
node_to_OD_dict = {}

for key in od_nodes_dict.keys():
    for value in od_nodes_dict[key]:
        node_to_OD_dict[value] = key

# %%
node_to_OD_dict
# Out:
# {1: 0,
#  2: 1,
#  3: 2,
#  4: 1,
#  5: 1,
#  6: 3,
#  7: 4,
#  8: 3,
#  9: 4,
#  10: 5,
#  11: 5,
#  12: 6,
#  13: 7,
#  14: 7,
#  15: 6,
#  16: 8,
#  17: 8,
#  18: 8,
#  19: 8,
#  20: 9,
#  21: 10,
#  22: 11,
#  23: 12,
#  24: 12,
#  25: 12,
#  26: 12,
#  27: 12,
#  28: 12,
#  29: 13,
#  30: 14,
#  31: 14,
#  32: 14,
#  33: 14,
#  34: 14,
#  35: 15,
#  36: 16,
#  37: 17,
#  38: 17,
#  39: 17,
#  40: 17,
#  41: 17,
#  42: 18,
#  43: 19,
#  44: 19,
#  45: 19,
#  46: 19,
#  47: 19,
#  48: 20,
#  49: 21,
#  50: 22,
#  51: 22,
#  52: 23,
#  53: 24,
#  54: 25,
#  55: 26,
#  56: 26,
#  57: 27,
#  58: 28,
#  59: 29,
#  60: 29,
#  61: 30,
#  62: 31,
#  63: 31,
#  64: 31,
#  65: 31,
#  66: 31,
#  67: 32,
#  68: 25,
#  69: 33,
#  70: 25,
#  71: 15,
#  72: 29,
#  73: 21,
#  74: 20}

# %%
# build a dictionary containing route information that is easy to tackle

route_dict = {}
with open('../temp_files/path_link_incidence_journal.txt', 'r') as the_file:
    idx = 0
    for row in the_file:
        if '->' in row:
            link_list = []
            link_idx_list = []
            node_list = []
            for i in row.split('->'):
                node_list.append(int(i))
            for i in range(len(node_list))[:-1]:
                link_list.append('%d->%d' %(node_list[i], node_list[i+1]))
                link_idx_list.append(link_label_dict_[str(node_list[i]) + '->' + str(node_list[i+1])])
            length_of_route = sum([link_length_dict[str(link_label_dict_[link])] \
                                  for link in link_list])
            route_dict[idx] = {'node_list': node_list, 'origi': node_to_OD_dict[node_list[0]], \
                               'desti': node_to_OD_dict[node_list[-1]], 'link_idx_list': link_idx_list, \
                               'length_of_route': length_of_route}
            idx += 1
            
with open('../temp_files/route_dict_journal.json', 'w') as json_file:
    json.dump(route_dict, json_file)

# %%
route_dict
# Out:
# {0: {'desti': 17,
#   'length_of_route': 17.697817325312034,
#   'link_idx_list': [89, 79, 84, 112],
#   'node_list': [24, 23, 22, 29, 41],
#   'origi': 12},
#  1: {'desti': 17,
#   'length_of_route': 20.779285420114356,
#   'link_idx_list': [92, 81, 84, 112],
#   'node_list': [24, 25, 22, 29, 41],
#   'origi': 12},
#  2: {'desti': 17,
#   'length_of_route': 22.311509183707628,
#   'link_idx_list': [94, 102, 110, 146, 150, 154, 158],
#   'node_list': [24, 26, 28, 37, 38, 39, 40, 41],
#   'origi': 12},
#  3: {'desti': 17,
#   'length_of_route': 22.550520883296503,
#   'link_idx_list': [94, 99, 81, 84, 112],
#   'node_list': [24, 26, 25, 22, 29, 41],
#   'origi': 12},
#  4: {'desti': 17,
#   'length_of_route': 22.621527255544144,
#   'link_idx_list': [89, 79, 86, 158],
#   'node_list': [24, 23, 22, 40, 41],
#   'origi': 12},
#  5: {'desti': 19,
#   'length_of_route': 24.621620715887495,
#   'link_idx_list': [102, 110, 148, 164, 168],
#   'node_list': [26, 28, 37, 42, 43, 44],
#   'origi': 12},
#  6: {'desti': 19,
#   'length_of_route': 26.329433612837036,
#   'link_idx_list': [102, 110, 146, 152, 164, 168],
#   'node_list': [26, 28, 37, 38, 42, 43, 44],
#   'origi': 12},
#  7: {'desti': 19,
#   'length_of_route': 26.781625523942,
#   'link_idx_list': [100, 104, 110, 148, 164, 168],
#   'node_list': [26, 27, 28, 37, 42, 43, 44],
#   'origi': 12},
#  8: {'desti': 19,
#   'length_of_route': 28.362582044775152,
#   'link_idx_list': [102, 110, 148, 166, 176, 173],
#   'node_list': [26, 28, 37, 42, 45, 46, 44],
#   'origi': 12},
#  9: {'desti': 19,
#   'length_of_route': 28.48943842089154,
#   'link_idx_list': [100, 104, 110, 146, 152, 164, 168],
#   'node_list': [26, 27, 28, 37, 38, 42, 43, 44],
#   'origi': 12},
#  10: {'desti': 5,
#   'length_of_route': 23.38945072212437,
#   'link_idx_list': [36, 23, 20, 30],
#   'node_list': [9, 13, 6, 8, 11],
#   'origi': 4},
#  11: {'desti': 5,
#   'length_of_route': 30.208158970626783,
#   'link_idx_list': [36, 23, 13, 14, 30],
#   'node_list': [9, 13, 6, 4, 8, 11],
#   'origi': 4},
#  12: {'desti': 5,
#   'length_of_route': 30.96227702191267,
#   'link_idx_list': [27, 28, 23, 20, 30],
#   'node_list': [9, 7, 13, 6, 8, 11],
#   'origi': 4},
#  13: {'desti': 5,
#   'length_of_route': 32.27765718427945,
#   'link_idx_list': [27, 11, 8, 20, 30],
#   'node_list': [9, 7, 3, 6, 8, 11],
#   'origi': 4},
#  14: {'desti': 5,
#   'length_of_route': 36.18720108074893,
#   'link_idx_list': [36, 46, 50, 55, 56, 45],
#   'node_list': [9, 13, 14, 17, 16, 19, 11],
#   'origi': 4},
#  15: {'desti': 31,
#   'length_of_route': 36.93566363665298,
#   'link_idx_list': [105, 106, 125, 128, 230, 243],
#   'node_list': [28, 27, 33, 32, 60, 63, 62],
#   'origi': 12},
#  16: {'desti': 31,
#   'length_of_route': 37.74341918538931,
#   'link_idx_list': [103, 100, 106, 125, 128, 230, 243],
#   'node_list': [28, 26, 27, 33, 32, 60, 63, 62],
#   'origi': 12},
#  17: {'desti': 31,
#   'length_of_route': 38.80183595305555,
#   'link_idx_list': [103, 95, 96, 125, 128, 230, 243],
#   'node_list': [28, 26, 24, 33, 32, 60, 63, 62],
#   'origi': 12},
#  18: {'desti': 31,
#   'length_of_route': 38.82274427262241,
#   'link_idx_list': [105, 106, 130, 127, 128, 230, 243],
#   'node_list': [28, 27, 33, 34, 32, 60, 63, 62],
#   'origi': 12},
#  19: {'desti': 31,
#   'length_of_route': 39.63049982135874,
#   'link_idx_list': [103, 100, 106, 130, 127, 128, 230, 243],
#   'node_list': [28, 26, 27, 33, 34, 32, 60, 63, 62],
#   'origi': 12},
#  20: {'desti': 14,
#   'length_of_route': 28.682347496716602,
#   'link_idx_list': [55, 58, 78, 88, 96, 130],
#   'node_list': [17, 16, 22, 23, 24, 33, 34],
#   'origi': 8},
#  21: {'desti': 14,
#   'length_of_route': 29.27822721382551,
#   'link_idx_list': [60, 78, 88, 96, 130],
#   'node_list': [17, 22, 23, 24, 33, 34],
#   'origi': 8},
#  22: {'desti': 14,
#   'length_of_route': 30.331401112422462,
#   'link_idx_list': [55, 58, 78, 88, 94, 100, 106, 130],
#   'node_list': [17, 16, 22, 23, 24, 26, 27, 33, 34],
#   'origi': 8},
#  23: {'desti': 14,
#   'length_of_route': 30.490147833659268,
#   'link_idx_list': [55, 58, 78, 88, 96, 125, 126],
#   'node_list': [17, 16, 22, 23, 24, 33, 32, 34],
#   'origi': 8},
#  24: {'desti': 14,
#   'length_of_route': 30.92728082953137,
#   'link_idx_list': [60, 78, 88, 94, 100, 106, 130],
#   'node_list': [17, 22, 23, 24, 26, 27, 33, 34],
#   'origi': 8},
#  25: {'desti': 19,
#   'length_of_route': 21.13049610562156,
#   'link_idx_list': [102, 110, 148, 164],
#   'node_list': [26, 28, 37, 42, 43],
#   'origi': 12},
#  26: {'desti': 19,
#   'length_of_route': 22.8383090025711,
#   'link_idx_list': [102, 110, 146, 152, 164],
#   'node_list': [26, 28, 37, 38, 42, 43],
#   'origi': 12},
#  27: {'desti': 19,
#   'length_of_route': 23.290500913676066,
#   'link_idx_list': [100, 104, 110, 148, 164],
#   'node_list': [26, 27, 28, 37, 42, 43],
#   'origi': 12},
#  28: {'desti': 19,
#   'length_of_route': 24.998313810625604,
#   'link_idx_list': [100, 104, 110, 146, 152, 164],
#   'node_list': [26, 27, 28, 37, 38, 42, 43],
#   'origi': 12},
#  29: {'desti': 19,
#   'length_of_route': 27.368691046298714,
#   'link_idx_list': [102, 110, 148, 166, 171],
#   'node_list': [26, 28, 37, 42, 45, 43],
#   'origi': 12},
#  30: {'desti': 6,
#   'length_of_route': 80.59204474030676,
#   'link_idx_list': [216, 218, 73, 68, 74, 53, 47, 37, 34],
#   'node_list': [56, 57, 58, 20, 21, 22, 14, 13, 9, 12],
#   'origi': 26},
#  31: {'desti': 19,
#   'length_of_route': 25.116819692529106,
#   'link_idx_list': [102, 110, 148, 166, 176],
#   'node_list': [26, 28, 37, 42, 45, 46],
#   'origi': 12},
#  32: {'desti': 19,
#   'length_of_route': 26.824632589478647,
#   'link_idx_list': [102, 110, 146, 152, 166, 176],
#   'node_list': [26, 28, 37, 38, 42, 45, 46],
#   'origi': 12},
#  33: {'desti': 19,
#   'length_of_route': 27.10008467996567,
#   'link_idx_list': [102, 110, 148, 164, 170, 176],
#   'node_list': [26, 28, 37, 42, 43, 45, 46],
#   'origi': 12},
#  34: {'desti': 19,
#   'length_of_route': 27.276824500583608,
#   'link_idx_list': [100, 104, 110, 148, 166, 176],
#   'node_list': [26, 27, 28, 37, 42, 45, 46],
#   'origi': 12},
#  35: {'desti': 19,
#   'length_of_route': 27.865129230002086,
#   'link_idx_list': [102, 110, 148, 164, 168, 172],
#   'node_list': [26, 28, 37, 42, 43, 44, 46],
#   'origi': 12},
#  36: {'desti': 5,
#   'length_of_route': 44.952967833025326,
#   'link_idx_list': [216, 218, 73, 43],
#   'node_list': [56, 57, 58, 20, 10],
#   'origi': 26},
#  37: {'desti': 5,
#   'length_of_route': 55.25763721433656,
#   'link_idx_list': [216, 220, 223, 73, 43],
#   'node_list': [56, 57, 59, 58, 20, 10],
#   'origi': 26},
#  38: {'desti': 5,
#   'length_of_route': 62.43238954944234,
#   'link_idx_list': [216, 220, 226, 241, 119, 71, 43],
#   'node_list': [56, 57, 59, 72, 60, 30, 20, 10],
#   'origi': 26},
#  39: {'desti': 5,
#   'length_of_route': 62.84107760880706,
#   'link_idx_list': [216, 220, 224, 119, 71, 43],
#   'node_list': [56, 57, 59, 60, 30, 20, 10],
#   'origi': 26},
#  40: {'desti': 5,
#   'length_of_route': 63.42688148262335,
#   'link_idx_list': [216, 220, 226, 241, 123, 117, 71, 43],
#   'node_list': [56, 57, 59, 72, 60, 31, 30, 20, 10],
#   'origi': 26},
#  41: {'desti': 5,
#   'length_of_route': 46.79243485279428,
#   'link_idx_list': [216, 218, 73, 43, 38],
#   'node_list': [56, 57, 58, 20, 10, 11],
#   'origi': 26},
#  42: {'desti': 5,
#   'length_of_route': 57.097104234105515,
#   'link_idx_list': [216, 220, 223, 73, 43, 38],
#   'node_list': [56, 57, 59, 58, 20, 10, 11],
#   'origi': 26},
#  43: {'desti': 5,
#   'length_of_route': 64.2718565692113,
#   'link_idx_list': [216, 220, 226, 241, 119, 71, 43, 38],
#   'node_list': [56, 57, 59, 72, 60, 30, 20, 10, 11],
#   'origi': 26},
#  44: {'desti': 5,
#   'length_of_route': 64.68054462857602,
#   'link_idx_list': [216, 220, 224, 119, 71, 43, 38],
#   'node_list': [56, 57, 59, 60, 30, 20, 10, 11],
#   'origi': 26},
#  45: {'desti': 5,
#   'length_of_route': 65.2663485023923,
#   'link_idx_list': [216, 220, 226, 241, 123, 117, 71, 43, 38],
#   'node_list': [56, 57, 59, 72, 60, 31, 30, 20, 10, 11],
#   'origi': 26},
#  46: {'desti': 3,
#   'length_of_route': 52.74162055978152,
#   'link_idx_list': [216, 218, 73, 43, 38, 31],
#   'node_list': [56, 57, 58, 20, 10, 11, 8],
#   'origi': 26},
#  47: {'desti': 3,
#   'length_of_route': 63.04628994109276,
#   'link_idx_list': [216, 220, 223, 73, 43, 38, 31],
#   'node_list': [56, 57, 59, 58, 20, 10, 11, 8],
#   'origi': 26},
#  48: {'desti': 3,
#   'length_of_route': 70.22104227619855,
#   'link_idx_list': [216, 220, 226, 241, 119, 71, 43, 38, 31],
#   'node_list': [56, 57, 59, 72, 60, 30, 20, 10, 11, 8],
#   'origi': 26},
#  49: {'desti': 3,
#   'length_of_route': 70.62973033556327,
#   'link_idx_list': [216, 220, 224, 119, 71, 43, 38, 31],
#   'node_list': [56, 57, 59, 60, 30, 20, 10, 11, 8],
#   'origi': 26},
#  50: {'desti': 3,
#   'length_of_route': 71.62422226874428,
#   'link_idx_list': [216, 220, 224, 123, 117, 71, 43, 38, 31],
#   'node_list': [56, 57, 59, 60, 31, 30, 20, 10, 11, 8],
#   'origi': 26},
#  51: {'desti': 4,
#   'length_of_route': 70.07546405134997,
#   'link_idx_list': [216, 218, 73, 43, 38, 31, 21, 22, 37],
#   'node_list': [56, 57, 58, 20, 10, 11, 8, 6, 13, 9],
#   'origi': 26},
#  52: {'desti': 4,
#   'length_of_route': 75.36285529763617,
#   'link_idx_list': [216, 218, 73, 68, 74, 53, 47, 37],
#   'node_list': [56, 57, 58, 20, 21, 22, 14, 13, 9],
#   'origi': 26},
#  53: {'desti': 4,
#   'length_of_route': 76.73150874279608,
#   'link_idx_list': [216, 220, 224, 123, 91, 79, 53, 47, 37],
#   'node_list': [56, 57, 59, 60, 31, 23, 22, 14, 13, 9],
#   'origi': 26},
#  54: {'desti': 4,
#   'length_of_route': 77.5986191025597,
#   'link_idx_list': [216, 218, 73, 68, 76, 79, 53, 47, 37],
#   'node_list': [56, 57, 58, 20, 21, 23, 22, 14, 13, 9],
#   'origi': 26},
#  55: {'desti': 4,
#   'length_of_route': 77.9820009301748,
#   'link_idx_list': [216, 218, 73, 43, 38, 31, 21, 22, 29, 26],
#   'node_list': [56, 57, 58, 20, 10, 11, 8, 6, 13, 7, 9],
#   'origi': 26},
#  56: {'desti': 3,
#   'length_of_route': 55.38902869485903,
#   'link_idx_list': [216, 218, 73, 43, 38, 31, 21],
#   'node_list': [56, 57, 58, 20, 10, 11, 8, 6],
#   'origi': 26},
#  57: {'desti': 3,
#   'length_of_route': 62.66336216814035,
#   'link_idx_list': [216, 218, 73, 43, 38, 31, 15, 12],
#   'node_list': [56, 57, 58, 20, 10, 11, 8, 4, 6],
#   'origi': 26},
#  58: {'desti': 3,
#   'length_of_route': 65.69369807617026,
#   'link_idx_list': [216, 220, 223, 73, 43, 38, 31, 21],
#   'node_list': [56, 57, 59, 58, 20, 10, 11, 8, 6],
#   'origi': 26},
#  59: {'desti': 3,
#   'length_of_route': 72.9680315494516,
#   'link_idx_list': [216, 220, 223, 73, 43, 38, 31, 15, 12],
#   'node_list': [56, 57, 59, 58, 20, 10, 11, 8, 4, 6],
#   'origi': 26},
#  60: {'desti': 3,
#   'length_of_route': 73.27713847064078,
#   'link_idx_list': [216, 220, 224, 119, 71, 43, 38, 31, 21],
#   'node_list': [56, 57, 59, 60, 30, 20, 10, 11, 8, 6],
#   'origi': 26},
#  61: {'desti': 4,
#   'length_of_route': 73.90721298456356,
#   'link_idx_list': [216, 218, 73, 43, 38, 31, 21, 22, 29],
#   'node_list': [56, 57, 58, 20, 10, 11, 8, 6, 13, 7],
#   'origi': 26},
#  62: {'desti': 4,
#   'length_of_route': 74.15025199696122,
#   'link_idx_list': [216, 218, 73, 43, 38, 31, 21, 22, 37, 27],
#   'node_list': [56, 57, 58, 20, 10, 11, 8, 6, 13, 9, 7],
#   'origi': 26},
#  63: {'desti': 4,
#   'length_of_route': 74.42944958147757,
#   'link_idx_list': [216, 218, 73, 43, 38, 31, 21, 9, 10],
#   'node_list': [56, 57, 58, 20, 10, 11, 8, 6, 3, 7],
#   'origi': 26},
#  64: {'desti': 4,
#   'length_of_route': 79.19460423084976,
#   'link_idx_list': [216, 218, 73, 68, 74, 53, 47, 29],
#   'node_list': [56, 57, 58, 20, 21, 22, 14, 13, 7],
#   'origi': 26},
#  65: {'desti': 4,
#   'length_of_route': 79.43764324324742,
#   'link_idx_list': [216, 218, 73, 68, 74, 53, 47, 37, 27],
#   'node_list': [56, 57, 58, 20, 21, 22, 14, 13, 9, 7],
#   'origi': 26},
#  66: {'desti': 30,
#   'length_of_route': 72.64452484837345,
#   'link_idx_list': [36, 46, 52, 78, 90, 122, 228],
#   'node_list': [9, 13, 14, 22, 23, 31, 60, 61],
#   'origi': 4},
#  67: {'desti': 30,
#   'length_of_route': 74.15015769526633,
#   'link_idx_list': [36, 46, 52, 78, 88, 96, 125, 128, 228],
#   'node_list': [9, 13, 14, 22, 23, 24, 33, 32, 60, 61],
#   'origi': 4},
#  68: {'desti': 30,
#   'length_of_route': 75.56280210502545,
#   'link_idx_list': [36, 46, 50, 55, 58, 78, 90, 122, 228],
#   'node_list': [9, 13, 14, 17, 16, 22, 23, 31, 60, 61],
#   'origi': 4},
#  69: {'desti': 30,
#   'length_of_route': 75.67551169380444,
#   'link_idx_list': [36, 46, 52, 78, 90, 120, 128, 228],
#   'node_list': [9, 13, 14, 22, 23, 31, 32, 60, 61],
#   'origi': 4},
#  70: {'desti': 30,
#   'length_of_route': 76.15868182213435,
#   'link_idx_list': [36, 46, 50, 60, 78, 90, 122, 228],
#   'node_list': [9, 13, 14, 17, 22, 23, 31, 60, 61],
#   'origi': 4},
#  71: {'desti': 7,
#   'length_of_route': 64.8011230379737,
#   'link_idx_list': [216, 218, 73, 68, 74, 53],
#   'node_list': [56, 57, 58, 20, 21, 22, 14],
#   'origi': 26},
#  72: {'desti': 7,
#   'length_of_route': 65.76108842376888,
#   'link_idx_list': [216, 220, 226, 241, 123, 91, 79, 53],
#   'node_list': [56, 57, 59, 72, 60, 31, 23, 22, 14],
#   'origi': 26},
#  73: {'desti': 7,
#   'length_of_route': 66.1697764831336,
#   'link_idx_list': [216, 220, 224, 123, 91, 79, 53],
#   'node_list': [56, 57, 59, 60, 31, 23, 22, 14],
#   'origi': 26},
#  74: {'desti': 7,
#   'length_of_route': 67.03688684289722,
#   'link_idx_list': [216, 218, 73, 68, 76, 79, 53],
#   'node_list': [56, 57, 58, 20, 21, 23, 22, 14],
#   'origi': 26},
#  75: {'desti': 7,
#   'length_of_route': 67.4093048819299,
#   'link_idx_list': [216, 220, 224, 129, 124, 97, 89, 79, 53],
#   'node_list': [56, 57, 59, 60, 32, 33, 24, 23, 22, 14],
#   'origi': 26},
#  76: {'desti': 6,
#   'length_of_route': 75.45850635799408,
#   'link_idx_list': [216, 218, 73, 43, 38, 31, 21, 22, 48],
#   'node_list': [56, 57, 58, 20, 10, 11, 8, 6, 13, 15],
#   'origi': 26},
#  77: {'desti': 6,
#   'length_of_route': 80.74589760428029,
#   'link_idx_list': [216, 218, 73, 68, 74, 53, 47, 48],
#   'node_list': [56, 57, 58, 20, 21, 22, 14, 13, 15],
#   'origi': 26},
#  78: {'desti': 6,
#   'length_of_route': 82.1145510494402,
#   'link_idx_list': [216, 220, 224, 123, 91, 79, 53, 47, 48],
#   'node_list': [56, 57, 59, 60, 31, 23, 22, 14, 13, 15],
#   'origi': 26},
#  79: {'desti': 6,
#   'length_of_route': 82.98166140920381,
#   'link_idx_list': [216, 218, 73, 68, 76, 79, 53, 47, 48],
#   'node_list': [56, 57, 58, 20, 21, 23, 22, 14, 13, 15],
#   'origi': 26},
#  80: {'desti': 6,
#   'length_of_route': 84.59019941966451,
#   'link_idx_list': [216, 218, 73, 68, 74, 61, 51, 47, 48],
#   'node_list': [56, 57, 58, 20, 21, 22, 17, 14, 13, 15],
#   'origi': 26},
#  81: {'desti': 5,
#   'length_of_route': 25.19371442869706,
#   'link_idx_list': [36, 23, 20, 30, 39],
#   'node_list': [9, 13, 6, 8, 11, 10],
#   'origi': 4},
#  82: {'desti': 5,
#   'length_of_route': 32.012422677199474,
#   'link_idx_list': [36, 23, 13, 14, 30, 39],
#   'node_list': [9, 13, 6, 4, 8, 11, 10],
#   'origi': 4},
#  83: {'desti': 5,
#   'length_of_route': 32.76654072848536,
#   'link_idx_list': [27, 28, 23, 20, 30, 39],
#   'node_list': [9, 7, 13, 6, 8, 11, 10],
#   'origi': 4},
#  84: {'desti': 5,
#   'length_of_route': 34.08192089085214,
#   'link_idx_list': [27, 11, 8, 20, 30, 39],
#   'node_list': [9, 7, 3, 6, 8, 11, 10],
#   'origi': 4},
#  85: {'desti': 5,
#   'length_of_route': 37.99146478732162,
#   'link_idx_list': [36, 46, 50, 55, 56, 45, 39],
#   'node_list': [9, 13, 14, 17, 16, 19, 11, 10],
#   'origi': 4},
#  86: {'desti': 30,
#   'length_of_route': 48.02999649590966,
#   'link_idx_list': [105, 106, 125, 128, 228],
#   'node_list': [28, 27, 33, 32, 60, 61],
#   'origi': 12},
#  87: {'desti': 30,
#   'length_of_route': 48.83775204464598,
#   'link_idx_list': [103, 100, 106, 125, 128, 228],
#   'node_list': [28, 26, 27, 33, 32, 60, 61],
#   'origi': 12},
#  88: {'desti': 30,
#   'length_of_route': 49.896168812312226,
#   'link_idx_list': [103, 95, 96, 125, 128, 228],
#   'node_list': [28, 26, 24, 33, 32, 60, 61],
#   'origi': 12},
#  89: {'desti': 30,
#   'length_of_route': 49.91707713187908,
#   'link_idx_list': [105, 106, 130, 127, 128, 228],
#   'node_list': [28, 27, 33, 34, 32, 60, 61],
#   'origi': 12},
#  90: {'desti': 30,
#   'length_of_route': 50.724832680615414,
#   'link_idx_list': [103, 100, 106, 130, 127, 128, 228],
#   'node_list': [28, 26, 27, 33, 34, 32, 60, 61],
#   'origi': 12},
#  91: {'desti': 6,
#   'length_of_route': 11.407191020735793,
#   'link_idx_list': [36, 48],
#   'node_list': [9, 13, 15],
#   'origi': 4},
#  92: {'desti': 6,
#   'length_of_route': 18.98001732052409,
#   'link_idx_list': [27, 28, 48],
#   'node_list': [9, 7, 13, 15],
#   'origi': 4},
#  93: {'desti': 6,
#   'length_of_route': 43.46812632342045,
#   'link_idx_list': [27, 11, 8, 22, 48],
#   'node_list': [9, 7, 3, 6, 13, 15],
#   'origi': 4},
#  94: {'desti': 6,
#   'length_of_route': 48.41406765467997,
#   'link_idx_list': [5, 2, 28, 48],
#   'node_list': [9, 1, 7, 13, 15],
#   'origi': 4},
#  95: {'desti': 6,
#   'length_of_route': 58.5308300460441,
#   'link_idx_list': [27, 11, 8, 24, 51, 47, 48],
#   'node_list': [9, 7, 3, 6, 17, 14, 13, 15],
#   'origi': 4},
#  96: {'desti': 8,
#   'length_of_route': 12.701764882309018,
#   'link_idx_list': [50, 55, 56],
#   'node_list': [14, 17, 16, 19],
#   'origi': 7},
#  97: {'desti': 8,
#   'length_of_route': 14.359597860106424,
#   'link_idx_list': [52, 67],
#   'node_list': [14, 22, 19],
#   'origi': 7},
#  98: {'desti': 8,
#   'length_of_route': 16.5798798536026,
#   'link_idx_list': [52, 59, 56],
#   'node_list': [14, 22, 16, 19],
#   'origi': 7},
#  99: {'desti': 8,
#   'length_of_route': 17.277875116758423,
#   'link_idx_list': [50, 55, 58, 67],
#   'node_list': [14, 17, 16, 22, 19],
#   'origi': 7},
#  100: {'desti': 8,
#   'length_of_route': 17.873754833867334,
#   'link_idx_list': [50, 60, 67],
#   'node_list': [14, 17, 22, 19],
#   'origi': 7},
#  101: {'desti': 31,
#   'length_of_route': 22.910918061907445,
#   'link_idx_list': [128, 230, 244, 248],
#   'node_list': [32, 60, 63, 65, 66],
#   'origi': 14},
#  102: {'desti': 31,
#   'length_of_route': 23.496632434759775,
#   'link_idx_list': [128, 232, 248],
#   'node_list': [32, 60, 65, 66],
#   'origi': 14},
#  103: {'desti': 31,
#   'length_of_route': 28.35953580500876,
#   'link_idx_list': [121, 122, 230, 244, 248],
#   'node_list': [32, 31, 60, 63, 65, 66],
#   'origi': 14},
#  104: {'desti': 31,
#   'length_of_route': 28.945250177861098,
#   'link_idx_list': [121, 122, 232, 248],
#   'node_list': [32, 31, 60, 65, 66],
#   'origi': 14},
#  105: {'desti': 31,
#   'length_of_route': 29.28133227616545,
#   'link_idx_list': [126, 134, 230, 244, 248],
#   'node_list': [32, 34, 60, 63, 65, 66],
#   'origi': 14},
#  106: {'desti': 25,
#   'length_of_route': 71.52229920093288,
#   'link_idx_list': [18, 44, 66, 82, 110, 148, 164, 168, 174],
#   'node_list': [5, 11, 19, 22, 28, 37, 42, 43, 44, 54],
#   'origi': 1},
#  107: {'desti': 25,
#   'length_of_route': 73.21990828601298,
#   'link_idx_list': [18, 44, 66, 82, 110, 148, 166, 176, 182],
#   'node_list': [5, 11, 19, 22, 28, 37, 42, 45, 46, 54],
#   'origi': 1},
#  108: {'desti': 25,
#   'length_of_route': 75.22217482976664,
#   'link_idx_list': [16, 40, 62, 66, 86, 155, 156, 196],
#   'node_list': [5, 10, 18, 19, 22, 40, 39, 48, 54],
#   'origi': 1},
#  109: {'desti': 25,
#   'length_of_route': 75.26326052982053,
#   'link_idx_list': [18, 44, 66, 82, 110, 148, 166, 176, 173, 174],
#   'node_list': [5, 11, 19, 22, 28, 37, 42, 45, 46, 44, 54],
#   'origi': 1},
#  110: {'desti': 25,
#   'length_of_route': 75.96821782348596,
#   'link_idx_list': [18, 44, 66, 82, 110, 148, 164, 168, 172, 182],
#   'node_list': [5, 11, 19, 22, 28, 37, 42, 43, 44, 46, 54],
#   'origi': 1},
#  111: {'desti': 26,
#   'length_of_route': 53.797309363743445,
#   'link_idx_list': [16, 42, 72, 219, 215],
#   'node_list': [5, 10, 20, 58, 57, 55],
#   'origi': 1},
#  112: {'desti': 26,
#   'length_of_route': 56.8297736058042,
#   'link_idx_list': [18, 39, 42, 72, 219, 215],
#   'node_list': [5, 11, 10, 20, 58, 57, 55],
#   'origi': 1},
#  113: {'desti': 26,
#   'length_of_route': 64.10692722696172,
#   'link_idx_list': [16, 42, 72, 222, 221, 215],
#   'node_list': [5, 10, 20, 58, 59, 57, 55],
#   'origi': 1},
#  114: {'desti': 26,
#   'length_of_route': 67.13939146902246,
#   'link_idx_list': [18, 39, 42, 72, 222, 221, 215],
#   'node_list': [5, 11, 10, 20, 58, 59, 57, 55],
#   'origi': 1},
#  115: {'desti': 26,
#   'length_of_route': 71.70408770847976,
#   'link_idx_list': [16, 42, 70, 118, 240, 227, 221, 215],
#   'node_list': [5, 10, 20, 30, 60, 72, 59, 57, 55],
#   'origi': 1},
#  116: {'desti': 26,
#   'length_of_route': 55.10031286732456,
#   'link_idx_list': [16, 42, 72, 219, 217],
#   'node_list': [5, 10, 20, 58, 57, 56],
#   'origi': 1},
#  117: {'desti': 26,
#   'length_of_route': 58.132777109385316,
#   'link_idx_list': [18, 39, 42, 72, 219, 217],
#   'node_list': [5, 11, 10, 20, 58, 57, 56],
#   'origi': 1},
#  118: {'desti': 26,
#   'length_of_route': 65.40993073054283,
#   'link_idx_list': [16, 42, 72, 222, 221, 217],
#   'node_list': [5, 10, 20, 58, 59, 57, 56],
#   'origi': 1},
#  119: {'desti': 26,
#   'length_of_route': 68.44239497260357,
#   'link_idx_list': [18, 39, 42, 72, 222, 221, 217],
#   'node_list': [5, 11, 10, 20, 58, 59, 57, 56],
#   'origi': 1},
#  120: {'desti': 26,
#   'length_of_route': 73.00709121206089,
#   'link_idx_list': [16, 42, 70, 118, 240, 227, 221, 217],
#   'node_list': [5, 10, 20, 30, 60, 72, 59, 57, 56],
#   'origi': 1},
#  121: {'desti': 27,
#   'length_of_route': 44.65784419217648,
#   'link_idx_list': [16, 42, 72, 219],
#   'node_list': [5, 10, 20, 58, 57],
#   'origi': 1},
#  122: {'desti': 27,
#   'length_of_route': 47.69030843423724,
#   'link_idx_list': [18, 39, 42, 72, 219],
#   'node_list': [5, 11, 10, 20, 58, 57],
#   'origi': 1},
#  123: {'desti': 27,
#   'length_of_route': 54.96746205539475,
#   'link_idx_list': [16, 42, 72, 222, 221],
#   'node_list': [5, 10, 20, 58, 59, 57],
#   'origi': 1},
#  124: {'desti': 27,
#   'length_of_route': 57.999926297455495,
#   'link_idx_list': [18, 39, 42, 72, 222, 221],
#   'node_list': [5, 11, 10, 20, 58, 59, 57],
#   'origi': 1},
#  125: {'desti': 27,
#   'length_of_route': 62.56462253691281,
#   'link_idx_list': [16, 42, 70, 118, 240, 227, 221],
#   'node_list': [5, 10, 20, 30, 60, 72, 59, 57],
#   'origi': 1},
#  126: {'desti': 22,
#   'length_of_route': 80.44469734376389,
#   'link_idx_list': [16, 40, 62, 66, 84, 114, 200],
#   'node_list': [5, 10, 18, 19, 22, 29, 49, 50],
#   'origi': 1},
#  127: {'desti': 22,
#   'length_of_route': 81.3058442962874,
#   'link_idx_list': [18, 44, 66, 84, 114, 200],
#   'node_list': [5, 11, 19, 22, 29, 49, 50],
#   'origi': 1},
#  128: {'desti': 22,
#   'length_of_route': 81.91711078056832,
#   'link_idx_list': [16, 38, 44, 66, 84, 114, 200],
#   'node_list': [5, 10, 11, 19, 22, 29, 49, 50],
#   'origi': 1},
#  129: {'desti': 22,
#   'length_of_route': 82.44565827342606,
#   'link_idx_list': [16, 40, 62, 57, 58, 84, 114, 200],
#   'node_list': [5, 10, 18, 19, 16, 22, 29, 49, 50],
#   'origi': 1},
#  130: {'desti': 22,
#   'length_of_route': 83.30680522594957,
#   'link_idx_list': [18, 44, 57, 58, 84, 114, 200],
#   'node_list': [5, 11, 19, 16, 22, 29, 49, 50],
#   'origi': 1},
#  131: {'desti': 22,
#   'length_of_route': 89.5390559239657,
#   'link_idx_list': [16, 40, 62, 66, 86, 155, 156, 190],
#   'node_list': [5, 10, 18, 19, 22, 40, 39, 48, 51],
#   'origi': 1},
#  132: {'desti': 22,
#   'length_of_route': 90.40020287648923,
#   'link_idx_list': [18, 44, 66, 86, 155, 156, 190],
#   'node_list': [5, 11, 19, 22, 40, 39, 48, 51],
#   'origi': 1},
#  133: {'desti': 22,
#   'length_of_route': 91.01146936077014,
#   'link_idx_list': [16, 38, 44, 66, 86, 155, 156, 190],
#   'node_list': [5, 10, 11, 19, 22, 40, 39, 48, 51],
#   'origi': 1},
#  134: {'desti': 22,
#   'length_of_route': 91.54001685362788,
#   'link_idx_list': [16, 40, 62, 57, 58, 86, 155, 156, 190],
#   'node_list': [5, 10, 18, 19, 16, 22, 40, 39, 48, 51],
#   'origi': 1},
#  135: {'desti': 22,
#   'length_of_route': 92.02980525710947,
#   'link_idx_list': [16, 40, 62, 66, 86, 155, 156, 192, 209],
#   'node_list': [5, 10, 18, 19, 22, 40, 39, 48, 52, 51],
#   'origi': 1},
#  136: {'desti': 23,
#   'length_of_route': 77.09873450776732,
#   'link_idx_list': [16, 40, 62, 66, 86, 155, 156, 192],
#   'node_list': [5, 10, 18, 19, 22, 40, 39, 48, 52],
#   'origi': 1},
#  137: {'desti': 23,
#   'length_of_route': 77.95988146029084,
#   'link_idx_list': [18, 44, 66, 86, 155, 156, 192],
#   'node_list': [5, 11, 19, 22, 40, 39, 48, 52],
#   'origi': 1},
#  138: {'desti': 23,
#   'length_of_route': 78.57114794457175,
#   'link_idx_list': [16, 38, 44, 66, 86, 155, 156, 192],
#   'node_list': [5, 10, 11, 19, 22, 40, 39, 48, 52],
#   'origi': 1},
#  139: {'desti': 23,
#   'length_of_route': 79.09969543742949,
#   'link_idx_list': [16, 40, 62, 57, 58, 86, 155, 156, 192],
#   'node_list': [5, 10, 18, 19, 16, 22, 40, 39, 48, 52],
#   'origi': 1},
#  140: {'desti': 23,
#   'length_of_route': 79.74758578144673,
#   'link_idx_list': [18, 44, 66, 84, 112, 159, 155, 156, 192],
#   'node_list': [5, 11, 19, 22, 29, 41, 40, 39, 48, 52],
#   'origi': 1},
#  141: {'desti': 24,
#   'length_of_route': 74.27867349695882,
#   'link_idx_list': [16, 40, 62, 66, 86, 155, 156, 194],
#   'node_list': [5, 10, 18, 19, 22, 40, 39, 48, 53],
#   'origi': 1},
#  142: {'desti': 24,
#   'length_of_route': 75.13982044948234,
#   'link_idx_list': [18, 44, 66, 86, 155, 156, 194],
#   'node_list': [5, 11, 19, 22, 40, 39, 48, 53],
#   'origi': 1},
#  143: {'desti': 24,
#   'length_of_route': 75.75108693376325,
#   'link_idx_list': [16, 38, 44, 66, 86, 155, 156, 194],
#   'node_list': [5, 10, 11, 19, 22, 40, 39, 48, 53],
#   'origi': 1},
#  144: {'desti': 24,
#   'length_of_route': 76.27963442662099,
#   'link_idx_list': [16, 40, 62, 57, 58, 86, 155, 156, 194],
#   'node_list': [5, 10, 18, 19, 16, 22, 40, 39, 48, 53],
#   'origi': 1},
#  145: {'desti': 24,
#   'length_of_route': 76.92752477063823,
#   'link_idx_list': [18, 44, 66, 84, 112, 159, 155, 156, 194],
#   'node_list': [5, 11, 19, 22, 29, 41, 40, 39, 48, 53],
#   'origi': 1},
#  146: {'desti': 27,
#   'length_of_route': 9.342478356225582,
#   'link_idx_list': [214],
#   'node_list': [55, 57],
#   'origi': 26},
#  147: {'desti': 26,
#   'length_of_route': 19.784947031373658,
#   'link_idx_list': [214, 217],
#   'node_list': [55, 57, 56],
#   'origi': 26},
#  148: {'desti': 25,
#   'length_of_route': 66.84994389464654,
#   'link_idx_list': [214, 220, 226, 241, 238, 145, 142, 174],
#   'node_list': [55, 57, 59, 72, 60, 71, 36, 44, 54],
#   'origi': 26},
#  149: {'desti': 25,
#   'length_of_route': 67.25863195401126,
#   'link_idx_list': [214, 220, 224, 238, 145, 142, 174],
#   'node_list': [55, 57, 59, 60, 71, 36, 44, 54],
#   'origi': 26},
#  150: {'desti': 25,
#   'length_of_route': 69.76027876525197,
#   'link_idx_list': [214, 220, 226, 241, 238, 139, 136, 142, 174],
#   'node_list': [55, 57, 59, 72, 60, 71, 35, 36, 44, 54],
#   'origi': 26},
#  151: {'desti': 25,
#   'length_of_route': 70.16896682461669,
#   'link_idx_list': [214, 220, 224, 238, 139, 136, 142, 174],
#   'node_list': [55, 57, 59, 60, 71, 35, 36, 44, 54],
#   'origi': 26},
#  152: {'desti': 25,
#   'length_of_route': 70.23841426556669,
#   'link_idx_list': [214, 220, 224, 129, 126, 132, 136, 142, 174],
#   'node_list': [55, 57, 59, 60, 32, 34, 35, 36, 44, 54],
#   'origi': 26},
#  153: {'desti': 24,
#   'length_of_route': 80.78853660892239,
#   'link_idx_list': [214, 220, 226, 241, 238, 145, 142, 174, 213],
#   'node_list': [55, 57, 59, 72, 60, 71, 36, 44, 54, 53],
#   'origi': 26},
#  154: {'desti': 24,
#   'length_of_route': 81.1972246682871,
#   'link_idx_list': [214, 220, 224, 238, 145, 142, 174, 213],
#   'node_list': [55, 57, 59, 60, 71, 36, 44, 54, 53],
#   'origi': 26},
#  155: {'desti': 24,
#   'length_of_route': 84.10755953889253,
#   'link_idx_list': [214, 220, 224, 238, 139, 136, 142, 174, 213],
#   'node_list': [55, 57, 59, 60, 71, 35, 36, 44, 54, 53],
#   'origi': 26},
#  156: {'desti': 24,
#   'length_of_route': 85.09173974959683,
#   'link_idx_list': [214, 220, 224, 238, 145, 140, 168, 174, 213],
#   'node_list': [55, 57, 59, 60, 71, 36, 43, 44, 54, 53],
#   'origi': 26},
#  157: {'desti': 24,
#   'length_of_route': 85.6431432908402,
#   'link_idx_list': [214, 220, 224, 238, 145, 142, 172, 182, 213],
#   'node_list': [55, 57, 59, 60, 71, 36, 44, 46, 54, 53],
#   'origi': 26},
#  158: {'desti': 28,
#   'length_of_route': 34.4682766251572,
#   'link_idx_list': [16, 42, 72],
#   'node_list': [5, 10, 20, 58],
#   'origi': 1},
#  159: {'desti': 28,
#   'length_of_route': 37.50074086721795,
#   'link_idx_list': [18, 39, 42, 72],
#   'node_list': [5, 11, 10, 20, 58],
#   'origi': 1},
#  160: {'desti': 28,
#   'length_of_route': 54.138498197313226,
#   'link_idx_list': [16, 40, 64, 69, 72],
#   'node_list': [5, 10, 18, 21, 20, 58],
#   'origi': 1},
#  161: {'desti': 28,
#   'length_of_route': 57.170962439373966,
#   'link_idx_list': [18, 39, 40, 64, 69, 72],
#   'node_list': [5, 11, 10, 18, 21, 20, 58],
#   'origi': 1},
#  162: {'desti': 28,
#   'length_of_route': 60.51320594865813,
#   'link_idx_list': [16, 42, 70, 118, 240, 227, 223],
#   'node_list': [5, 10, 20, 30, 60, 72, 59, 58],
#   'origi': 1},
#  163: {'desti': 29,
#   'length_of_route': 43.61257074269451,
#   'link_idx_list': [16, 42, 72, 222],
#   'node_list': [5, 10, 20, 58, 59],
#   'origi': 1},
#  164: {'desti': 29,
#   'length_of_route': 46.645034984755256,
#   'link_idx_list': [18, 39, 42, 72, 222],
#   'node_list': [5, 11, 10, 20, 58, 59],
#   'origi': 1},
#  165: {'desti': 29,
#   'length_of_route': 51.20973122421257,
#   'link_idx_list': [16, 42, 70, 118, 240, 227],
#   'node_list': [5, 10, 20, 30, 60, 72, 59],
#   'origi': 1},
#  166: {'desti': 29,
#   'length_of_route': 51.98007456394589,
#   'link_idx_list': [16, 42, 70, 118, 225],
#   'node_list': [5, 10, 20, 30, 60, 59],
#   'origi': 1},
#  167: {'desti': 29,
#   'length_of_route': 52.26466364930751,
#   'link_idx_list': [16, 42, 70, 116, 122, 240, 227],
#   'node_list': [5, 10, 20, 30, 31, 60, 72, 59],
#   'origi': 1},
#  168: {'desti': 22,
#   'length_of_route': 106.81613609182088,
#   'link_idx_list': [214, 218, 73, 68, 74, 84, 114, 200],
#   'node_list': [55, 57, 58, 20, 21, 22, 29, 49, 50],
#   'origi': 26},
#  169: {'desti': 22,
#   'length_of_route': 108.18478953698079,
#   'link_idx_list': [214, 220, 224, 123, 91, 79, 84, 114, 200],
#   'node_list': [55, 57, 59, 60, 31, 23, 22, 29, 49, 50],
#   'origi': 26},
#  170: {'desti': 22,
#   'length_of_route': 109.0518998967444,
#   'link_idx_list': [214, 218, 73, 68, 76, 79, 84, 114, 200],
#   'node_list': [55, 57, 58, 20, 21, 23, 22, 29, 49, 50],
#   'origi': 26},
#  171: {'desti': 22,
#   'length_of_route': 110.7835971201857,
#   'link_idx_list': [214, 218, 73, 68, 74, 84, 114, 202, 207],
#   'node_list': [55, 57, 58, 20, 21, 22, 29, 49, 73, 50],
#   'origi': 26},
#  172: {'desti': 22,
#   'length_of_route': 112.15225056534561,
#   'link_idx_list': [214, 220, 224, 123, 91, 79, 84, 114, 202, 207],
#   'node_list': [55, 57, 59, 60, 31, 23, 22, 29, 49, 73, 50],
#   'origi': 26},
#  173: {'desti': 21,
#   'length_of_route': 93.77706425978988,
#   'link_idx_list': [214, 218, 73, 68, 74, 84, 114],
#   'node_list': [55, 57, 58, 20, 21, 22, 29, 49],
#   'origi': 26},
#  174: {'desti': 21,
#   'length_of_route': 94.73702964558507,
#   'link_idx_list': [214, 220, 226, 241, 123, 91, 79, 84, 114],
#   'node_list': [55, 57, 59, 72, 60, 31, 23, 22, 29, 49],
#   'origi': 26},
#  175: {'desti': 21,
#   'length_of_route': 95.14571770494979,
#   'link_idx_list': [214, 220, 224, 123, 91, 79, 84, 114],
#   'node_list': [55, 57, 59, 60, 31, 23, 22, 29, 49],
#   'origi': 26},
#  176: {'desti': 21,
#   'length_of_route': 96.0128280647134,
#   'link_idx_list': [214, 218, 73, 68, 76, 79, 84, 114],
#   'node_list': [55, 57, 58, 20, 21, 23, 22, 29, 49],
#   'origi': 26},
#  177: {'desti': 21,
#   'length_of_route': 96.9646369953297,
#   'link_idx_list': [214, 220, 224, 238, 145, 142, 174, 197, 188],
#   'node_list': [55, 57, 59, 60, 71, 36, 44, 54, 48, 49],
#   'origi': 26},
#  178: {'desti': 17,
#   'length_of_route': 52.10449373203602,
#   'link_idx_list': [251, 235, 123, 91, 79, 86],
#   'node_list': [68, 67, 60, 31, 23, 22, 40],
#   'origi': 25},
#  179: {'desti': 17,
#   'length_of_route': 53.34402213083233,
#   'link_idx_list': [251, 235, 129, 124, 97, 89, 79, 86],
#   'node_list': [68, 67, 60, 32, 33, 24, 23, 22, 40],
#   'origi': 25},
#  180: {'desti': 17,
#   'length_of_route': 53.89219805319189,
#   'link_idx_list': [251, 235, 123, 91, 79, 84, 112, 159],
#   'node_list': [68, 67, 60, 31, 23, 22, 29, 41, 40],
#   'origi': 25},
#  181: {'desti': 17,
#   'length_of_route': 54.89729832439249,
#   'link_idx_list': [251, 252, 256, 145, 140, 165, 153, 150, 154],
#   'node_list': [68, 67, 69, 71, 36, 43, 42, 38, 39, 40],
#   'origi': 25},
#  182: {'desti': 17,
#   'length_of_route': 55.04602462556174,
#   'link_idx_list': [251, 235, 129, 121, 91, 79, 86],
#   'node_list': [68, 67, 60, 32, 31, 23, 22, 40],
#   'origi': 25},
#  183: {'desti': 8,
#   'length_of_route': 16.250535648067878,
#   'link_idx_list': [50, 55, 56, 63],
#   'node_list': [14, 17, 16, 19, 18],
#   'origi': 7},
#  184: {'desti': 8,
#   'length_of_route': 17.908368625865286,
#   'link_idx_list': [52, 67, 63],
#   'node_list': [14, 22, 19, 18],
#   'origi': 7},
#  185: {'desti': 8,
#   'length_of_route': 20.12865061936146,
#   'link_idx_list': [52, 59, 56, 63],
#   'node_list': [14, 22, 16, 19, 18],
#   'origi': 7},
#  186: {'desti': 8,
#   'length_of_route': 20.747145055391805,
#   'link_idx_list': [52, 75, 65],
#   'node_list': [14, 22, 21, 18],
#   'origi': 7},
#  187: {'desti': 8,
#   'length_of_route': 20.826645882517283,
#   'link_idx_list': [50, 55, 58, 67, 63],
#   'node_list': [14, 17, 16, 22, 19, 18],
#   'origi': 7},
#  188: {'desti': 14,
#   'length_of_route': 27.055600631662312,
#   'link_idx_list': [66, 78, 90],
#   'node_list': [19, 22, 23, 31],
#   'origi': 8},
#  189: {'desti': 14,
#   'length_of_route': 29.05656156132448,
#   'link_idx_list': [57, 58, 78, 90],
#   'node_list': [19, 16, 22, 23, 31],
#   'origi': 8},
#  190: {'desti': 14,
#   'length_of_route': 30.18111219336288,
#   'link_idx_list': [63, 64, 76, 90],
#   'node_list': [19, 18, 21, 23, 31],
#   'origi': 8},
#  191: {'desti': 14,
#   'length_of_route': 32.360079814243576,
#   'link_idx_list': [57, 54, 60, 78, 90],
#   'node_list': [19, 16, 17, 22, 23, 31],
#   'origi': 8},
#  192: {'desti': 14,
#   'length_of_route': 33.71938571198956,
#   'link_idx_list': [66, 75, 76, 90],
#   'node_list': [19, 22, 21, 23, 31],
#   'origi': 8},
#  193: {'desti': 9,
#   'length_of_route': 30.732738218547922,
#   'link_idx_list': [52, 75, 69],
#   'node_list': [14, 22, 21, 20],
#   'origi': 7},
#  194: {'desti': 9,
#   'length_of_route': 33.138148714019245,
#   'link_idx_list': [52, 78, 77, 69],
#   'node_list': [14, 22, 23, 21, 20],
#   'origi': 7},
#  195: {'desti': 9,
#   'length_of_route': 33.65101547519993,
#   'link_idx_list': [50, 55, 58, 75, 69],
#   'node_list': [14, 17, 16, 22, 21, 20],
#   'origi': 7},
#  196: {'desti': 9,
#   'length_of_route': 34.24689519230883,
#   'link_idx_list': [50, 60, 75, 69],
#   'node_list': [14, 17, 22, 21, 20],
#   'origi': 7},
#  197: {'desti': 9,
#   'length_of_route': 36.05642597067124,
#   'link_idx_list': [50, 55, 58, 78, 77, 69],
#   'node_list': [14, 17, 16, 22, 23, 21, 20],
#   'origi': 7},
#  198: {'desti': 18,
#   'length_of_route': 43.4857297636846,
#   'link_idx_list': [251, 252, 256, 145, 140, 165],
#   'node_list': [68, 67, 69, 71, 36, 43, 42],
#   'origi': 25},
#  199: {'desti': 18,
#   'length_of_route': 44.55176634356368,
#   'link_idx_list': [251, 235, 238, 145, 140, 165],
#   'node_list': [68, 67, 60, 71, 36, 43, 42],
#   'origi': 25},
#  200: {'desti': 18,
#   'length_of_route': 46.39606463429002,
#   'link_idx_list': [251, 252, 256, 139, 136, 140, 165],
#   'node_list': [68, 67, 69, 71, 35, 36, 43, 42],
#   'origi': 25},
#  201: {'desti': 18,
#   'length_of_route': 46.64681515750052,
#   'link_idx_list': [251, 252, 256, 145, 142, 169, 165],
#   'node_list': [68, 67, 69, 71, 36, 44, 43, 42],
#   'origi': 25},
#  202: {'desti': 18,
#   'length_of_route': 47.4621012141691,
#   'link_idx_list': [251, 235, 238, 139, 136, 140, 165],
#   'node_list': [68, 67, 60, 71, 35, 36, 43, 42],
#   'origi': 25},
#  203: {'desti': 15,
#   'length_of_route': 46.093659937768436,
#   'link_idx_list': [189, 185, 181, 173, 143, 144],
#   'node_list': [49, 48, 47, 46, 44, 36, 71],
#   'origi': 21},
#  204: {'desti': 15,
#   'length_of_route': 48.57104902742465,
#   'link_idx_list': [189, 185, 179, 171, 141, 144],
#   'node_list': [49, 48, 47, 45, 43, 36, 71],
#   'origi': 21},
#  205: {'desti': 15,
#   'length_of_route': 48.79973295306788,
#   'link_idx_list': [189, 185, 179, 176, 173, 143, 144],
#   'node_list': [49, 48, 47, 45, 46, 44, 36, 71],
#   'origi': 21},
#  206: {'desti': 15,
#   'length_of_route': 49.26553339180219,
#   'link_idx_list': [189, 185, 181, 173, 143, 137, 138],
#   'node_list': [49, 48, 47, 46, 44, 36, 35, 71],
#   'origi': 21},
#  207: {'desti': 15,
#   'length_of_route': 49.59453348079659,
#   'link_idx_list': [189, 198, 187, 181, 173, 143, 144],
#   'node_list': [49, 48, 74, 47, 46, 44, 36, 71],
#   'origi': 21},
#  208: {'desti': 19,
#   'length_of_route': 39.51456163834414,
#   'link_idx_list': [251, 252, 256, 145, 140],
#   'node_list': [68, 67, 69, 71, 36, 43],
#   'origi': 25},
#  209: {'desti': 19,
#   'length_of_route': 40.580598218223216,
#   'link_idx_list': [251, 235, 238, 145, 140],
#   'node_list': [68, 67, 60, 71, 36, 43],
#   'origi': 25},
#  210: {'desti': 19,
#   'length_of_route': 42.42489650894956,
#   'link_idx_list': [251, 252, 256, 139, 136, 140],
#   'node_list': [68, 67, 69, 71, 35, 36, 43],
#   'origi': 25},
#  211: {'desti': 19,
#   'length_of_route': 42.67564703216006,
#   'link_idx_list': [251, 252, 256, 145, 142, 169],
#   'node_list': [68, 67, 69, 71, 36, 44, 43],
#   'origi': 25},
#  212: {'desti': 19,
#   'length_of_route': 43.49093308882864,
#   'link_idx_list': [251, 235, 238, 139, 136, 140],
#   'node_list': [68, 67, 60, 71, 35, 36, 43],
#   'origi': 25},
#  213: {'desti': 8,
#   'length_of_route': 27.05963929421244,
#   'link_idx_list': [116, 91, 79, 59],
#   'node_list': [30, 31, 23, 22, 16],
#   'origi': 14},
#  214: {'desti': 8,
#   'length_of_route': 30.30340125494678,
#   'link_idx_list': [116, 91, 79, 61, 55],
#   'node_list': [30, 31, 23, 22, 17, 16],
#   'origi': 14},
#  215: {'desti': 8,
#   'length_of_route': 33.837241388015336,
#   'link_idx_list': [116, 120, 124, 97, 89, 79, 59],
#   'node_list': [30, 31, 32, 33, 24, 23, 22, 16],
#   'origi': 14},
#  216: {'desti': 8,
#   'length_of_route': 33.87459425660992,
#   'link_idx_list': [116, 91, 79, 67, 57],
#   'node_list': [30, 31, 23, 22, 19, 16],
#   'origi': 14},
#  217: {'desti': 8,
#   'length_of_route': 33.89307106508749,
#   'link_idx_list': [116, 91, 77, 74, 59],
#   'node_list': [30, 31, 23, 21, 22, 16],
#   'origi': 14},
#  218: {'desti': 27,
#   'length_of_route': 43.349987600067195,
#   'link_idx_list': [64, 69, 72, 219],
#   'node_list': [18, 21, 20, 58, 57],
#   'origi': 8},
#  219: {'desti': 27,
#   'length_of_route': 44.69245078871094,
#   'link_idx_list': [41, 42, 72, 219],
#   'node_list': [18, 10, 20, 58, 57],
#   'origi': 8},
#  220: {'desti': 27,
#   'length_of_route': 50.57482267965288,
#   'link_idx_list': [62, 45, 39, 42, 72, 219],
#   'node_list': [18, 19, 11, 10, 20, 58, 57],
#   'origi': 8},
#  221: {'desti': 27,
#   'length_of_route': 52.44257571618588,
#   'link_idx_list': [64, 76, 90, 122, 240, 227, 221],
#   'node_list': [18, 21, 23, 31, 60, 72, 59, 57],
#   'origi': 8},
#  222: {'desti': 27,
#   'length_of_route': 52.78682760553485,
#   'link_idx_list': [62, 66, 75, 69, 72, 219],
#   'node_list': [18, 19, 22, 21, 20, 58, 57],
#   'origi': 8},
#  223: {'desti': 6,
#   'length_of_route': 15.790921702333073,
#   'link_idx_list': [47, 37, 34],
#   'node_list': [14, 13, 9, 12],
#   'origi': 7},
#  224: {'desti': 6,
#   'length_of_route': 23.697458581157914,
#   'link_idx_list': [47, 29, 26, 34],
#   'node_list': [14, 13, 7, 9, 12],
#   'origi': 7},
#  225: {'desti': 6,
#   'length_of_route': 39.002927474857614,
#   'link_idx_list': [50, 25, 22, 37, 34],
#   'node_list': [14, 17, 6, 13, 9, 12],
#   'origi': 7},
#  226: {'desti': 6,
#   'length_of_route': 43.22728874727012,
#   'link_idx_list': [50, 55, 33, 21, 22, 37, 34],
#   'node_list': [14, 17, 16, 8, 6, 13, 9, 12],
#   'origi': 7},
#  227: {'desti': 6,
#   'length_of_route': 45.588680981961375,
#   'link_idx_list': [52, 59, 54, 25, 22, 37, 34],
#   'node_list': [14, 22, 16, 17, 6, 13, 9, 12],
#   'origi': 7},
#  228: {'desti': 12,
#   'length_of_route': 25.343977861091414,
#   'link_idx_list': [167, 149, 111, 103, 99],
#   'node_list': [45, 42, 37, 28, 26, 25],
#   'origi': 19},
#  229: {'desti': 12,
#   'length_of_route': 26.280212781281378,
#   'link_idx_list': [167, 149, 111, 103, 95, 92],
#   'node_list': [45, 42, 37, 28, 26, 24, 25],
#   'origi': 19},
#  230: {'desti': 12,
#   'length_of_route': 27.20037145919066,
#   'link_idx_list': [171, 165, 149, 111, 103, 99],
#   'node_list': [45, 43, 42, 37, 28, 26, 25],
#   'origi': 19},
#  231: {'desti': 12,
#   'length_of_route': 27.678742250711764,
#   'link_idx_list': [167, 149, 111, 105, 101, 99],
#   'node_list': [45, 42, 37, 28, 27, 26, 25],
#   'origi': 19},
#  232: {'desti': 12,
#   'length_of_route': 28.114513658819885,
#   'link_idx_list': [167, 153, 147, 111, 103, 99],
#   'node_list': [45, 42, 38, 37, 28, 26, 25],
#   'origi': 19},
#  233: {'desti': 7,
#   'length_of_route': 7.5254129722949505,
#   'link_idx_list': [47],
#   'node_list': [14, 13],
#   'origi': 7},
#  234: {'desti': 7,
#   'length_of_route': 30.73741874481949,
#   'link_idx_list': [50, 25, 22],
#   'node_list': [14, 17, 6, 13],
#   'origi': 7},
#  235: {'desti': 7,
#   'length_of_route': 34.961780017232,
#   'link_idx_list': [50, 55, 33, 21, 22],
#   'node_list': [14, 17, 16, 8, 6, 13],
#   'origi': 7},
#  236: {'desti': 7,
#   'length_of_route': 37.32317225192325,
#   'link_idx_list': [52, 59, 54, 25, 22],
#   'node_list': [14, 22, 16, 17, 6, 13],
#   'origi': 7},
#  237: {'desti': 7,
#   'length_of_route': 37.85929567684741,
#   'link_idx_list': [52, 61, 25, 22],
#   'node_list': [14, 22, 17, 6, 13],
#   'origi': 7},
#  238: {'desti': 30,
#   'length_of_route': 36.425966706297075,
#   'link_idx_list': [233, 228],
#   'node_list': [65, 60, 61],
#   'origi': 31},
#  239: {'desti': 30,
#   'length_of_route': 36.11903601793399,
#   'link_idx_list': [245, 231, 228],
#   'node_list': [65, 63, 60, 61],
#   'origi': 31},
#  240: {'desti': 31,
#   'length_of_route': 25.3316338470404,
#   'link_idx_list': [233, 230, 243],
#   'node_list': [65, 60, 63, 62],
#   'origi': 31},
#  241: {'desti': 31,
#   'length_of_route': 5.587441806968725,
#   'link_idx_list': [245, 243],
#   'node_list': [65, 63, 62],
#   'origi': 31},
#  242: {'desti': 29,
#   'length_of_route': 19.007579217151623,
#   'link_idx_list': [245, 231, 240, 227],
#   'node_list': [65, 63, 60, 72, 59],
#   'origi': 31},
#  243: {'desti': 29,
#   'length_of_route': 19.3145099055147,
#   'link_idx_list': [233, 240, 227],
#   'node_list': [65, 60, 72, 59],
#   'origi': 31},
#  244: {'desti': 29,
#   'length_of_route': 19.777922556884942,
#   'link_idx_list': [245, 231, 225],
#   'node_list': [65, 63, 60, 59],
#   'origi': 31},
#  245: {'desti': 29,
#   'length_of_route': 20.08485324524802,
#   'link_idx_list': [233, 225],
#   'node_list': [65, 60, 59],
#   'origi': 31},
#  246: {'desti': 29,
#   'length_of_route': 53.9921159449677,
#   'link_idx_list': [245, 231, 119, 71, 72, 222],
#   'node_list': [65, 63, 60, 30, 20, 58, 59],
#   'origi': 31},
#  247: {'desti': 29,
#   'length_of_route': 11.588988156239735,
#   'link_idx_list': [233],
#   'node_list': [65, 60],
#   'origi': 31},
#  248: {'desti': 29,
#   'length_of_route': 11.282057467876655,
#   'link_idx_list': [245, 231],
#   'node_list': [65, 63, 60],
#   'origi': 31},
#  249: {'desti': 31,
#   'length_of_route': 6.352585110246855,
#   'link_idx_list': [248],
#   'node_list': [65, 66],
#   'origi': 31},
#  250: {'desti': 32,
#   'length_of_route': 19.91271551699017,
#   'link_idx_list': [245, 231, 234],
#   'node_list': [65, 63, 60, 67],
#   'origi': 31},
#  251: {'desti': 32,
#   'length_of_route': 20.21964620535325,
#   'link_idx_list': [233, 234],
#   'node_list': [65, 60, 67],
#   'origi': 31},
#  252: {'desti': 32,
#   'length_of_route': 35.20510655211288,
#   'link_idx_list': [245, 231, 236, 253],
#   'node_list': [65, 63, 60, 69, 67],
#   'origi': 31},
#  253: {'desti': 32,
#   'length_of_route': 35.51203724047596,
#   'link_idx_list': [233, 236, 253],
#   'node_list': [65, 60, 69, 67],
#   'origi': 31},
#  254: {'desti': 32,
#   'length_of_route': 44.88493825589734,
#   'link_idx_list': [245, 231, 238, 257, 253],
#   'node_list': [65, 63, 60, 71, 69, 67],
#   'origi': 31},
#  255: {'desti': 27,
#   'length_of_route': 24.593984485190436,
#   'link_idx_list': [128, 240, 227, 221],
#   'node_list': [32, 60, 72, 59, 57],
#   'origi': 14},
#  256: {'desti': 27,
#   'length_of_route': 25.364327824923755,
#   'link_idx_list': [128, 225, 221],
#   'node_list': [32, 60, 59, 57],
#   'origi': 14},
#  257: {'desti': 27,
#   'length_of_route': 30.042602228291756,
#   'link_idx_list': [121, 122, 240, 227, 221],
#   'node_list': [32, 31, 60, 72, 59, 57],
#   'origi': 14},
#  258: {'desti': 27,
#   'length_of_route': 30.81294556802507,
#   'link_idx_list': [121, 122, 225, 221],
#   'node_list': [32, 31, 60, 59, 57],
#   'origi': 14},
#  259: {'desti': 27,
#   'length_of_route': 30.964398699448445,
#   'link_idx_list': [126, 134, 240, 227, 221],
#   'node_list': [32, 34, 60, 72, 59, 57],
#   'origi': 14},
#  260: {'desti': 28,
#   'length_of_route': 22.542567896935758,
#   'link_idx_list': [128, 240, 227, 223],
#   'node_list': [32, 60, 72, 59, 58],
#   'origi': 14},
#  261: {'desti': 28,
#   'length_of_route': 23.31291123666908,
#   'link_idx_list': [128, 225, 223],
#   'node_list': [32, 60, 59, 58],
#   'origi': 14},
#  262: {'desti': 28,
#   'length_of_route': 27.991185640037077,
#   'link_idx_list': [121, 122, 240, 227, 223],
#   'node_list': [32, 31, 60, 72, 59, 58],
#   'origi': 14},
#  263: {'desti': 28,
#   'length_of_route': 28.761528979770397,
#   'link_idx_list': [121, 122, 225, 223],
#   'node_list': [32, 31, 60, 59, 58],
#   'origi': 14},
#  264: {'desti': 28,
#   'length_of_route': 28.91298211119377,
#   'link_idx_list': [126, 134, 240, 227, 223],
#   'node_list': [32, 34, 60, 72, 59, 58],
#   'origi': 14},
#  265: {'desti': 26,
#   'length_of_route': 33.7334496567574,
#   'link_idx_list': [128, 240, 227, 221, 215],
#   'node_list': [32, 60, 72, 59, 57, 55],
#   'origi': 14},
#  266: {'desti': 26,
#   'length_of_route': 34.503792996490716,
#   'link_idx_list': [128, 225, 221, 215],
#   'node_list': [32, 60, 59, 57, 55],
#   'origi': 14},
#  267: {'desti': 26,
#   'length_of_route': 39.18206739985872,
#   'link_idx_list': [121, 122, 240, 227, 221, 215],
#   'node_list': [32, 31, 60, 72, 59, 57, 55],
#   'origi': 14},
#  268: {'desti': 26,
#   'length_of_route': 39.95241073959203,
#   'link_idx_list': [121, 122, 225, 221, 215],
#   'node_list': [32, 31, 60, 59, 57, 55],
#   'origi': 14},
#  269: {'desti': 26,
#   'length_of_route': 40.103863871015406,
#   'link_idx_list': [126, 134, 240, 227, 221, 215],
#   'node_list': [32, 34, 60, 72, 59, 57, 55],
#   'origi': 14},
#  270: {'desti': 26,
#   'length_of_route': 35.03645316033851,
#   'link_idx_list': [128, 240, 227, 221, 217],
#   'node_list': [32, 60, 72, 59, 57, 56],
#   'origi': 14},
#  271: {'desti': 26,
#   'length_of_route': 35.80679650007183,
#   'link_idx_list': [128, 225, 221, 217],
#   'node_list': [32, 60, 59, 57, 56],
#   'origi': 14},
#  272: {'desti': 26,
#   'length_of_route': 40.48507090343983,
#   'link_idx_list': [121, 122, 240, 227, 221, 217],
#   'node_list': [32, 31, 60, 72, 59, 57, 56],
#   'origi': 14},
#  273: {'desti': 26,
#   'length_of_route': 41.25541424317315,
#   'link_idx_list': [121, 122, 225, 221, 217],
#   'node_list': [32, 31, 60, 59, 57, 56],
#   'origi': 14},
#  274: {'desti': 26,
#   'length_of_route': 41.40686737459652,
#   'link_idx_list': [126, 134, 240, 227, 221, 217],
#   'node_list': [32, 34, 60, 72, 59, 57, 56],
#   'origi': 14},
#  275: {'desti': 24,
#   'length_of_route': 49.889811255641604,
#   'link_idx_list': [126, 132, 136, 142, 174, 213],
#   'node_list': [32, 34, 35, 36, 44, 54, 53],
#   'origi': 14},
#  276: {'desti': 24,
#   'length_of_route': 53.784326336951324,
#   'link_idx_list': [126, 132, 136, 140, 168, 174, 213],
#   'node_list': [32, 34, 35, 36, 43, 44, 54, 53],
#   'origi': 14},
#  277: {'desti': 24,
#   'length_of_route': 54.312145122981065,
#   'link_idx_list': [126, 132, 138, 145, 142, 174, 213],
#   'node_list': [32, 34, 35, 71, 36, 44, 54, 53],
#   'origi': 14},
#  278: {'desti': 24,
#   'length_of_route': 54.3357298781947,
#   'link_idx_list': [126, 132, 136, 142, 172, 182, 213],
#   'node_list': [32, 34, 35, 36, 44, 46, 54, 53],
#   'origi': 14},
#  279: {'desti': 24,
#   'length_of_route': 56.57097528093503,
#   'link_idx_list': [126, 132, 136, 142, 172, 180, 184, 194],
#   'node_list': [32, 34, 35, 36, 44, 46, 47, 48, 53],
#   'origi': 14},
#  280: {'desti': 25,
#   'length_of_route': 35.95121854136576,
#   'link_idx_list': [126, 132, 136, 142, 174],
#   'node_list': [32, 34, 35, 36, 44, 54],
#   'origi': 14},
#  281: {'desti': 25,
#   'length_of_route': 39.84573362267548,
#   'link_idx_list': [126, 132, 136, 140, 168, 174],
#   'node_list': [32, 34, 35, 36, 43, 44, 54],
#   'origi': 14},
#  282: {'desti': 25,
#   'length_of_route': 40.37355240870522,
#   'link_idx_list': [126, 132, 138, 145, 142, 174],
#   'node_list': [32, 34, 35, 71, 36, 44, 54],
#   'origi': 14},
#  283: {'desti': 25,
#   'length_of_route': 40.397137163918856,
#   'link_idx_list': [126, 132, 136, 142, 172, 182],
#   'node_list': [32, 34, 35, 36, 44, 46, 54],
#   'origi': 14},
#  284: {'desti': 25,
#   'length_of_route': 43.52660769519215,
#   'link_idx_list': [126, 132, 136, 140, 170, 176, 182],
# ...
#   'link_idx_list': [111, 103, 100, 106, 125, 128, 225, 221, 217],
#   'node_list': [37, 28, 26, 27, 33, 32, 60, 59, 57, 56],
#   'origi': 17},
#  907: {'desti': 26,
#   'length_of_route': 63.37129663647031,
#   'link_idx_list': [111, 103, 95, 96, 125, 128, 225, 221, 217],
#   'node_list': [37, 28, 26, 24, 33, 32, 60, 59, 57, 56],
#   'origi': 17},
#  908: {'desti': 26,
#   'length_of_route': 63.39220495603717,
#   'link_idx_list': [111, 105, 106, 130, 127, 128, 225, 221, 217],
#   'node_list': [37, 28, 27, 33, 34, 32, 60, 59, 57, 56],
#   'origi': 17},
#  909: {'desti': 27,
#   'length_of_route': 50.29231230518634,
#   'link_idx_list': [111, 105, 106, 125, 128, 240, 227, 221],
#   'node_list': [37, 28, 27, 33, 32, 60, 72, 59, 57],
#   'origi': 17},
#  910: {'desti': 27,
#   'length_of_route': 51.062655644919666,
#   'link_idx_list': [111, 105, 106, 125, 128, 225, 221],
#   'node_list': [37, 28, 27, 33, 32, 60, 59, 57],
#   'origi': 17},
#  911: {'desti': 27,
#   'length_of_route': 51.10006785392267,
#   'link_idx_list': [111, 103, 100, 106, 125, 128, 240, 227, 221],
#   'node_list': [37, 28, 26, 27, 33, 32, 60, 72, 59, 57],
#   'origi': 17},
#  912: {'desti': 27,
#   'length_of_route': 51.87041119365599,
#   'link_idx_list': [111, 103, 100, 106, 125, 128, 225, 221],
#   'node_list': [37, 28, 26, 27, 33, 32, 60, 59, 57],
#   'origi': 17},
#  913: {'desti': 27,
#   'length_of_route': 52.15848462158891,
#   'link_idx_list': [111, 103, 95, 96, 125, 128, 240, 227, 221],
#   'node_list': [37, 28, 26, 24, 33, 32, 60, 72, 59, 57],
#   'origi': 17},
#  914: {'desti': 22,
#   'length_of_route': 83.65302339480253,
#   'link_idx_list': [68, 74, 86, 155, 156, 190],
#   'node_list': [20, 21, 22, 40, 39, 48, 51],
#   'origi': 9},
#  915: {'desti': 22,
#   'length_of_route': 85.44072771595842,
#   'link_idx_list': [68, 74, 84, 112, 159, 155, 156, 190],
#   'node_list': [20, 21, 22, 29, 41, 40, 39, 48, 51],
#   'origi': 9},
#  916: {'desti': 22,
#   'length_of_route': 85.88878719972605,
#   'link_idx_list': [68, 76, 79, 86, 155, 156, 190],
#   'node_list': [20, 21, 23, 22, 40, 39, 48, 51],
#   'origi': 9},
#  917: {'desti': 22,
#   'length_of_route': 86.1437727279463,
#   'link_idx_list': [68, 74, 86, 155, 156, 192, 209],
#   'node_list': [20, 21, 22, 40, 39, 48, 52, 51],
#   'origi': 9},
#  918: {'desti': 22,
#   'length_of_route': 86.70527662325686,
#   'link_idx_list': [68, 74, 86, 160, 190],
#   'node_list': [20, 21, 22, 40, 48, 51],
#   'origi': 9},
#  919: {'desti': 22,
#   'length_of_route': 88.86857131197169,
#   'link_idx_list': [6, 8, 24, 55, 58, 86, 155, 156, 190],
#   'node_list': [2, 3, 6, 17, 16, 22, 40, 39, 48, 51],
#   'origi': 1},
#  920: {'desti': 22,
#   'length_of_route': 89.46445102908059,
#   'link_idx_list': [6, 8, 24, 60, 86, 155, 156, 190],
#   'node_list': [2, 3, 6, 17, 22, 40, 39, 48, 51],
#   'origi': 1},
#  921: {'desti': 22,
#   'length_of_route': 90.81717493133787,
#   'link_idx_list': [6, 8, 20, 32, 58, 86, 155, 156, 190],
#   'node_list': [2, 3, 6, 8, 16, 22, 40, 39, 48, 51],
#   'origi': 1},
#  922: {'desti': 22,
#   'length_of_route': 91.35932064511546,
#   'link_idx_list': [6, 8, 24, 55, 58, 86, 155, 156, 192, 209],
#   'node_list': [2, 3, 6, 17, 16, 22, 40, 39, 48, 52, 51],
#   'origi': 1},
#  923: {'desti': 22,
#   'length_of_route': 91.92082454042603,
#   'link_idx_list': [6, 8, 24, 55, 58, 86, 160, 190],
#   'node_list': [2, 3, 6, 17, 16, 22, 40, 48, 51],
#   'origi': 1},
#  924: {'desti': 29,
#   'length_of_route': 20.702637896910012,
#   'link_idx_list': [214, 220],
#   'node_list': [55, 57, 59],
#   'origi': 26},
#  925: {'desti': 29,
#   'length_of_route': 28.845737357581648,
#   'link_idx_list': [214, 218, 222],
#   'node_list': [55, 57, 58, 59],
#   'origi': 26},
#  926: {'desti': 29,
#   'length_of_route': 61.262863574586596,
#   'link_idx_list': [214, 218, 73, 70, 118, 240, 227],
#   'node_list': [55, 57, 58, 20, 30, 60, 72, 59],
#   'origi': 26},
#  927: {'desti': 29,
#   'length_of_route': 62.03320691431992,
#   'link_idx_list': [214, 218, 73, 70, 118, 225],
#   'node_list': [55, 57, 58, 20, 30, 60, 59],
#   'origi': 26},
#  928: {'desti': 29,
#   'length_of_route': 62.317795999681536,
#   'link_idx_list': [214, 218, 73, 70, 116, 122, 240, 227],
#   'node_list': [55, 57, 58, 20, 30, 31, 60, 72, 59],
#   'origi': 26},
#  929: {'desti': 23,
#   'length_of_route': 71.21270197860414,
#   'link_idx_list': [68, 74, 86, 155, 156, 192],
#   'node_list': [20, 21, 22, 40, 39, 48, 52],
#   'origi': 9},
#  930: {'desti': 23,
#   'length_of_route': 73.00040629976003,
#   'link_idx_list': [68, 74, 84, 112, 159, 155, 156, 192],
#   'node_list': [20, 21, 22, 29, 41, 40, 39, 48, 52],
#   'origi': 9},
#  931: {'desti': 23,
#   'length_of_route': 73.44846578352767,
#   'link_idx_list': [68, 76, 79, 86, 155, 156, 192],
#   'node_list': [20, 21, 23, 22, 40, 39, 48, 52],
#   'origi': 9},
#  932: {'desti': 23,
#   'length_of_route': 74.26495520705848,
#   'link_idx_list': [68, 74, 86, 160, 192],
#   'node_list': [20, 21, 22, 40, 48, 52],
#   'origi': 9},
#  933: {'desti': 23,
#   'length_of_route': 75.23617010468354,
#   'link_idx_list': [68, 76, 79, 84, 112, 159, 155, 156, 192],
#   'node_list': [20, 21, 23, 22, 29, 41, 40, 39, 48, 52],
#   'origi': 9},
#  934: {'desti': 31,
#   'length_of_route': 57.47499068636387,
#   'link_idx_list': [36, 46, 52, 78, 90, 122, 230],
#   'node_list': [9, 13, 14, 22, 23, 31, 60, 63],
#   'origi': 4},
#  935: {'desti': 31,
#   'length_of_route': 58.98062353325675,
#   'link_idx_list': [36, 46, 52, 78, 88, 96, 125, 128, 230],
#   'node_list': [9, 13, 14, 22, 23, 24, 33, 32, 60, 63],
#   'origi': 4},
#  936: {'desti': 31,
#   'length_of_route': 60.39326794301587,
#   'link_idx_list': [36, 46, 50, 55, 58, 78, 90, 122, 230],
#   'node_list': [9, 13, 14, 17, 16, 22, 23, 31, 60, 63],
#   'origi': 4},
#  937: {'desti': 31,
#   'length_of_route': 60.505977531794855,
#   'link_idx_list': [36, 46, 52, 78, 90, 120, 128, 230],
#   'node_list': [9, 13, 14, 22, 23, 31, 32, 60, 63],
#   'origi': 4},
#  938: {'desti': 31,
#   'length_of_route': 60.950262703829615,
#   'link_idx_list': [36, 46, 52, 78, 90, 122, 232, 245],
#   'node_list': [9, 13, 14, 22, 23, 31, 60, 65, 63],
#   'origi': 4},
#  939: {'desti': 17,
#   'length_of_route': 47.93972171296508,
#   'link_idx_list': [203, 189, 157, 151, 147],
#   'node_list': [73, 49, 48, 39, 38, 37],
#   'origi': 21},
#  940: {'desti': 17,
#   'length_of_route': 51.11242480450655,
#   'link_idx_list': [203, 189, 185, 179, 167, 149],
#   'node_list': [73, 49, 48, 47, 45, 42, 37],
#   'origi': 21},
#  941: {'desti': 17,
#   'length_of_route': 52.25669431561793,
#   'link_idx_list': [203, 189, 185, 181, 177, 167, 149],
#   'node_list': [73, 49, 48, 47, 46, 45, 42, 37],
#   'origi': 21},
#  942: {'desti': 17,
#   'length_of_route': 52.629429148664066,
#   'link_idx_list': [203, 163, 159, 155, 151, 147],
#   'node_list': [73, 49, 41, 40, 39, 38, 37],
#   'origi': 21},
#  943: {'desti': 17,
#   'length_of_route': 52.9688184026058,
#   'link_idx_list': [203, 189, 185, 179, 171, 165, 149],
#   'node_list': [73, 49, 48, 47, 45, 43, 42, 37],
#   'origi': 21},
#  944: {'desti': 28,
#   'length_of_route': 19.70144324004434,
#   'link_idx_list': [214, 218],
#   'node_list': [55, 57, 58],
#   'origi': 26},
#  945: {'desti': 28,
#   'length_of_route': 30.006112621355577,
#   'link_idx_list': [214, 220, 223],
#   'node_list': [55, 57, 59, 58],
#   'origi': 26},
#  946: {'desti': 28,
#   'length_of_route': 62.00083069194825,
#   'link_idx_list': [214, 220, 226, 241, 119, 71, 72],
#   'node_list': [55, 57, 59, 72, 60, 30, 20, 58],
#   'origi': 26},
#  947: {'desti': 28,
#   'length_of_route': 62.40951875131297,
#   'link_idx_list': [214, 220, 224, 119, 71, 72],
#   'node_list': [55, 57, 59, 60, 30, 20, 58],
#   'origi': 26},
#  948: {'desti': 28,
#   'length_of_route': 62.99532262512926,
#   'link_idx_list': [214, 220, 226, 241, 123, 117, 71, 72],
#   'node_list': [55, 57, 59, 72, 60, 31, 30, 20, 58],
#   'origi': 26},
#  949: {'desti': 14,
#   'length_of_route': 31.78231715381773,
#   'link_idx_list': [181, 173, 143, 137, 133, 127],
#   'node_list': [47, 46, 44, 36, 35, 34, 32],
#   'origi': 19},
#  950: {'desti': 14,
#   'length_of_route': 34.25970624347394,
#   'link_idx_list': [179, 171, 141, 137, 133, 127],
#   'node_list': [47, 45, 43, 36, 35, 34, 32],
#   'origi': 19},
#  951: {'desti': 14,
#   'length_of_route': 34.488390169117174,
#   'link_idx_list': [179, 176, 173, 143, 137, 133, 127],
#   'node_list': [47, 45, 46, 44, 36, 35, 34, 32],
#   'origi': 19},
#  952: {'desti': 14,
#   'length_of_route': 35.40397575458531,
#   'link_idx_list': [181, 177, 171, 141, 137, 133, 127],
#   'node_list': [47, 46, 45, 43, 36, 35, 34, 32],
#   'origi': 19},
#  953: {'desti': 14,
#   'length_of_route': 35.94311243772886,
#   'link_idx_list': [181, 173, 143, 144, 139, 133, 127],
#   'node_list': [47, 46, 44, 36, 71, 35, 34, 32],
#   'origi': 19},
#  954: {'desti': 17,
#   'length_of_route': 4.459947841535517,
#   'link_idx_list': [150, 154],
#   'node_list': [38, 39, 40],
#   'origi': 17},
#  955: {'desti': 17,
#   'length_of_route': 32.37051047971738,
#   'link_idx_list': [147, 111, 83, 86],
#   'node_list': [38, 37, 28, 22, 40],
#   'origi': 17},
#  956: {'desti': 17,
#   'length_of_route': 33.290372532742175,
#   'link_idx_list': [147, 111, 103, 95, 89, 79, 86],
#   'node_list': [38, 37, 28, 26, 24, 23, 22, 40],
#   'origi': 17},
#  957: {'desti': 17,
#   'length_of_route': 34.15821480087326,
#   'link_idx_list': [147, 111, 83, 84, 112, 159],
#   'node_list': [38, 37, 28, 22, 29, 41, 40],
#   'origi': 17},
#  958: {'desti': 17,
#   'length_of_route': 35.078076853898054,
#   'link_idx_list': [147, 111, 103, 95, 89, 79, 84, 112, 159],
#   'node_list': [38, 37, 28, 26, 24, 23, 22, 29, 41, 40],
#   'origi': 17},
#  959: {'desti': 12,
#   'length_of_route': 37.08435252659566,
#   'link_idx_list': [6, 8, 24, 55, 58, 82],
#   'node_list': [2, 3, 6, 17, 16, 22, 28],
#   'origi': 1},
#  960: {'desti': 12,
#   'length_of_route': 37.680232243704566,
#   'link_idx_list': [6, 8, 24, 60, 82],
#   'node_list': [2, 3, 6, 17, 22, 28],
#   'origi': 1},
#  961: {'desti': 12,
#   'length_of_route': 38.93431439578957,
#   'link_idx_list': [6, 8, 24, 55, 58, 78, 88, 94, 102],
#   'node_list': [2, 3, 6, 17, 16, 22, 23, 24, 26, 28],
#   'origi': 1},
#  962: {'desti': 12,
#   'length_of_route': 39.03295614596184,
#   'link_idx_list': [6, 8, 20, 32, 58, 82],
#   'node_list': [2, 3, 6, 8, 16, 22, 28],
#   'origi': 1},
#  963: {'desti': 12,
#   'length_of_route': 39.530194112898485,
#   'link_idx_list': [6, 8, 24, 60, 78, 88, 94, 102],
#   'node_list': [2, 3, 6, 17, 22, 23, 24, 26, 28],
#   'origi': 1},
#  964: {'desti': 12,
#   'length_of_route': 38.711794666341994,
#   'link_idx_list': [6, 8, 24, 55, 58, 78, 88, 94, 100],
#   'node_list': [2, 3, 6, 17, 16, 22, 23, 24, 26, 27],
#   'origi': 1},
#  965: {'desti': 12,
#   'length_of_route': 39.30767438345091,
#   'link_idx_list': [6, 8, 24, 60, 78, 88, 94, 100],
#   'node_list': [2, 3, 6, 17, 22, 23, 24, 26, 27],
#   'origi': 1},
#  966: {'desti': 12,
#   'length_of_route': 39.391667544568826,
#   'link_idx_list': [6, 8, 24, 55, 58, 82, 105],
#   'node_list': [2, 3, 6, 17, 16, 22, 28, 27],
#   'origi': 1},
#  967: {'desti': 12,
#   'length_of_route': 39.98754726167773,
#   'link_idx_list': [6, 8, 24, 60, 82, 105],
#   'node_list': [2, 3, 6, 17, 22, 28, 27],
#   'origi': 1},
#  968: {'desti': 12,
#   'length_of_route': 40.19942309330516,
#   'link_idx_list': [6, 8, 24, 55, 58, 82, 103, 100],
#   'node_list': [2, 3, 6, 17, 16, 22, 28, 26, 27],
#   'origi': 1},
#  969: {'desti': 17,
#   'length_of_route': 1.2922793827309171,
#   'link_idx_list': [154],
#   'node_list': [39, 40],
#   'origi': 17},
#  970: {'desti': 17,
#   'length_of_route': 35.4743036068204,
#   'link_idx_list': [151, 147, 111, 83, 86],
#   'node_list': [39, 38, 37, 28, 22, 40],
#   'origi': 17},
#  971: {'desti': 17,
#   'length_of_route': 36.39416565984519,
#   'link_idx_list': [151, 147, 111, 103, 95, 89, 79, 86],
#   'node_list': [39, 38, 37, 28, 26, 24, 23, 22, 40],
#   'origi': 17},
#  972: {'desti': 17,
#   'length_of_route': 37.262007927976285,
#   'link_idx_list': [151, 147, 111, 83, 84, 112, 159],
#   'node_list': [39, 38, 37, 28, 22, 29, 41, 40],
#   'origi': 17},
#  973: {'desti': 17,
#   'length_of_route': 38.53939883445756,
#   'link_idx_list': [151, 147, 111, 103, 99, 81, 86],
#   'node_list': [39, 38, 37, 28, 26, 25, 22, 40],
#   'origi': 17},
#  974: {'desti': 15,
#   'length_of_route': 20.680686029663157,
#   'link_idx_list': [181, 173, 143, 137],
#   'node_list': [47, 46, 44, 36, 35],
#   'origi': 19},
#  975: {'desti': 15,
#   'length_of_route': 23.15807511931937,
#   'link_idx_list': [179, 171, 141, 137],
#   'node_list': [47, 45, 43, 36, 35],
#   'origi': 19},
#  976: {'desti': 15,
#   'length_of_route': 23.386759044962602,
#   'link_idx_list': [179, 176, 173, 143, 137],
#   'node_list': [47, 45, 46, 44, 36, 35],
#   'origi': 19},
#  977: {'desti': 15,
#   'length_of_route': 24.30234463043074,
#   'link_idx_list': [181, 177, 171, 141, 137],
#   'node_list': [47, 46, 45, 43, 36, 35],
#   'origi': 19},
#  978: {'desti': 15,
#   'length_of_route': 24.841481313574285,
#   'link_idx_list': [181, 173, 143, 144, 139],
#   'node_list': [47, 46, 44, 36, 71, 35],
#   'origi': 19},
#  979: {'desti': 15,
#   'length_of_route': 31.967368653499282,
#   'link_idx_list': [55, 58, 78, 88, 94, 100, 108],
#   'node_list': [17, 16, 22, 23, 24, 26, 27, 35],
#   'origi': 8},
#  980: {'desti': 15,
#   'length_of_route': 32.56324837060819,
#   'link_idx_list': [60, 78, 88, 94, 100, 108],
#   'node_list': [17, 22, 23, 24, 26, 27, 35],
#   'origi': 8},
#  981: {'desti': 15,
#   'length_of_route': 32.64724153172611,
#   'link_idx_list': [55, 58, 82, 105, 108],
#   'node_list': [17, 16, 22, 28, 27, 35],
#   'origi': 8},
#  982: {'desti': 15,
#   'length_of_route': 33.24312124883502,
#   'link_idx_list': [60, 82, 105, 108],
#   'node_list': [17, 22, 28, 27, 35],
#   'origi': 8},
#  983: {'desti': 15,
#   'length_of_route': 33.45499708046244,
#   'link_idx_list': [55, 58, 82, 103, 100, 108],
#   'node_list': [17, 16, 22, 28, 26, 27, 35],
#   'origi': 8},
#  984: {'desti': 9,
#   'length_of_route': 33.900553411136194,
#   'link_idx_list': [6, 8, 20, 30, 39, 42],
#   'node_list': [2, 3, 6, 8, 11, 10, 20],
#   'origi': 1},
#  985: {'desti': 9,
#   'length_of_route': 40.719261659638605,
#   'link_idx_list': [6, 8, 13, 14, 30, 39, 42],
#   'node_list': [2, 3, 6, 4, 8, 11, 10, 20],
#   'origi': 1},
#  986: {'desti': 9,
#   'length_of_route': 50.6409158924758,
#   'link_idx_list': [6, 8, 24, 55, 58, 75, 69],
#   'node_list': [2, 3, 6, 17, 16, 22, 21, 20],
#   'origi': 1},
#  987: {'desti': 9,
#   'length_of_route': 51.23679560958471,
#   'link_idx_list': [6, 8, 24, 60, 75, 69],
#   'node_list': [2, 3, 6, 17, 22, 21, 20],
#   'origi': 1},
#  988: {'desti': 9,
#   'length_of_route': 52.589519511841985,
#   'link_idx_list': [6, 8, 20, 32, 58, 75, 69],
#   'node_list': [2, 3, 6, 8, 16, 22, 21, 20],
#   'origi': 1},
#  989: {'desti': 8,
#   'length_of_route': 29.691665299584898,
#   'link_idx_list': [6, 8, 24, 55, 56],
#   'node_list': [2, 3, 6, 17, 16, 19],
#   'origi': 1},
#  990: {'desti': 8,
#   'length_of_route': 31.64026891895108,
#   'link_idx_list': [6, 8, 20, 32, 56],
#   'node_list': [2, 3, 6, 8, 16, 19],
#   'origi': 1},
#  991: {'desti': 8,
#   'length_of_route': 32.852771080100275,
#   'link_idx_list': [6, 8, 20, 30, 44],
#   'node_list': [2, 3, 6, 8, 11, 19],
#   'origi': 1},
#  992: {'desti': 8,
#   'length_of_route': 34.2677755340343,
#   'link_idx_list': [6, 8, 24, 55, 58, 67],
#   'node_list': [2, 3, 6, 17, 16, 22, 19],
#   'origi': 1},
#  993: {'desti': 8,
#   'length_of_route': 34.863655251143214,
#   'link_idx_list': [6, 8, 24, 60, 67],
#   'node_list': [2, 3, 6, 17, 22, 19],
#   'origi': 1},
#  994: {'desti': 11,
#   'length_of_route': 28.476233541731656,
#   'link_idx_list': [6, 8, 24, 55, 58],
#   'node_list': [2, 3, 6, 17, 16, 22],
#   'origi': 1},
#  995: {'desti': 11,
#   'length_of_route': 29.072113258840563,
#   'link_idx_list': [6, 8, 24, 60],
#   'node_list': [2, 3, 6, 17, 22],
#   'origi': 1},
#  996: {'desti': 11,
#   'length_of_route': 30.424837161097837,
#   'link_idx_list': [6, 8, 20, 32, 58],
#   'node_list': [2, 3, 6, 8, 16, 22],
#   'origi': 1},
#  997: {'desti': 11,
#   'length_of_route': 33.72835541401693,
#   'link_idx_list': [6, 8, 20, 32, 54, 60],
#   'node_list': [2, 3, 6, 8, 16, 17, 22],
#   'origi': 1},
#  998: {'desti': 11,
#   'length_of_route': 35.51050956796314,
#   'link_idx_list': [6, 8, 24, 55, 56, 66],
#   'node_list': [2, 3, 6, 17, 16, 19, 22],
#   'origi': 1},
#  999: {'desti': 10,
#   'length_of_route': 35.198006771218765,
#   'link_idx_list': [6, 8, 24, 55, 58, 75],
#   'node_list': [2, 3, 6, 17, 16, 22, 21],
#   'origi': 1},
#  ...}

# %%
link_label_dict_['24->23'], link_label_dict_['23->22'], link_label_dict_['22->29']
# Out:
# (89, 79, 84)
