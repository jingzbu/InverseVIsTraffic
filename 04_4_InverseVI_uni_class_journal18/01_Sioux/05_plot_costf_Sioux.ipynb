# %%
polyEval(coeffs, pt) = sum([coeffs[i] * pt^(i-1) for i = 1:length(coeffs)])
# Out:
# polyEval (generic function with 1 method)

# %%
coeffs_dict = readstring("./results_Sioux/coeffs_dict_Sioux.json")
coeffs_dict = JSON.parse(coeffs_dict)
# Out:
# Dict{String,Any} with 60 entries:
#   "(6,1.0,1.0,1)"   => Any[1.0,-0.00157125,-0.0168442,0.0579633,0.0930661,0.022…
#   "(5,1.0,0.1,1)"   => Any[1.0,0.00387063,-0.0350077,0.0651266,0.108695,0.00866…
#   "(3,1.5,100.0,1)" => Any[1.0,-0.000744058,0.0123247,0.0100313]
#   "(4,1.5,0.01,1)"  => Any[1.0,-0.00712288,0.0134895,-0.0100209,0.152593]
#   "(5,1.0,1.0,1)"   => Any[1.0,-0.00143874,-0.0210144,0.0725201,0.0942907,0.012…
#   "(6,1.5,10.0,1)"  => Any[1.0,-0.00547657,-0.00735009,0.0667406,0.0814293,0.02…
#   "(3,1.5,1.0,1)"   => Any[1.0,-0.0218448,0.0231819,0.147912]
#   "(6,1.0,10.0,1)"  => Any[1.0,-0.00656221,0.00873578,0.0564977,0.0749529,0.029…
#   "(5,1.5,1.0,1)"   => Any[1.0,0.00598798,-0.0462791,0.0885942,0.0927395,0.0120…
#   "(3,0.5,0.01,1)"  => Any[1.0,0.487486,-1.01347,0.702319]
#   "(3,0.5,1.0,1)"   => Any[1.0,-0.0147784,0.00242111,0.150385]
#   "(5,1.0,0.01,1)"  => Any[1.0,0.00702862,-0.045645,0.0715116,0.108251,0.008305…
#   "(4,1.0,1.0,1)"   => Any[1.0,0.016778,-0.071428,0.058138,0.135398]
#   "(6,1.5,1.0,1)"   => Any[1.0,0.00502549,-0.0410652,0.078335,0.0960466,0.01407…
#   "(4,1.0,100.0,1)" => Any[1.0,-0.00215166,0.00467022,0.0172793,0.0133495]
#   "(5,1.5,0.01,1)"  => Any[1.0,0.00702888,-0.045646,0.0715128,0.108251,0.008305…
#   "(4,1.0,0.01,1)"  => Any[1.0,-0.00712287,0.0134895,-0.0100209,0.152593]
#   "(6,1.5,0.1,1)"   => Any[1.0,0.00321345,-0.0286122,0.0436095,0.128819,0.00133…
#   "(6,1.5,100.0,1)" => Any[1.0,0.000488112,0.0287405,0.0613036,0.055595,0.02145…
#   "(6,0.5,10.0,1)"  => Any[1.0,0.000134856,0.00399586,0.0215735,0.0494827,0.041…
#   "(4,1.5,0.1,1)"   => Any[1.0,0.0208014,-0.0847276,0.0654185,0.134283]
#   "(6,0.5,1.0,1)"   => Any[1.0,-0.0013418,0.00363047,0.0379111,0.0788798,0.0414…
#   "(4,0.5,100.0,1)" => Any[1.0,-0.000262043,0.0015127,0.0103277,0.0157857]
#   "(3,1.0,10.0,1)"  => Any[1.0,-0.0143344,0.0278983,0.0489222]
#   "(4,0.5,0.01,1)"  => Any[1.0,-0.00712288,0.0134895,-0.0100209,0.152593]
#   ⋮                 => ⋮

# %%
deg = 3
c = 0.5
lam = 0.01
# Out:
# 0.01

# %%
using PyPlot

PyPlot.figure(figsize=(8, 3.5))

iterN = 1

true_coeffs = [1, 0, 0, 0, 0.15]
# true_coeffs = [1, .2, .5, .8, .15]

est_coeffs = coeffs_dict["($deg,$c,$lam,$iterN)"]

xs = linspace(0, 2, 20)
ys_true = map(x->polyEval(true_coeffs, x), xs)

ys = map(x->polyEval(est_coeffs, x), xs)

PyPlot.plot(xs, ys_true, "s-r", label=L"ground truth $f(\cdot)$", linewidth=1)
PyPlot.plot(xs, ys, "d-b", label=L"$\hat f(\cdot)$ with $n = 3$, $c = 0.5$, $\gamma = 0.01$", 
linewidth=1)

legend(loc="upper left", fancybox="true", numpoints=1) 
# plot(xs, ys, "--b")
grid("on")
xlim(-0.1, 1.4);
ylim(0.98, 1.6);

font1 = Dict("family"=>"rm","color"=>"k","weight"=>"normal","size"=>14)
xlabel("Scaled Flow", fontdict=font1)
ylabel("Scaled Cost", fontdict=font1)

savefig("./results_Sioux/fitting_Sioux_uni_class_$(deg)_$(c)_$(lam).pdf")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f8abda62ad0>)
# /home/jzh/anaconda2/lib/python2.7/site-packages/matplotlib/font_manager.py:1288: UserWarning: findfont: Font family [u'rm'] not found. Falling back to Bitstream Vera Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
deg_1 = 3
c_1 = 1.5
lam_1 = 0.01

deg_2 = 4
c_2 = 1.5
lam_2 = 0.01

deg_3 = 5
c_3 = 1.5
lam_3 = 0.01

deg_4 = 6
c_4 = 1.5
lam_4 = 0.01
# Out:
# 0.01

# %%
using PyPlot

PyPlot.figure(figsize=(8, 3.5))

iterN = 1

true_coeffs = [1, 0, 0, 0, 0.15]
# true_coeffs = [1, .2, .5, .8, .15]

est_coeffs_1 = coeffs_dict["($deg_1,$c_1,$lam_1,$iterN)"]
est_coeffs_2 = coeffs_dict["($deg_2,$c_2,$lam_2,$iterN)"]
est_coeffs_3 = coeffs_dict["($deg_3,$c_3,$lam_3,$iterN)"]
est_coeffs_4 = coeffs_dict["($deg_4,$c_4,$lam_4,$iterN)"]

xs_true = linspace(0, 2, 20)
xs_1 = linspace(0, 2, 20)
xs_2 = linspace(0, 2, 20)
xs_3 = linspace(0, 2, 20)
xs_4 = linspace(0, 2, 20)

ys_true = map(x->polyEval(true_coeffs, x), xs_true)

ys_1 = map(x->polyEval(est_coeffs_1, x), xs_1)
ys_2 = map(x->polyEval(est_coeffs_2, x), xs_2)
ys_3 = map(x->polyEval(est_coeffs_3, x), xs_3)
ys_4 = map(x->polyEval(est_coeffs_4, x), xs_4)

PyPlot.plot(xs_true, ys_true, "s-r", label=L"ground truth $f(\cdot)$", linewidth=1,
markerfacecolor="None", markeredgecolor="r", markeredgewidth=1)

PyPlot.plot(xs_1, ys_1, "x-b", label=L"$\hat f(\cdot)$ with $n = 3$, $c = 1.5$, $\gamma = 0.01$", 
linewidth=1, markerfacecolor="None", markeredgecolor="b", markeredgewidth=1)

PyPlot.plot(xs_2, ys_2, "*-m", label=L"$\hat f(\cdot)$ with $n = 4$, $c = 1.5$, $\gamma = 0.01$", 
linewidth=1, markerfacecolor="None", markeredgecolor="m", markeredgewidth=1)

PyPlot.plot(xs_3, ys_3, c="sienna", ls="-", marker="o", 
label=L"$\hat f(\cdot)$ with $n = 5$, $c = 1.5$, $\gamma = 0.01$", 
linewidth=1, markerfacecolor="None", markeredgecolor="sienna", markeredgewidth=1)

PyPlot.plot(xs_4, ys_4, "^-g", label=L"$\hat f(\cdot)$ with $n = 6$, $c = 1.5$, $\gamma = 0.01$", 
linewidth=1, markerfacecolor="None", markeredgecolor="g", markeredgewidth=1)

legend(loc="upper left", fancybox="true", numpoints=1, frameon=false) 
# plot(xs, ys, "--b")
# grid("on")
xlim(-0.1, 1.4);
ylim(0.98, 1.6);

font1 = Dict("family"=>"rm","color"=>"k","weight"=>"normal","size"=>14)
xlabel("Scaled Flow", fontdict=font1)
ylabel("Scaled Cost", fontdict=font1)

savefig("./results_Sioux/fitting_Sioux_uni_class_n.pdf")

dire = "/home/jzh/Dropbox/Research/Data-driven_estimation_inverse_optimization/" * 
"MA_traffic_IEEE_special_issue_18/imag/"

savefig(dire * "fitting_Sioux_uni_class_n.pdf", dpi=300, bbox_inches="tight")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f8abdf96b90>)

# %%
deg_1 = 6
c_1 = 0.5
lam_1 = 10.0

deg_2 = 6
c_2 = 1.0
lam_2 = 10.0

deg_3 = 6
c_3 = 1.5
lam_3 = 10.0
# Out:
# 10.0

# %%
using PyPlot

PyPlot.figure(figsize=(8, 3.5))

iterN = 1

true_coeffs = [1, 0, 0, 0, 0.15]
# true_coeffs = [1, .2, .5, .8, .15]

est_coeffs_1 = coeffs_dict["($deg_1,$c_1,$lam_1,$iterN)"]
est_coeffs_2 = coeffs_dict["($deg_2,$c_2,$lam_2,$iterN)"]
est_coeffs_3 = coeffs_dict["($deg_3,$c_3,$lam_3,$iterN)"]

xs = linspace(0, 2, 20)
ys_true = map(x->polyEval(true_coeffs, x), xs)

ys_1 = map(x->polyEval(est_coeffs_1, x), xs)
ys_2 = map(x->polyEval(est_coeffs_2, x), xs)
ys_3 = map(x->polyEval(est_coeffs_3, x), xs)

PyPlot.plot(xs, ys_true, "s-r", label=L"ground truth $f(\cdot)$", linewidth=1, 
markerfacecolor="None", markeredgecolor="r", markeredgewidth=1)

PyPlot.plot(xs, ys_1, label=L"$\hat f(\cdot)$ with $n = 6$, $c = 0.5$, $\gamma = 10.0$", 
linewidth=1, c="sienna", ls="-", marker="o", markerfacecolor="None", markeredgecolor="sienna", 
markeredgewidth=1)

PyPlot.plot(xs, ys_2, "x-m", label=L"$\hat f(\cdot)$ with $n = 6$, $c = 1.0$, $\gamma = 10.0$", 
linewidth=1, markerfacecolor="None", markeredgecolor="m", markeredgewidth=1)

PyPlot.plot(xs, ys_3, "*-b", label=L"$\hat f(\cdot)$ with $n = 6$, $c = 1.5$, $\gamma = 10.0$", 
linewidth=1, markerfacecolor="None", markeredgecolor="b", markeredgewidth=1)

legend(loc="upper left", fancybox="true", numpoints=1, frameon=false) 
# plot(xs, ys, "--b")
# grid("on")
xlim(-0.1, 1.4);
ylim(0.98, 1.6);

font1 = Dict("family"=>"rm","color"=>"k","weight"=>"normal","size"=>14)
xlabel("Scaled Flow", fontdict=font1)
ylabel("Scaled Cost", fontdict=font1)

savefig("./results_Sioux/fitting_Sioux_uni_class_c.pdf")

dire = "/home/jzh/Dropbox/Research/Data-driven_estimation_inverse_optimization/" * 
"MA_traffic_IEEE_special_issue_18/imag/"

savefig(dire * "fitting_Sioux_uni_class_c.pdf", dpi=300, bbox_inches="tight")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f8abdf66b50>)

# %%
deg_1 = 5
c_1 = 1.5
lam_1 = 0.01

deg_2 = 5
c_2 = 1.5
lam_2 = 0.1

deg_3 = 5
c_3 = 1.5
lam_3 = 1.0

deg_4 = 5
c_4 = 1.5
lam_4 = 10.0

deg_5 = 5
c_5 = 1.5
lam_5 = 100.0
# Out:
# 100.0

# %%
using PyPlot

PyPlot.figure(figsize=(8, 3.5))

iterN = 1

true_coeffs = [1, 0, 0, 0, 0.15]
# true_coeffs = [1, .2, .5, .8, .15]

est_coeffs_1 = coeffs_dict["($deg_1,$c_1,$lam_1,$iterN)"]
est_coeffs_2 = coeffs_dict["($deg_2,$c_2,$lam_2,$iterN)"]
est_coeffs_3 = coeffs_dict["($deg_3,$c_3,$lam_3,$iterN)"]
est_coeffs_4 = coeffs_dict["($deg_4,$c_4,$lam_4,$iterN)"]
est_coeffs_5 = coeffs_dict["($deg_5,$c_5,$lam_5,$iterN)"]


xs = linspace(0, 2, 20)
xs_true = linspace(0, 2, 20)
xs_1 = linspace(0, 2, 20)
xs_2 = linspace(0, 2, 20)
ys_true = map(x->polyEval(true_coeffs, x), xs_true)

ys_1 = map(x->polyEval(est_coeffs_1, x), xs_1)
ys_2 = map(x->polyEval(est_coeffs_2, x), xs_2)
ys_3 = map(x->polyEval(est_coeffs_3, x), xs)
ys_4 = map(x->polyEval(est_coeffs_4, x), xs)
ys_5 = map(x->polyEval(est_coeffs_5, x), xs)

PyPlot.plot(xs_true, ys_true, "s-r", label=L"ground truth $f(\cdot)$", linewidth=1,
markerfacecolor="None", markeredgecolor="r", markeredgewidth=1)

PyPlot.plot(xs_1, ys_1, "o-g", label=L"$\hat f(\cdot)$ with $n = 5$, $c = 1.5$, $\gamma = 0.01$", 
linewidth=1, markerfacecolor="None", markeredgecolor="g", markeredgewidth=1, markersize=6)

PyPlot.plot(xs_2, ys_2, "*-b", label=L"$\hat f(\cdot)$ with $n = 5$, $c = 1.5$, $\gamma = 0.1$", 
linewidth=1, markerfacecolor="None", markeredgecolor="b", markeredgewidth=1, markersize=6)

PyPlot.plot(xs, ys_3, c="sienna", ls="-", marker="+", linewidth=1,
markerfacecolor="None", markeredgecolor="sienna", markeredgewidth=1, 
label=L"$\hat f(\cdot)$ with $n = 5$, $c = 1.5$, $\gamma = 1.0$", 
linewidth=1, markerfacecolor="None")

PyPlot.plot(xs, ys_4, "^-m", label=L"$\hat f(\cdot)$ with $n = 5$, $c = 1.5$, $\gamma = 10.0$", 
linewidth=1, markerfacecolor="None", markeredgecolor="m", markeredgewidth=1)

PyPlot.plot(xs, ys_5, c="indigo", ls="-", marker="x",
label=L"$\hat f(\cdot)$ with $n = 5$, $c = 1.5$, $\gamma = 100.0$", 
linewidth=1, markerfacecolor="None", markeredgecolor="indigo", markeredgewidth=1)

legend(loc="upper left", fancybox="true", numpoints=1, frameon=false) 
# plot(xs, ys, "--b")
# grid("on")
xlim(-0.1, 1.4);
ylim(0.98, 1.6);

font1 = Dict("family"=>"rm","color"=>"k","weight"=>"normal","size"=>16)
xlabel("Scaled Flow", fontdict=font1)
ylabel("Scaled Cost", fontdict=font1)

savefig("./results_Sioux/fitting_Sioux_uni_class_gamma.pdf")

dire = "/home/jzh/Dropbox/Research/Data-driven_estimation_inverse_optimization/" * 
"MA_traffic_IEEE_special_issue_18/imag/"

savefig(dire * "fitting_Sioux_uni_class_gamma.pdf", dpi=300, bbox_inches="tight")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f8abdd29510>)
