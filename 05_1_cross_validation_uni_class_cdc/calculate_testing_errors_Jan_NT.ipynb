# %%
# %run ../Python_files/util_data_storage_and_load.py

# %%
# %run ../Python_files/load_dicts.py

# %%
# %run ../Python_files/util.py

# %%
import numpy as np
from numpy.linalg import inv
from numpy import linalg as LA

# %%
# load testing sets (link flows)

testing_set_1, testing_set_2, testing_set_3 = zload('../temp_files/testing_sets_Jan_NT.pkz')

# %%
testing_sets = {}

testing_sets[1] = testing_set_1
testing_sets[2] = testing_set_2
testing_sets[3] = testing_set_3

# %%
np.size(testing_sets[2], 1)
# Out:
# 7

# %%
np.mean(np.array(testing_sets[3])[:,0])
# Out:
# 3905.8523557548774

# %%
# load link flow data (solution of the forward problem corresponding to trained costs)

import json

with open('../temp_files/uni-class_traffic_assignment_MSA_flows_Jan_NT.json', 'r') as json_file:
    xl = json.load(json_file)

# %%
# create a dictionary to store testing errors
testing_errors_dict = {}

from numpy import arange

deg_grid = range(4, 9)
c_grid = list(arange(.5, 3.5, .5))
lamb_grid = [10. ** m for m in range(-3, 5)]
train_idx = range(1, 4)

for deg in deg_grid:
    for c in c_grid:
        for lam in lamb_grid:
            for idx in train_idx:
                key_ = "'(" + str(deg) + ',' + str(c) + ',' + str(lam) + ',' + str(idx) + ")'"
                #if lam == 1e-5:
                #    key_ = "'(" + str(deg) + ',' + str(c) + ',' + '1.0e-5' + ',' + str(idx) + ")'"
                key_ = key_[1:-1]
                testing_errors_dict[key_] = np.mean([LA.norm(np.array(xl[key_]) - \
                                                             np.array(testing_sets[idx])[:, j]) \
                                                     for j in range(np.size(testing_sets[idx], 1))])

# %%
testing_mean_errors_dict = {}

deg_grid = range(4, 9)
c_grid = list(arange(.5, 3.5, .5))
lamb_grid = [10. ** m for m in range(-3, 5)]
train_idx = range(1, 4)

for deg in deg_grid:
    for c in c_grid:
        for lam in lamb_grid:
            key_ = {}
            for idx in train_idx:
                key_[idx] = "'(" + str(deg) + ',' + str(c) + ',' + str(lam) + ',' + str(idx) + ")'"
                #if lam == 1e-5:
                #    key_[idx] = "'(" + str(deg) + ',' + str(c) + ',' + '1.0e-5' + ',' + str(idx) + ")'"
                key_[idx] = key_[idx][1:-1]
            key__ = "'(" + str(deg) + ',' + str(c) + ',' + str(lam) + ")'"
            #if lam == 1e-5:
            #    key__ = "'(" + str(deg) + ',' + str(c) + ',' + '1.0e-5' + ")'"
            key__ = key__[1:-1]
            
            testing_mean_errors_dict[key__] = np.mean([testing_errors_dict[key_[idx]] for idx in train_idx])

# %%
testing_mean_errors_switch_dict = {}
for _key_ in testing_mean_errors_dict.keys():
    testing_mean_errors_switch_dict[testing_mean_errors_dict[_key_]] = _key_

# %%
best_key = '(6,1.5,10000.0,1)'

# Writing JSON data
with open('../temp_files/cross_validation_best_key_Jan_NT.json', 'w') as json_file:
    json.dump(best_key, json_file)

# %%
testing_mean_errors_switch_dict
# Out:
# {40279.40696970297: '(7,3.0,100.0)'}

# %%
testing_mean_errors_dict
# Out:
# {'(4,0.5,0.001)': 1736.3497943385817,
#  '(4,0.5,0.01)': 1763.623608488221,
#  '(4,0.5,0.1)': 1815.7991812611056,
#  '(4,0.5,1.0)': 1832.0991094869216,
#  '(4,0.5,10.0)': 1834.0535740652351,
#  '(4,0.5,100.0)': 1834.0535740652347,
#  '(4,0.5,1000.0)': 1834.8227662209374,
#  '(4,0.5,10000.0)': 1834.0535740652347,
#  '(4,1.0,0.001)': 1742.1925799630365,
#  '(4,1.0,0.01)': 1756.464699949255,
#  '(4,1.0,0.1)': 1884.4007215098065,
#  '(4,1.0,1.0)': 1997.2117693283717,
#  '(4,1.0,10.0)': 2019.9784077126226,
#  '(4,1.0,100.0)': 2019.3930119376357,
#  '(4,1.0,1000.0)': 2019.3930119376364,
#  '(4,1.0,10000.0)': 2019.3930119376357,
#  '(4,1.5,0.001)': 1747.1272131636313,
#  '(4,1.5,0.01)': 1754.0668198085034,
#  '(4,1.5,0.1)': 1895.9358297542858,
#  '(4,1.5,1.0)': 2184.8499387614183,
#  '(4,1.5,10.0)': 2263.7004765399865,
#  '(4,1.5,100.0)': 2271.2233554019508,
#  '(4,1.5,1000.0)': 2271.2233554019499,
#  '(4,1.5,10000.0)': 2274.11512994234,
#  '(4,2.0,0.001)': 1750.8535971324943,
#  '(4,2.0,0.01)': 1756.8069015389528,
#  '(4,2.0,0.1)': 1877.5087889976755,
#  '(4,2.0,1.0)': 2305.5117965894715,
#  '(4,2.0,10.0)': 2447.2914131442958,
#  '(4,2.0,100.0)': 2466.3806414113174,
#  '(4,2.0,1000.0)': 2467.689046007275,
#  '(4,2.0,10000.0)': 2471.1507740966481,
#  '(4,2.5,0.001)': 1754.4407123654971,
#  '(4,2.5,0.01)': 1758.0572969886932,
#  '(4,2.5,0.1)': 1852.6216620364755,
#  '(4,2.5,1.0)': 2359.8427801853281,
#  '(4,2.5,10.0)': 2624.3042247999415,
#  '(4,2.5,100.0)': 2664.7016196823911,
#  '(4,2.5,1000.0)': 2667.313933864672,
#  '(4,2.5,10000.0)': 2668.4296507051508,
#  '(4,3.0,0.001)': 1756.3661987303115,
#  '(4,3.0,0.01)': 1760.9792269973011,
#  '(4,3.0,0.1)': 1831.6922187916318,
#  '(4,3.0,1.0)': 2373.8750961063979,
#  '(4,3.0,10.0)': 2775.1309873219707,
#  '(4,3.0,100.0)': 2853.9910975870293,
#  '(4,3.0,1000.0)': 2859.8293954215137,
#  '(4,3.0,10000.0)': 2858.3305794531861,
#  '(5,0.5,0.001)': 1725.9448389425913,
#  '(5,0.5,0.01)': 1734.7820893915389,
#  '(5,0.5,0.1)': 1750.4890634437754,
#  '(5,0.5,1.0)': 1756.2254412093923,
#  '(5,0.5,10.0)': 1757.0719960900797,
#  '(5,0.5,100.0)': 1757.0719960900788,
#  '(5,0.5,1000.0)': 1757.0719959970186,
#  '(5,0.5,10000.0)': 1757.0719959970186,
#  '(5,1.0,0.001)': 1731.7705792595295,
#  '(5,1.0,0.01)': 1734.6075176898912,
#  '(5,1.0,0.1)': 1762.7477835626742,
#  '(5,1.0,1.0)': 1815.3057103291897,
#  '(5,1.0,10.0)': 1831.0848529662289,
#  '(5,1.0,100.0)': 1832.3072437651081,
#  '(5,1.0,1000.0)': 1832.3072437651081,
#  '(5,1.0,10000.0)': 1832.3072437651081,
#  '(5,1.5,0.001)': 1734.8893780244464,
#  '(5,1.5,0.01)': 1737.8355096455289,
#  '(5,1.5,0.1)': 1756.8083535679723,
#  '(5,1.5,1.0)': 1869.4379344689623,
#  '(5,1.5,10.0)': 1948.9984196181842,
#  '(5,1.5,100.0)': 1960.7212970350711,
#  '(5,1.5,1000.0)': 1961.4278248836117,
#  '(5,1.5,10000.0)': 1961.4278248836124,
#  '(5,2.0,0.001)': 1735.4218806730114,
#  '(5,2.0,0.01)': 1740.589781215901,
#  '(5,2.0,0.1)': 1750.281617441364,
#  '(5,2.0,1.0)': 1882.3021799142527,
#  '(5,2.0,10.0)': 2085.2767473986069,
#  '(5,2.0,100.0)': 2133.3864186106707,
#  '(5,2.0,1000.0)': 2138.1540569371596,
#  '(5,2.0,10000.0)': 2140.1921562259254,
#  '(5,2.5,0.001)': 1737.1746408852086,
#  '(5,2.5,0.01)': 1743.3555533825086,
#  '(5,2.5,0.1)': 1749.6178439630739,
#  '(5,2.5,1.0)': 1863.9334740494189,
#  '(5,2.5,10.0)': 2198.0116138220396,
#  '(5,2.5,100.0)': 2301.2587549175055,
#  '(5,2.5,1000.0)': 2313.1578832792543,
#  '(5,2.5,10000.0)': 2318.2096194503033,
#  '(5,3.0,0.001)': 1738.99498634925,
#  '(5,3.0,0.01)': 1746.0485853984526,
#  '(5,3.0,0.1)': 1750.8711624740051,
#  '(5,3.0,1.0)': 1836.4086118849202,
#  '(5,3.0,10.0)': 2258.4174868510454,
#  '(5,3.0,100.0)': 2432.4455903369294,
#  '(5,3.0,1000.0)': 2461.0996435098032,
#  '(5,3.0,10000.0)': 2459.7471188366085,
#  '(6,0.5,0.001)': 1690.1919290401784,
#  '(6,0.5,0.01)': 1707.2142956703563,
#  '(6,0.5,0.1)': 1724.5043810419068,
#  '(6,0.5,1.0)': 1733.915124789979,
#  '(6,0.5,10.0)': 1734.7197388325421,
#  '(6,0.5,100.0)': 1734.5321864423731,
#  '(6,0.5,1000.0)': 1734.3212016182295,
#  '(6,0.5,10000.0)': 1734.7197388325424,
#  '(6,1.0,0.001)': 1712.0586847737529,
#  '(6,1.0,0.01)': 1718.4342632714104,
#  '(6,1.0,0.1)': 1733.6416978344066,
#  '(6,1.0,1.0)': 1754.6900080945725,
#  '(6,1.0,10.0)': 1761.5309099405465,
#  '(6,1.0,100.0)': 1762.4421287527691,
#  '(6,1.0,1000.0)': 1764.2018838317688,
#  '(6,1.0,10000.0)': 1762.8805916365227,
#  '(6,1.5,0.001)': 1714.9633578811381,
#  '(6,1.5,0.01)': 1729.6523827441715,
#  '(6,1.5,0.1)': 1732.7273594888986,
#  '(6,1.5,1.0)': 1763.6725045936053,
#  '(6,1.5,10.0)': 1814.2684576648655,
#  '(6,1.5,100.0)': 1826.8429778736174,
#  '(6,1.5,1000.0)': 1827.9343245993186,
#  '(6,1.5,10000.0)': 1829.4215699834065,
#  '(6,2.0,0.001)': 1720.8872914480596,
#  '(6,2.0,0.01)': 1732.5252504175685,
#  '(6,2.0,0.1)': 1733.8448308844854,
#  '(6,2.0,1.0)': 1755.2687688661508,
#  '(6,2.0,10.0)': 1856.383687717168,
#  '(6,2.0,100.0)': 1919.3927723008189,
#  '(6,2.0,1000.0)': 1927.5221478068222,
#  '(6,2.0,10000.0)': 1927.5221478068222,
#  '(6,2.5,0.001)': 19809.159236984953,
#  '(6,2.5,0.01)': 1733.492324346289,
#  '(6,2.5,0.1)': 1737.4112868557197,
#  '(6,2.5,1.0)': 1748.3585663420108,
#  '(6,2.5,10.0)': 1867.3271886308751,
#  '(6,2.5,100.0)': 2019.8540808077787,
#  '(6,2.5,1000.0)': 2054.6544453817492,
#  '(6,2.5,10000.0)': 2059.4069681116366,
#  '(6,3.0,0.001)': 19268.391934388655,
#  '(6,3.0,0.01)': 1733.2603735006512,
#  '(6,3.0,0.1)': 1740.3593209329745,
#  '(6,3.0,1.0)': 1745.7192618122226,
#  '(6,3.0,10.0)': 1845.7424031352987,
#  '(6,3.0,100.0)': 2106.208624131008,
#  '(6,3.0,1000.0)': 2196.712714194472,
#  '(6,3.0,10000.0)': 2207.7130556726147,
#  '(7,0.5,0.001)': 1665.5157827952071,
#  '(7,0.5,0.01)': 1674.5769421030436,
#  '(7,0.5,0.1)': 1706.5927744581611,
#  '(7,0.5,1.0)': 1721.1080378694235,
#  '(7,0.5,10.0)': 1720.4254090141355,
#  '(7,0.5,100.0)': 1720.126015648166,
#  '(7,0.5,1000.0)': 1719.6811771741566,
#  '(7,0.5,10000.0)': 1720.1260156481658,
#  '(7,1.0,0.001)': 1682.6299438901488,
#  '(7,1.0,0.01)': 1692.1793073829747,
#  '(7,1.0,0.1)': 1706.6565784808106,
#  '(7,1.0,1.0)': 1734.4315816894748,
#  '(7,1.0,10.0)': 1740.4019660473141,
#  '(7,1.0,100.0)': 1739.7661360370184,
#  '(7,1.0,1000.0)': 1739.7217726315278,
#  '(7,1.0,10000.0)': 1739.7217566930749,
#  '(7,1.5,0.001)': 17720.037822966486,
#  '(7,1.5,0.01)': 1707.8005599681776,
#  '(7,1.5,0.1)': 1718.2658301338743,
#  '(7,1.5,1.0)': 1733.5386877170877,
#  '(7,1.5,10.0)': 1757.1361824910935,
#  '(7,1.5,100.0)': 1769.9995791959361,
#  '(7,1.5,1000.0)': 1772.334709987882,
#  '(7,1.5,10000.0)': 1772.9294012298303,
#  '(7,2.0,0.001)': 19252.961427724313,
#  '(7,2.0,0.01)': 1711.5040867831904,
#  '(7,2.0,0.1)': 1728.0709277021153,
#  '(7,2.0,1.0)': 1732.1570849864013,
#  '(7,2.0,10.0)': 1761.7521766265265,
#  '(7,2.0,100.0)': 1810.2282964685255,
#  '(7,2.0,1000.0)': 1824.7381924966296,
#  '(7,2.0,10000.0)': 1827.1624249060339,
#  '(7,2.5,0.001)': 24478.393835545136,
#  '(7,2.5,0.01)': 1714.2975537998148,
#  '(7,2.5,0.1)': 1729.7421023708466,
#  '(7,2.5,1.0)': 1733.3473982570883,
#  '(7,2.5,10.0)': 1752.5807333741741,
#  '(7,2.5,100.0)': 1845.0838347295269,
#  '(7,2.5,1000.0)': 1896.8199445692874,
#  '(7,2.5,10000.0)': 1905.4090275847104,
#  '(7,3.0,0.001)': 24482.603531382407,
#  '(7,3.0,0.01)': 19869.225392123055,
#  '(7,3.0,0.1)': 1730.6814920743602,
#  '(7,3.0,1.0)': 1735.035623682071,
#  '(7,3.0,10.0)': 1744.8117857763882,
#  '(7,3.0,100.0)': 1848.0784987987099,
#  '(7,3.0,1000.0)': 1976.9709480783679,
#  '(7,3.0,10000.0)': 2002.7994424299166,
#  '(8,0.5,0.001)': 1632.6282984278739,
#  '(8,0.5,0.01)': 1621.0375654573863,
#  '(8,0.5,0.1)': 1613.0393211190558,
#  '(8,0.5,1.0)': 1612.2350272879967,
#  '(8,0.5,10.0)': 1612.6793675000124,
#  '(8,0.5,100.0)': 1612.6794088494701,
#  '(8,0.5,1000.0)': 1612.6793254485799,
#  '(8,0.5,10000.0)': 1612.67932839065,
#  '(8,1.0,0.001)': 1664.7951937097453,
#  '(8,1.0,0.01)': 1669.0896961939168,
#  '(8,1.0,0.1)': 1672.3757591444607,
#  '(8,1.0,1.0)': 1705.8099952699811,
#  '(8,1.0,10.0)': 1722.473881322657,
#  '(8,1.0,100.0)': 1724.1748530397736,
#  '(8,1.0,1000.0)': 1724.2482680510122,
#  '(8,1.0,10000.0)': 1723.6333435018043,
#  '(8,1.5,0.001)': 25754.049341965219,
#  '(8,1.5,0.01)': 1683.5893077086068,
#  '(8,1.5,0.1)': 1692.5472532000997,
#  '(8,1.5,1.0)': 1704.7233771410113,
#  '(8,1.5,10.0)': 1735.6069222659287,
#  '(8,1.5,100.0)': 1742.1154453599822,
#  '(8,1.5,1000.0)': 1744.3900190515294,
#  '(8,1.5,10000.0)': 1744.4471356877536,
#  '(8,2.0,0.001)': 28104.178144877093,
#  '(8,2.0,0.01)': 10984.921730167882,
#  '(8,2.0,0.1)': 1703.8917422310635,
#  '(8,2.0,1.0)': 1717.3070813529459,
#  '(8,2.0,10.0)': 1729.5974632919731,
#  '(8,2.0,100.0)': 1757.3215940965183,
#  '(8,2.0,1000.0)': 1775.139195911265,
#  '(8,2.0,10000.0)': 1776.3985765828177,
#  '(8,2.5,0.001)': 34803.376989196833,
#  '(8,2.5,0.01)': 16408.192557170154,
#  '(8,2.5,0.1)': 1706.4433219155133,
#  '(8,2.5,1.0)': 1721.4583961154206,
#  '(8,2.5,10.0)': 1730.0585889132763,
#  '(8,2.5,100.0)': 1758.4829766065311,
#  '(8,2.5,1000.0)': 1808.1406123214338,
#  '(8,2.5,10000.0)': 1821.9907232110211,
#  '(8,3.0,0.001)': 34617.46959782223,
#  '(8,3.0,0.01)': 20611.084989083283,
#  '(8,3.0,0.1)': 1712.0469568696108,
#  '(8,3.0,1.0)': 1726.7873035746763,
#  '(8,3.0,10.0)': 1730.5795368927456,
#  '(8,3.0,100.0)': 1749.6251825304232,
#  '(8,3.0,1000.0)': 1829.851610325042,
#  '(8,3.0,10000.0)': 1879.9784828965476}
