# %%
# %run ../Python_files/util.py

# %%
tmc_ref_speed_dict =zload('../temp_files/tmc_ref_speed_dict.pkz')

# %%
tmc_ref_speed_dict.keys
# Out:
# <function keys>

# %%
# AM: 7:00 am - 9:00 am
# MD: 11:00 am - 13:00 pm
# PM: 17:00 pm - 19:00 pm
# NT: 21:00 pm - 23:00 pm

# %%
class TMC_Day_Speed(object):
    def __init__(self, tmc, day, speed, travel_time):
        self.tmc = tmc
        self.day = day
        self.speed = speed
        self.travel_time = travel_time
    def ave_speed(self):
        return sum([self.speed[i] * self.travel_time[i] for i in range(len(self.speed))]) / sum(self.travel_time)

# %%
data_folder = '/home/jzh/INRIX/All_INRIX_2012_filtered/'

# %%
tmc_day_speed_dict = {}

import glob


i = 0
for f_name in glob.glob(data_folder + 'Jul_MD/' + '*'):

    i = i + 1
    
    df = load(f_name)

    tmc = list(df.loc[:,'tmc'])[0]
    day = list(df.loc[:,'day'])[0]
    speed = list(df.loc[:,'speed'])
    travel_time = list(df.loc[:,'travel_time'])

    tmc_day_speed = TMC_Day_Speed(tmc, day, speed, travel_time)

    tmc_day_speed_dict[tmc + str(day)] = tmc_day_speed
    
    if i % 500 == 0:
        print "%d TMC-day pairs have been put into the dictionary" %i
# Out:
# 500 TMC-day pairs have been put into the dictionary
# 1000 TMC-day pairs have been put into the dictionary
# 1500 TMC-day pairs have been put into the dictionary
# 2000 TMC-day pairs have been put into the dictionary
# 2500 TMC-day pairs have been put into the dictionary
# 3000 TMC-day pairs have been put into the dictionary
# 3500 TMC-day pairs have been put into the dictionary
# 4000 TMC-day pairs have been put into the dictionary
# 4500 TMC-day pairs have been put into the dictionary
# 5000 TMC-day pairs have been put into the dictionary
# 5500 TMC-day pairs have been put into the dictionary
# 6000 TMC-day pairs have been put into the dictionary
# 6500 TMC-day pairs have been put into the dictionary
# 7000 TMC-day pairs have been put into the dictionary
# 7500 TMC-day pairs have been put into the dictionary
# 8000 TMC-day pairs have been put into the dictionary
# 8500 TMC-day pairs have been put into the dictionary
# 9000 TMC-day pairs have been put into the dictionary
# 9500 TMC-day pairs have been put into the dictionary
# 10000 TMC-day pairs have been put into the dictionary
# 10500 TMC-day pairs have been put into the dictionary
# 11000 TMC-day pairs have been put into the dictionary
# 11500 TMC-day pairs have been put into the dictionary
# 12000 TMC-day pairs have been put into the dictionary
# 12500 TMC-day pairs have been put into the dictionary
# 13000 TMC-day pairs have been put into the dictionary
# 13500 TMC-day pairs have been put into the dictionary
# 14000 TMC-day pairs have been put into the dictionary
# 14500 TMC-day pairs have been put into the dictionary
# 15000 TMC-day pairs have been put into the dictionary
# 15500 TMC-day pairs have been put into the dictionary
# 16000 TMC-day pairs have been put into the dictionary
# 16500 TMC-day pairs have been put into the dictionary
# 17000 TMC-day pairs have been put into the dictionary
# 17500 TMC-day pairs have been put into the dictionary
# 18000 TMC-day pairs have been put into the dictionary
# 18500 TMC-day pairs have been put into the dictionary
# 19000 TMC-day pairs have been put into the dictionary
# 19500 TMC-day pairs have been put into the dictionary
# 20000 TMC-day pairs have been put into the dictionary
# 20500 TMC-day pairs have been put into the dictionary
# 21000 TMC-day pairs have been put into the dictionary
# 21500 TMC-day pairs have been put into the dictionary

# %%
zdump(tmc_day_speed_dict, '../temp_files/Jul_MD/tmc_day_speed_dict.pkz')

# %%
df
# Out:
#               tmc  month  day  dow  hour  speed  travel_time
# 142771  129N04114      7    1    6    11     57         0.22
# 250799  129N04114      7    1    6    11     63         0.20
# 128601  129N04114      7    1    6    11     63         0.20
# 142753  129N04114      7    1    6    12     51         0.25
# 41024   129N04114      7    1    6    11     57         0.22
# 258331  129N04114      7    1    6    12     56         0.22
# 128663  129N04114      7    1    6    12     53         0.24
# 143090  129N04114      7    1    6    11     60         0.21
# 128615  129N04114      7    1    6    11     57         0.22
# 194434  129N04114      7    1    6    11     55         0.23
# 41295   129N04114      7    1    6    11     57         0.22
# 259301  129N04114      7    1    6    12     49         0.26
# 142898  129N04114      7    1    6    12     55         0.23
# 41150   129N04114      7    1    6    11     60         0.21
# 257799  129N04114      7    1    6    12     48         0.26
# 128725  129N04114      7    1    6    12     52         0.24
# 194482  129N04114      7    1    6    11     60         0.21
# 129292  129N04114      7    1    6    11     54         0.23
# 251449  129N04114      7    1    6    11     43         0.29
# 252703  129N04114      7    1    6    11     63         0.20
# 260185  129N04114      7    1    6    12     51         0.25
# 259055  129N04114      7    1    6    12     53         0.24
# 194126  129N04114      7    1    6    11     42         0.30
# 251070  129N04114      7    1    6    11     51         0.25
# 129009  129N04114      7    1    6    12     49         0.26
# 143023  129N04114      7    1    6    11     57         0.22
# 258830  129N04114      7    1    6    12     64         0.20
# 142800  129N04114      7    1    6    12     58         0.22
# 250679  129N04114      7    1    6    11     63         0.20
# 41084   129N04114      7    1    6    12     51         0.25
# ...           ...    ...  ...  ...   ...    ...          ...
# 193883  129N04114      7    1    6    12     56         0.22
# 193911  129N04114      7    1    6    12     57         0.22
# 258408  129N04114      7    1    6    12     57         0.22
# 41531   129N04114      7    1    6    12     53         0.24
# 143321  129N04114      7    1    6    11     60         0.21
# 143322  129N04114      7    1    6    12     55         0.23
# 41596   129N04114      7    1    6    12     49         0.26
# 251592  129N04114      7    1    6    11     57         0.22
# 41113   129N04114      7    1    6    11     55         0.23
# 142924  129N04114      7    1    6    11     63         0.20
# 194078  129N04114      7    1    6    12     57         0.22
# 259067  129N04114      7    1    6    12     57         0.22
# 143156  129N04114      7    1    6    11     55         0.23
# 258687  129N04114      7    1    6    12     64         0.20
# 128758  129N04114      7    1    6    12     59         0.21
# 143015  129N04114      7    1    6    11     52         0.24
# 258642  129N04114      7    1    6    12     64         0.20
# 194364  129N04114      7    1    6    11     63         0.20
# 41261   129N04114      7    1    6    12     56         0.22
# 143102  129N04114      7    1    6    11     62         0.20
# 194670  129N04114      7    1    6    11     57         0.22
# 251761  129N04114      7    1    6    11     60         0.21
# 41316   129N04114      7    1    6    11     52         0.24
# 41317   129N04114      7    1    6    11     51         0.25
# 251113  129N04114      7    1    6    11     57         0.22
# 143483  129N04114      7    1    6    11     57         0.22
# 41162   129N04114      7    1    6    11     57         0.22
# 251793  129N04114      7    1    6    11     54         0.23
# 128818  129N04114      7    1    6    11     57         0.22
# 194414  129N04114      7    1    6    11     60         0.21
#
# [120 rows x 7 columns]

# %%
tmc_day_speed_dict['129N041141'].ave_speed()
# Out:
# 55.970293353137741
