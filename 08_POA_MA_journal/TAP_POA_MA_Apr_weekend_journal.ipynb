# %%
using JSON
using JuMP

poaDictAprWeekend = Dict{}()

using PyCall

unshift!(PyVector(pyimport("sys")["path"]), "");
@pyimport GLS_Apr_weekend_ext

# %%
function POA_MA_Apr_weekend_ext(day)

    #load OD pair-route incidence
    odPairRoute = readall("od_pair_route_incidence_MA_ext.json");
    odPairRoute = JSON.parse(odPairRoute);

    #load link-route incidence
    linkRoute = readall("link_route_incidence_MA_ext.json");
    linkRoute = JSON.parse(linkRoute);

    #load OD pair labels
    odPairLabel = readall("od_pair_label_dict_MA_refined_ext.json");
    odPairLabel = JSON.parse(odPairLabel);

    odPairLabel_ = readall("od_pair_label_dict__MA_refined_ext.json");
    odPairLabel_ = JSON.parse(odPairLabel_);

    #load link labels
    linkLabel = readall("link_label_dict_MA_ext.json");
    linkLabel = JSON.parse(linkLabel);

    linkLabel_ = readall("link_label_dict_MA__ext.json");
    linkLabel_ = JSON.parse(linkLabel_);

    #load node-link incidence
    nodeLink = readall("node_link_incidence_MA_ext.json");
    nodeLink = JSON.parse(nodeLink);

    include("load_network_uni-class.jl")

    ta_data = load_ta_network("MA_Apr_weekend_ext");

    capacity = ta_data.capacity;
    free_flow_time = ta_data.free_flow_time;

    demandsDict = readall("../08_develop_new_OD_demand_estimator_MA_Dijkstra_uni_class_Apr_weekend/results/demandsDictFixed$(day).json");
    demandsDict = JSON.parse(demandsDict);

    # demands = demandsDict["$(length(demandsDict)-1)"]

    demands = demandsDict

    odPairLabel_;

    demandsVec = zeros(462)

    for i = 1:length(demandsVec)
        demandsVec[i] = demands["($(odPairLabel_["$i"][1]),$(odPairLabel_["$i"][2]))"]
    end

    demandsVec

    for key=keys(odPairRoute)
        if contains(key, "462-")
            println(key)
        end
    end

    linkRoute

    deg = 6
    c = 0.5
    lam = 10000.0

    coeffs_dict = readall("../temp_files/coeffs_dict_Apr_weekend.json")
    coeffs_dict = JSON.parse(coeffs_dict)
    fcoeffs = coeffs_dict["($(deg),$(c),$(lam),1)"]

    # fcoeffs = [1, 0, 0, 0, 0, 0, 0, 0, 0]

    # m = Model(solver=GurobiSolver(OutputFlag=false))
    m = Model()

    numLinks = 74
    numRoute = 4614
    numOD = 462

    @defVar(m, linkFlow[1:numLinks])
    @defVar(m, pathFlow[1:numRoute])

    pathFlowSum = Dict()

    for i=1:numOD
        pathFlowSum[i] = 0
        for j=1:numRoute
            if "$(i)-$(j)" in keys(odPairRoute)
                pathFlowSum[i] += pathFlow[j]
            end
        end
        @addConstraint(m, pathFlowSum[i] == demandsVec[i])
    end

    pathFlowLinkSum = Dict()

    for a=1:numLinks
        pathFlowLinkSum[a] = 0
        for j=1:numRoute
            if "$(a)-$(j)" in keys(linkRoute)
                pathFlowLinkSum[a] += pathFlow[j]
            end
        end
        @addConstraint(m, pathFlowLinkSum[a] == linkFlow[a])
    end

    for j=1:numRoute
        @addConstraint(m, pathFlow[j] >= 0)
    end

    @defNLExpr(f, sum{free_flow_time[a] * fcoeffs[1] * linkFlow[a] + 
        free_flow_time[a] * fcoeffs[2] * linkFlow[a]^2 / capacity[a] +
        free_flow_time[a] * fcoeffs[3] * linkFlow[a]^3 / capacity[a]^2 +
        free_flow_time[a] * fcoeffs[4] * linkFlow[a]^4 / capacity[a]^3 +
        free_flow_time[a] * fcoeffs[5] * linkFlow[a]^5 / capacity[a]^4 +
        free_flow_time[a] * fcoeffs[6] * linkFlow[a]^6 / capacity[a]^5 +
        free_flow_time[a] * fcoeffs[7] * linkFlow[a]^7 / capacity[a]^6, a = 1:numLinks})

    @setNLObjective(m, Min, f)

    solve(m)

    getValue(linkFlow)

    getObjectiveValue(m)

    flows = Dict{(Int64,Int64),Float64}()

    for i = 1:length(ta_data.start_node)
        key = (ta_data.start_node[i], ta_data.end_node[i])
        flows[key] = getValue(linkFlow)[i]
    end

    flows

    flow_user = GLS_Apr_weekend_ext.x_

    function socialObj(linkFlowVec)
        objVal = sum([free_flow_time[a] * fcoeffs[1] * linkFlowVec[a] + 
            free_flow_time[a] * fcoeffs[2] * linkFlowVec[a]^2 / capacity[a] + 
            free_flow_time[a] * fcoeffs[3] * linkFlowVec[a]^3 / capacity[a]^2 + 
            free_flow_time[a] * fcoeffs[4] * linkFlowVec[a]^4 / capacity[a]^3 + 
            free_flow_time[a] * fcoeffs[5] * linkFlowVec[a]^5 / capacity[a]^4 + 
            free_flow_time[a] * fcoeffs[6] * linkFlowVec[a]^6 / capacity[a]^5 + 
            free_flow_time[a] * fcoeffs[7] * linkFlowVec[a]^7 / capacity[a]^6 for a = 1:numLinks])
        return objVal
    end
    
    return socialObj(flow_user[:, day])/getObjectiveValue(m)
    
end
# Out:
# POA_MA_Apr_weekend_ext (generic function with 1 method)

# %%
function POA_MA_Apr_weekend_ext_alt(day)
    
    #load OD pair-route incidence
    odPairRoute = readall("od_pair_route_incidence_MA_ext.json");
    odPairRoute = JSON.parse(odPairRoute);

    #load link-route incidence
    linkRoute = readall("link_route_incidence_MA_ext.json");
    linkRoute = JSON.parse(linkRoute);

    #load OD pair labels
    odPairLabel = readall("od_pair_label_dict_MA_refined_ext.json");
    odPairLabel = JSON.parse(odPairLabel);

    odPairLabel_ = readall("od_pair_label_dict__MA_refined_ext.json");
    odPairLabel_ = JSON.parse(odPairLabel_);

    #load link labels
    linkLabel = readall("link_label_dict_MA_ext.json");
    linkLabel = JSON.parse(linkLabel);

    linkLabel_ = readall("link_label_dict_MA__ext.json");
    linkLabel_ = JSON.parse(linkLabel_);

    #load node-link incidence
    nodeLink = readall("node_link_incidence_MA_ext.json");
    nodeLink = JSON.parse(nodeLink);

    include("load_network_uni-class.jl")

    ta_data = load_ta_network("MA");

    capacity = ta_data.capacity;
    free_flow_time = ta_data.free_flow_time;

    demandsDict = readall("../08_develop_new_OD_demand_estimator_MA_Dijkstra_uni_class_Apr_weekend/results/demandsDictFixed$(day).json");
    demandsDict = JSON.parse(demandsDict);

    # demands = demandsDict["$(length(demandsDict)-1)"]

    demands = demandsDict
    
    demands_ = Dict{}()

    for key in keys(demands)
        key_ = (int(split(split(key, ',')[1], '(')[2]),int(split(split(key, ',')[2], ')')[1]))
        demands_[key_] = demands[key]
    end

    odPairLabel_;

    demandsVec = zeros(462)

    for i = 1:length(demandsVec)
        demandsVec[i] = demands["($(odPairLabel_["$i"][1]),$(odPairLabel_["$i"][2]))"]
    end

    demandsVec

    for key=keys(odPairRoute)
        if contains(key, "462-")
            println(key)
        end
    end

    linkRoute;

    deg = 6
    c = 0.5
    lam = 10000.0

    coeffs_dict_Apr_weekend_ = readall("../temp_files/coeffs_dict_Apr_weekend.json")
    coeffs_dict_Apr_weekend_ = JSON.parse(coeffs_dict_Apr_weekend_)
    fcoeffs = coeffs_dict_Apr_weekend_["($(deg),$(c),$(lam),1)"]

    # fcoeffs = [1, 0, 0, 0, .15]
    
    # m = Model(solver=GurobiSolver(OutputFlag=false))
    m = Model()

    numLinks = 74  # number of links
    numNodes = 22  # number of nodes

    @defVar(m, linkFlow[1:numLinks])

    @defVar(m, odLinkFlow[keys(demands_), 1:numLinks])
    for (s,t) = keys(demands_)
        for k = 1:numLinks
            @addConstraint(m, odLinkFlow[(s,t), k] >= 0)
        end
    end

    for k = 1:numLinks
        linkFlowPartial = sum([odLinkFlow[(s,t), k] for (s,t) = keys(demands_)])
        @addConstraint(m, linkFlowPartial == linkFlow[k])
    end

    for l = 1:numNodes
        for (s,t) = keys(demands_)
            if s != t
                odLinkFlowPartial = sum([nodeLink["$(l-1)-$(k-1)"] * odLinkFlow[(s,t), k] for k = 1:numLinks])
                if (l == s)
                    @addConstraint(m, odLinkFlowPartial + demands_[(s,t)] == 0)
                elseif (l == t)
                    @addConstraint(m, odLinkFlowPartial - demands_[(s,t)] == 0)
                else
                    @addConstraint(m, odLinkFlowPartial == 0)
                end
            end
        end
    end

    @defNLExpr(f, sum{free_flow_time[a] * fcoeffs[1] * linkFlow[a] + 
        free_flow_time[a] * fcoeffs[2] * linkFlow[a]^2 / capacity[a] +
        free_flow_time[a] * fcoeffs[3] * linkFlow[a]^3 / capacity[a]^2 +
        free_flow_time[a] * fcoeffs[4] * linkFlow[a]^4 / capacity[a]^3 +
        free_flow_time[a] * fcoeffs[5] * linkFlow[a]^5 / capacity[a]^4 +
        free_flow_time[a] * fcoeffs[6] * linkFlow[a]^6 / capacity[a]^5 +
        free_flow_time[a] * fcoeffs[7] * linkFlow[a]^7 / capacity[a]^6, a = 1:numLinks})

    @setNLObjective(m, Min, f)

    solve(m)

    println(getValue(linkFlow))

    getObjectiveValue(m)

    flows = Dict{(Int64,Int64),Float64}()

    for i = 1:length(ta_data.start_node)
        key = (ta_data.start_node[i], ta_data.end_node[i])
        flows[key] = getValue(linkFlow)[i]
    end

    flows

    # getValue(linkFlow)

    # getObjectiveValue(m)

    flow_user = GLS_Apr_weekend_ext.x_

    function socialObj(linkFlowVec)
        objVal = sum([free_flow_time[a] * fcoeffs[1] * linkFlowVec[a] + 
            free_flow_time[a] * fcoeffs[2] * linkFlowVec[a]^2 / capacity[a] + 
            free_flow_time[a] * fcoeffs[3] * linkFlowVec[a]^3 / capacity[a]^2 + 
            free_flow_time[a] * fcoeffs[4] * linkFlowVec[a]^4 / capacity[a]^3 + 
            free_flow_time[a] * fcoeffs[5] * linkFlowVec[a]^5 / capacity[a]^4 + 
            free_flow_time[a] * fcoeffs[6] * linkFlowVec[a]^6 / capacity[a]^5 + 
            free_flow_time[a] * fcoeffs[7] * linkFlowVec[a]^7 / capacity[a]^6 for a = 1:numLinks])
        return objVal
    end
    
    println(socialObj(flow_user[:, day])/getObjectiveValue(m))
    
    return socialObj(flow_user[:, day])/getObjectiveValue(m)
end
# Out:
# POA_MA_Apr_weekend_ext_alt (generic function with 1 method)

# %%
weekend_Apr_list = [1, 7, 8, 14, 15, 21, 22, 28, 29]
# weekend_Apr_list = [29]
# Out:
# 9-element Array{Int64,1}:
#   1
#   7
#   8
#  14
#  15
#  21
#  22
#  28
#  29

# %%
for day in weekend_Apr_list
    poaDictAprWeekend[day] = POA_MA_Apr_weekend_ext_alt(day)
end
# Out:
# 462-329
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.12.1, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:   104266
# Number of nonzeros in inequality constraint Jacobian.:    35816
# Number of nonzeros in Lagrangian Hessian.............:       74
#
# Total number of variables............................:    35890
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:    10238
# Total number of inequality constraints...............:    35816
#         inequality constraints with only lower bounds:    35816
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 1.43e+03 1.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  2.1604961e-02 1.43e+03 1.00e+00  -1.0 3.27e+02    -  3.13e-05 3.13e-05h  1
#    2  5.7547777e-01 1.43e+03 2.31e+00  -1.0 2.05e+03    -  1.45e-05 1.24e-04h  1
#    3  2.5486511e+00 1.43e+03 2.91e+00  -1.0 2.76e+03    -  9.50e-05 2.56e-04h  1
#    4  9.7345647e+00 1.43e+03 3.13e+00  -1.0 3.12e+03    -  1.98e-04 7.54e-04f  1
#    5  2.9033693e+01 1.43e+03 3.28e+00  -1.0 3.31e+03    -  5.93e-04 1.87e-03f  1
#    6  8.9491650e+01 1.42e+03 3.33e+00  -1.0 3.35e+03    -  1.55e-03 5.76e-03f  1
#    7  3.2709467e+02 1.39e+03 3.65e+00  -1.0 3.31e+03    -  5.20e-03 2.28e-02f  1
#    8  1.3497531e+03 1.25e+03 3.94e+00  -1.0 3.11e+03    -  1.95e-02 1.01e-01f  1
#    9  1.9746094e+03 1.16e+03 3.67e+00  -1.0 2.25e+03    -  3.92e-02 7.16e-02f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  2.6095958e+03 1.07e+03 3.39e+00  -1.0 2.09e+03    -  9.05e-02 7.81e-02f  1
#   11  3.9592962e+03 8.77e+02 2.79e+00  -1.0 1.93e+03    -  8.12e-02 1.79e-01f  1
#   12  5.9253245e+03 6.06e+02 1.93e+00  -1.0 1.59e+03    -  1.27e-01 3.09e-01h  1
#   13  8.0256145e+03 3.32e+02 1.07e+00  -1.0 1.13e+03    -  1.10e-01 4.53e-01h  1
#   14  9.5039176e+03 1.57e+02 5.03e-01  -1.0 6.43e+02    -  5.57e-01 5.27e-01h  1
#   15  1.0277485e+04 9.05e+01 3.88e-01  -1.0 3.58e+02    -  8.26e-02 4.22e-01f  1
#   16  1.0274353e+04 6.42e+01 4.00e-01  -1.0 3.03e+03    -  8.44e-03 2.91e-01f  1
#   17  1.0205108e+04 6.37e+01 3.93e-01  -1.0 2.52e+04    -  1.65e-02 7.57e-03f  1
#   18  1.0191517e+04 6.35e+01 3.82e-01  -1.0 1.11e+04    -  2.61e-02 3.12e-03f  1
#   19  1.0141337e+04 6.25e+01 3.62e-01  -1.0 1.35e+04    -  4.77e-02 1.53e-02f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20  1.0133248e+04 6.18e+01 3.39e-01  -1.0 4.74e+03    -  5.87e-02 1.22e-02f  1
#   21  1.0113101e+04 5.90e+01 3.39e-01  -1.0 4.88e+03    -  5.85e-03 4.45e-02f  1
#   22  1.0115176e+04 5.88e+01 3.21e-01  -1.0 1.14e+03    -  4.83e-02 4.11e-03f  1
#   23  1.0130727e+04 5.70e+01 3.05e-01  -1.0 1.72e+03    -  4.61e-02 3.06e-02f  1
#   24  1.0186116e+04 5.15e+01 2.95e-01  -1.0 1.39e+03    -  3.93e-02 9.70e-02f  1
#   25  1.0147426e+04 4.83e+01 2.91e-01  -1.0 5.64e+03    -  2.12e-02 6.18e-02f  1
#   26  1.0141431e+04 4.80e+01 2.81e-01  -1.0 3.39e+03    -  3.17e-02 6.22e-03f  1
#   27  1.0034277e+04 4.67e+01 2.80e-01  -1.0 1.36e+04    -  4.96e-03 2.71e-02f  1
#   28  1.0013156e+04 4.65e+01 2.75e-01  -1.0 2.33e+04    -  1.64e-02 3.84e-03f  1
#   29  1.0002661e+04 4.60e+01 2.63e-01  -1.0 4.25e+03    -  4.03e-02 1.02e-02f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   30  9.9566472e+03 4.46e+01 2.62e-01  -1.0 8.67e+03    -  5.85e-03 3.10e-02f  1
#   31  9.7283366e+03 4.11e+01 2.58e-01  -1.0 1.22e+04    -  2.04e-02 7.87e-02f  1
#   32  9.6181593e+03 4.08e+01 2.55e-01  -1.0 3.54e+04    -  1.11e-02 7.70e-03f  1
#   33  9.5648213e+03 4.06e+01 2.54e-01  -1.0 3.02e+04    -  5.61e-03 4.53e-03f  1
#   34  9.5510971e+03 4.04e+01 2.04e-01  -1.0 1.66e+04    -  1.82e-01 4.18e-03f  1
#   35  9.6580628e+03 3.48e+01 1.98e-01  -1.0 9.73e+02    -  3.92e-02 1.40e-01f  1
#   36  9.6639805e+03 3.41e+01 1.90e-01  -1.0 3.36e+03    -  3.66e-02 1.97e-02f  1
#   37  9.6940471e+03 3.22e+01 1.86e-01  -1.0 2.34e+03    -  2.68e-02 5.36e-02f  1
#   38  9.7040948e+03 3.17e+01 1.62e-01  -1.0 2.30e+03    -  5.49e-01 1.83e-02f  1
#   39  9.9064191e+03 2.53e+01 1.23e-01  -1.0 4.34e+02    -  6.50e-02 2.01e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   40  1.0353260e+04 1.23e+01 6.85e-02  -1.0 5.20e+02    -  1.77e-01 5.12e-01f  1
#   41  1.0391796e+04 1.13e+01 6.43e-02  -1.0 2.26e+03    -  6.80e-02 8.21e-02f  1
#   42  1.0470152e+04 9.64e+00 7.24e-02  -1.0 2.60e+02    -  8.87e-01 1.49e-01f  1
#   43  1.0977212e+04 1.23e+00 3.19e-02  -1.0 5.95e+02    -  2.70e-01 8.73e-01f  1
#   44  1.1069684e+04 1.42e-10 1.00e-06  -1.0 7.47e+01    -  1.00e+00 1.00e+00h  1
#   45  8.3002613e+03 3.14e-10 1.67e-02  -1.7 8.14e+02    -  7.95e-01 9.91e-01f  1
#   46  7.7908787e+03 4.05e-10 3.30e-02  -2.5 1.76e+02    -  5.72e-01 8.04e-01f  1
#   47  7.6654944e+03 4.77e-10 3.77e-02  -2.5 4.48e+01    -  6.93e-01 1.00e+00f  1
#   48  7.6649673e+03 7.81e-11 2.83e-08  -2.5 7.34e+00    -  1.00e+00 1.00e+00f  1
#   49  7.5836397e+03 6.66e-11 5.05e-03  -3.8 2.32e+01    -  7.24e-01 8.64e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   50  7.5707434e+03 6.70e-11 8.27e-03  -3.8 7.45e+00    -  8.80e-01 1.00e+00f  1
#   51  7.5707382e+03 8.99e-11 1.50e-09  -3.8 1.51e+00    -  1.00e+00 1.00e+00f  1
#   52  7.5664075e+03 3.49e-11 1.04e-02  -5.7 1.90e+00    -  7.02e-01 8.28e-01f  1
#   53  7.5655671e+03 2.42e-11 4.23e-02  -5.7 3.70e-01    -  5.15e-01 9.35e-01f  1
#   54  7.5655084e+03 2.30e-11 4.01e-03  -5.7 2.70e-02    -  6.85e-01 1.00e+00f  1
#   55  7.5655084e+03 2.25e-11 1.84e-11  -5.7 2.14e-04    -  1.00e+00 1.00e+00h  1
#   56  7.5654436e+03 3.34e-11 2.39e-05  -8.6 2.48e-02    -  9.67e-01 9.99e-01f  1
#   57  7.5654435e+03 2.86e-11 2.51e-14  -8.6 2.89e-05    -  1.00e+00 1.00e+00f  1
#
# Number of Iterations....: 57
#
#                                    (scaled)                 (unscaled)
# Objective...............:   7.5654435384542649e+03    7.5654435384542649e+03
# Dual infeasibility......:   2.5091040356528538e-14    2.5091040356528538e-14
# Constraint violation....:   2.8581845764019342e-11    2.8581845764019342e-11
# Complementarity.........:   2.5909890166771052e-09    2.5909890166771052e-09
# Overall NLP error.......:   2.5909890166771052e-09    2.5909890166771052e-09
#
#
# Number of objective function evaluations             = 58
# Number of objective gradient evaluations             = 58
# Number of equality constraint evaluations            = 58
# Number of inequality constraint evaluations          = 58
# Number of equality constraint Jacobian evaluations   = 58
# Number of inequality constraint Jacobian evaluations = 58
# Number of Lagrangian Hessian evaluations             = 57
# Total CPU secs in IPOPT (w/o function evaluations)   =     19.060
# Total CPU secs in NLP function evaluations           =      0.240
#
# EXIT: Optimal Solution Found.
# [1079.3229143934852,1156.3856144548722,316.7488240161525,303.0397849750758,87.23556250506657,-7.234700569895362e-7,1181.6841724238445,1185.7150789064399,1252.052084727521,874.3130265890242,350.4341315803717,478.7121086958229,-1.507114724208855e-6,-1.3159091531941285e-6,1246.8361961185321,1303.3273147265202,1434.9509812425306,1464.0664985472158,1177.761991231981,1301.0919820332722,647.7832330113314,301.69113476714597,1210.0923102837262,1431.991780186899,-9.979587213611453e-7,-8.693850155807144e-7,1459.5351199249255,1898.7261674068702,1534.667640769732,1999.9583504322654,1450.3888198531529,1886.3843076955884,30.52522588087804,11.484294174807879,29.311715228974972,97.95788070361931,1087.6359803376756,1397.5210029270918,1570.1832075607833,1895.0401566042872,1392.3319511227442,1938.6406506082235,-2.24479740389564e-6,-2.218874345766661e-6,1371.3062736187348,1370.9074793953673,1015.9545454664787,967.2099716053438,228.70953500019903,21.947569863618963,179.87021115454093,75.12904359347722,1202.635727300301,1080.5661073134013,74.80209662922624,13.065901393582523,64.76903378539738,36.331127562481534,1138.5395997667713,760.0081673557582,-1.719744196519443e-6,-2.190691195698356e-6,2011.7993208181808,1457.4347922067584,-1.5728226666012543e-6,-1.6437139814384707e-6,1837.3249373956714,1804.3377659531027,871.608107628489,874.9470204548225,873.882870565836,578.7115507097529,1161.2026950670966,746.1997433792264]
# 1.180722607748575
# 462-329
# This is Ipopt version 3.12.1, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:   104266
# Number of nonzeros in inequality constraint Jacobian.:    35816
# Number of nonzeros in Lagrangian Hessian.............:       74
#
# Total number of variables............................:    35890
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:    10238
# Total number of inequality constraints...............:    35816
#         inequality constraints with only lower bounds:    35816
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 1.32e+03 1.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  2.3717981e-02 1.32e+03 1.00e+00  -1.0 2.90e+02    -  3.41e-05 3.42e-05h  1
#    2  5.3915015e-01 1.32e+03 2.32e+00  -1.0 1.75e+03    -  1.56e-05 1.34e-04h  1
#    3  2.2698401e+00 1.32e+03 2.91e+00  -1.0 2.23e+03    -  1.01e-04 2.77e-04h  1
#    4  8.4868828e+00 1.32e+03 3.14e+00  -1.0 2.42e+03    -  2.25e-04 8.30e-04f  1
#    5  2.8030576e+01 1.32e+03 3.39e+00  -1.0 2.55e+03    -  6.40e-04 2.46e-03f  1
#    6  8.0032588e+01 1.31e+03 3.53e+00  -1.0 2.57e+03    -  1.91e-03 6.49e-03f  1
#    7  3.0478423e+02 1.27e+03 3.77e+00  -1.0 2.53e+03    -  4.89e-03 2.84e-02f  1
#    8  7.9893423e+03 2.72e-07 1.94e+01  -1.0 2.37e+03    -  2.45e-02 1.00e+00h  1
#    9  7.9186022e+03 2.33e-07 1.81e+01  -1.0 5.06e+03    -  7.61e-02 6.80e-02f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  7.9185817e+03 1.78e-07 1.61e+01  -1.0 7.27e+02    -  2.34e-01 1.08e-01f  1
#   11  8.0528912e+03 4.08e-08 1.09e+01  -1.0 3.85e+02    -  3.65e-01 3.22e-01f  1
#   12  8.3643891e+03 5.60e-08 5.87e+00  -1.0 2.00e+02    -  3.99e-01 4.63e-01f  1
#   13  8.7244288e+03 7.25e-08 3.00e+00  -1.0 2.02e+02    -  7.98e-02 4.83e-01f  1
#   14  8.5382123e+03 6.88e-08 2.58e+00  -1.0 4.86e+03    -  6.69e-03 1.45e-01f  1
#   15  8.4982621e+03 6.87e-08 2.56e+00  -1.0 2.57e+04    -  1.93e-02 4.14e-03f  1
#   16  8.4564159e+03 6.85e-08 2.55e+00  -1.0 1.52e+04    -  3.00e-02 6.41e-03f  1
#   17  8.4291098e+03 6.81e-08 2.53e+00  -1.0 9.03e+03    -  1.30e-01 1.28e-02f  1
#   18  8.4559465e+03 6.65e-08 2.39e+00  -1.0 5.59e+02    -  6.84e-02 5.46e-02f  1
#   19  8.5326852e+03 6.12e-08 1.95e+00  -1.0 6.41e+02    -  4.39e-02 1.79e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20  8.4808171e+03 6.02e-08 1.88e+00  -1.0 5.58e+03    -  1.57e-02 3.35e-02f  1
#   21  8.4630208e+03 6.00e-08 1.87e+00  -1.0 9.48e+03    -  1.10e-02 6.77e-03f  1
#   22  8.4016819e+03 5.96e-08 1.85e+00  -1.0 2.07e+04    -  3.26e-02 1.25e-02f  1
#   23  8.3778929e+03 5.92e-08 1.83e+00  -1.0 8.98e+03    -  1.49e-02 1.07e-02f  1
#   24  8.3595591e+03 5.83e-08 1.78e+00  -1.0 2.93e+03    -  1.90e-02 2.94e-02f  1
#   25  8.1798160e+03 5.66e-08 1.67e+00  -1.0 1.20e+04    -  1.35e-02 5.63e-02f  1
#   26  8.0255683e+03 5.62e-08 1.65e+00  -1.0 2.73e+04    -  1.02e-02 1.37e-02f  1
#   27  8.0008325e+03 5.61e-08 1.65e+00  -1.0 3.90e+04    -  1.94e-02 2.62e-03f  1
#   28  7.9597514e+03 5.59e-08 1.64e+00  -1.0 2.89e+04    -  1.34e-02 6.81e-03f  1
#   29  7.9449669e+03 5.56e-08 1.63e+00  -1.0 9.32e+03    -  1.73e-01 9.82e-03f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   30  8.0626450e+03 5.01e-08 1.33e+00  -1.0 4.57e+02    -  1.12e-01 1.79e-01f  1
#   31  8.0875856e+03 4.88e-08 1.29e+00  -1.0 8.87e+02    -  2.09e-01 4.33e-02f  1
#   32  8.4042454e+03 3.60e-08 7.21e-01  -1.0 2.44e+02    -  5.16e-01 4.42e-01f  1
#   33  7.3347347e+03 1.64e-08 2.65e-01  -1.7 3.82e+02    -  9.17e-02 6.71e-01f  1
#   34  7.2856844e+03 1.55e-08 2.42e-01  -1.7 1.15e+03    -  1.65e-01 6.49e-02f  1
#   35  7.1238172e+03 1.23e-08 1.64e-01  -1.7 1.04e+02    -  8.64e-01 2.34e-01f  1
#   36  6.0222724e+03 1.99e-09 4.40e-02  -2.5 2.74e+02    -  2.27e-01 8.95e-01f  1
#   37  5.9685867e+03 1.35e-09 5.37e-02  -2.5 7.38e+02    -  1.15e-01 3.30e-01f  1
#   38  5.9400591e+03 1.01e-09 2.24e-02  -2.5 3.46e+01    -  4.38e-01 2.62e-01f  1
#   39  5.8944452e+03 7.55e-10 2.68e-02  -3.8 1.35e+02    -  1.03e-01 2.59e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   40  5.8110228e+03 2.82e-10 6.04e-03  -3.8 4.05e+01    -  7.63e-01 6.39e-01f  1
#   41  5.7700485e+03 6.88e-11 3.73e-02  -3.8 1.66e+01    -  8.77e-02 8.43e-01f  1
#   42  5.7623052e+03 3.52e-11 1.02e-02  -3.8 3.77e+00    -  7.62e-01 1.00e+00f  1
#   43  5.7622712e+03 1.79e-11 2.50e-04  -3.8 9.31e-01    -  9.60e-01 1.00e+00f  1
#   44  5.7571019e+03 2.04e-11 1.27e-03  -5.7 1.57e+00    -  6.63e-01 9.82e-01f  1
#   45  5.7570081e+03 2.02e-11 2.92e-04  -5.7 1.11e-01    -  7.90e-01 1.00e+00f  1
#   46  5.7570081e+03 2.24e-11 1.84e-11  -5.7 2.51e-02    -  1.00e+00 1.00e+00h  1
#   47  5.7569428e+03 3.42e-11 3.76e-07  -8.6 1.94e-02    -  9.92e-01 1.00e+00f  1
#   48  5.7569428e+03 1.56e-11 2.51e-14  -8.6 3.51e-05    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 48
#
#                                    (scaled)                 (unscaled)
# Objective...............:   5.7569428492901970e+03    5.7569428492901970e+03
# Dual infeasibility......:   2.5091040356528538e-14    2.5091040356528538e-14
# Constraint violation....:   1.5562019061494731e-11    1.5562019061494731e-11
# Complementarity.........:   2.6606246508415455e-09    2.6606246508415455e-09
# Overall NLP error.......:   2.6606246508415455e-09    2.6606246508415455e-09
#
#
# Number of objective function evaluations             = 49
# Number of objective gradient evaluations             = 49
# Number of equality constraint evaluations            = 49
# Number of inequality constraint evaluations          = 49
# Number of equality constraint Jacobian evaluations   = 49
# Number of inequality constraint Jacobian evaluations = 49
# Number of Lagrangian Hessian evaluations             = 48
# Total CPU secs in IPOPT (w/o function evaluations)   =     16.952
# Total CPU secs in NLP function evaluations           =      0.140
#
# EXIT: Optimal Solution Found.
# [937.2169247593512,992.7517305456798,382.0195999935844,364.2910348919737,133.53906235630942,-1.1313842435507791e-6,957.8579433301444,1011.4130168360605,911.9227983096978,556.8567009925281,199.94866468163892,332.97974836183226,-1.5188922466798371e-6,-1.340618209899262e-6,858.1449390563415,885.4001144316184,1034.3792842786684,1052.2974273225773,877.3069250187873,973.577676945414,435.31991087099817,114.60674141446401,953.5549443539655,1051.2949920018661,-1.0376804750352927e-6,-9.537538610955609e-7,602.8939133502043,1247.0491771915802,1391.9942731575,1631.6699006438223,600.8599095487599,1247.0491718655862,29.362779772481804,30.28509749434788,32.61788784777162,102.89921996464575,896.8329817975249,1083.7956269518274,671.1474871655515,1265.103209197689,1290.827599307838,1631.6699077531148,-2.234585958993575e-6,-2.254635264300952e-6,942.510923503068,942.5109178133337,541.0149366085102,556.5857472244384,287.3160252502651,50.91790529215837,122.40629542345141,117.86944969615016,1101.8168021571996,987.215352168449,34.52709838167849,4.892906633180714,128.66644262622074,96.45547453244228,648.211311405155,540.0480330478218,-1.8498241727098978e-6,-2.1906269467942725e-6,1491.7131896821797,1051.6891862535535,-1.5906578021931787e-6,-1.6503993720259179e-6,1560.8253043943346,1560.8252994463433,807.986401722043,807.8898282767871,574.7729737805734,502.65262982063,807.5948132774644,538.2435559500099]
# 1.1995764980377461
# 462-329
# This is Ipopt version 3.12.1, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:   104266
# Number of nonzeros in inequality constraint Jacobian.:    35816
# Number of nonzeros in Lagrangian Hessian.............:       74
#
# Total number of variables............................:    35890
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:    10238
# Total number of inequality constraints...............:    35816
#         inequality constraints with only lower bounds:    35816
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 1.25e+03 1.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  2.4092949e-02 1.25e+03 1.00e+00  -1.0 2.86e+02    -  3.47e-05 3.47e-05h  1
#    2  6.9914464e-01 1.25e+03 2.29e+00  -1.0 1.86e+03    -  1.72e-05 1.36e-04h  1
#    3  3.2401832e+00 1.25e+03 2.91e+00  -1.0 2.52e+03    -  1.01e-04 2.90e-04h  1
#    4  1.2430976e+01 1.25e+03 3.16e+00  -1.0 2.83e+03    -  2.33e-04 8.46e-04f  1
#    5  3.7620863e+01 1.25e+03 3.29e+00  -1.0 2.99e+03    -  6.62e-04 2.18e-03f  1
#    6  1.0893530e+02 1.24e+03 3.34e+00  -1.0 2.98e+03    -  1.61e-03 6.15e-03f  1
#    7  3.6725620e+02 1.21e+03 3.63e+00  -1.0 2.92e+03    -  5.42e-03 2.26e-02f  1
#    8  2.1124903e+03 1.02e+03 4.70e+00  -1.0 2.76e+03    -  1.92e-02 1.57e-01f  1
#    9  2.7816691e+03 9.46e+02 4.38e+00  -1.0 1.94e+03    -  4.83e-02 7.53e-02f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  3.5027968e+03 8.64e+02 3.99e+00  -1.0 1.96e+03    -  1.10e-01 8.67e-02f  1
#   11  5.0348541e+03 6.91e+02 3.21e+00  -1.0 2.04e+03    -  1.17e-01 2.00e-01h  1
#   12  7.3255313e+03 4.41e+02 2.05e+00  -1.0 1.57e+03    -  2.59e-01 3.62e-01h  1
#   13  1.0281763e+04 1.43e+02 6.69e-01  -1.0 9.64e+02    -  5.20e-01 6.75e-01h  1
#   14  1.1046692e+04 8.87e+01 4.13e-01  -1.0 3.87e+02    -  6.88e-02 3.81e-01f  1
#   15  1.1046511e+04 7.60e+01 3.77e-01  -1.0 3.80e+03    -  6.64e-03 1.44e-01f  1
#   16  1.1008398e+04 7.55e+01 3.70e-01  -1.0 2.11e+04    -  1.72e-02 5.76e-03f  1
#   17  1.1000551e+04 7.52e+01 3.59e-01  -1.0 7.11e+03    -  2.66e-02 5.04e-03f  1
#   18  1.0931299e+04 7.18e+01 3.34e-01  -1.0 9.55e+03    -  7.43e-02 4.46e-02f  1
#   19  1.0893669e+04 7.12e+01 3.32e-01  -1.0 2.05e+04    -  1.89e-02 7.88e-03f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20  1.0873564e+04 7.05e+01 3.28e-01  -1.0 1.13e+04    -  3.76e-03 1.06e-02f  1
#   21  1.0883105e+04 6.98e+01 3.25e-01  -1.0 1.12e+03    -  1.26e-01 9.94e-03f  1
#   22  1.1002735e+04 6.13e+01 2.85e-01  -1.0 9.08e+02    -  3.27e-02 1.22e-01f  1
#   23  1.0949349e+04 5.91e+01 2.75e-01  -1.0 6.94e+03    -  9.58e-03 3.67e-02f  1
#   24  1.0926809e+04 5.87e+01 2.73e-01  -1.0 1.34e+04    -  9.38e-03 6.28e-03f  1
#   25  1.0860536e+04 5.79e+01 2.70e-01  -1.0 2.18e+04    -  2.61e-02 1.27e-02f  1
#   26  1.0845121e+04 5.75e+01 2.68e-01  -1.0 1.10e+04    -  2.13e-02 7.14e-03f  1
#   27  1.0854521e+04 5.60e+01 2.61e-01  -1.0 2.23e+03    -  3.14e-02 2.62e-02f  1
#   28  1.0609721e+04 5.18e+01 2.48e-01  -1.0 1.17e+04    -  3.20e-03 7.47e-02f  1
#   29  1.0568377e+04 5.17e+01 2.45e-01  -1.0 3.65e+04    -  1.22e-02 3.25e-03f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   30  1.0495113e+04 5.13e+01 2.39e-01  -1.0 3.90e+04    -  4.96e-02 6.45e-03f  1
#   31  1.0479112e+04 5.08e+01 2.38e-01  -1.0 1.57e+04    -  1.92e-01 9.41e-03f  1
#   32  1.0529579e+04 4.83e+01 2.26e-01  -1.0 1.10e+03    -  1.41e-02 4.98e-02f  1
#   33  1.0664604e+04 4.21e+01 1.96e-01  -1.0 1.01e+03    -  3.01e-02 1.30e-01f  1
#   34  1.0680992e+04 4.13e+01 2.38e-01  -1.0 8.44e+02    -  5.15e-01 1.69e-02f  1
#   35  1.1169595e+04 2.49e+01 1.22e-01  -1.0 5.37e+02    -  6.10e-02 3.98e-01f  1
#   36  1.1200735e+04 2.39e+01 1.18e-01  -1.0 1.09e+03    -  6.01e-02 4.01e-02f  1
#   37  1.1262121e+04 2.21e+01 1.15e-01  -1.0 5.28e+02    -  1.80e-01 7.28e-02f  1
#   38  1.1333389e+04 2.00e+01 1.01e-01  -1.0 2.69e+03    -  3.10e-02 9.64e-02f  1
#   39  1.1400568e+04 1.83e+01 1.30e-01  -1.0 5.52e+02    -  7.37e-01 8.72e-02f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   40  1.1847660e+04 8.75e+00 6.47e-02  -1.0 4.48e+02    -  6.55e-01 5.21e-01f  1
#   41  1.2232784e+04 1.48e+00 1.33e-02  -1.0 5.74e+02    -  3.22e-01 8.30e-01h  1
#   42  1.2323536e+04 1.16e-10 1.42e-05  -1.0 2.30e+02    -  1.00e+00 1.00e+00h  1
#   43  9.5516558e+03 4.52e-10 1.70e-02  -1.7 8.17e+02    -  7.69e-01 9.92e-01f  1
#   44  9.0402443e+03 3.84e-10 5.23e-02  -2.5 1.86e+02    -  4.82e-01 8.11e-01f  1
#   45  8.9200589e+03 2.63e-10 6.18e-02  -2.5 5.90e+01    -  6.39e-01 1.00e+00f  1
#   46  8.9194837e+03 1.88e-10 3.94e-08  -2.5 1.45e+01    -  1.00e+00 1.00e+00f  1
#   47  8.8389411e+03 1.47e-10 2.00e-02  -3.8 2.78e+01    -  5.05e-01 8.55e-01f  1
#   48  8.8252584e+03 1.53e-10 1.52e-02  -3.8 6.74e+00    -  8.72e-01 1.00e+00f  1
#   49  8.8252493e+03 1.48e-10 1.53e-09  -3.8 1.76e+00    -  1.00e+00 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   50  8.8209063e+03 5.49e-11 3.40e-03  -5.7 1.83e+00    -  7.65e-01 8.31e-01f  1
#   51  8.8200748e+03 3.15e-11 1.80e-02  -5.7 4.07e-01    -  6.92e-01 9.42e-01f  1
#   52  8.8200231e+03 2.10e-11 8.18e-04  -5.7 2.80e-02    -  8.94e-01 1.00e+00f  1
#   53  8.8200231e+03 2.04e-11 1.84e-11  -5.7 2.95e-04    -  1.00e+00 1.00e+00h  1
#   54  8.8199584e+03 1.73e-11 3.23e-05  -8.6 2.54e-02    -  9.70e-01 9.97e-01f  1
#   55  8.8199582e+03 1.95e-11 2.51e-14  -8.6 9.63e-05    -  1.00e+00 1.00e+00f  1
#
# Number of Iterations....: 55
#
#                                    (scaled)                 (unscaled)
# Objective...............:   8.8199582391463136e+03    8.8199582391463136e+03
# Dual infeasibility......:   2.5091040356528538e-14    2.5091040356528538e-14
# Constraint violation....:   1.9518836129179531e-11    1.9518836129179531e-11
# Complementarity.........:   2.5618337697614482e-09    2.5618337697614482e-09
# Overall NLP error.......:   2.5618337697614482e-09    2.5618337697614482e-09
#
#
# Number of objective function evaluations             = 56
# Number of objective gradient evaluations             = 56
# Number of equality constraint evaluations            = 56
# Number of inequality constraint evaluations          = 56
# Number of equality constraint Jacobian evaluations   = 56
# Number of inequality constraint Jacobian evaluations = 56
# Number of Lagrangian Hessian evaluations             = 55
# Total CPU secs in IPOPT (w/o function evaluations)   =     19.028
# Total CPU secs in NLP function evaluations           =      0.172
#
# EXIT: Optimal Solution Found.
# [1125.8905678030694,1376.0258561027547,692.7714745111974,633.9754026147216,274.1153331044526,-6.785707512256928e-7,1198.3231248958366,1468.4289818698062,2197.273454277152,1634.7878036234108,454.2881951603615,603.6056748382758,-1.512487105002058e-6,-1.2992869514926854e-6,1141.352392059903,1284.2232153647892,1442.0015044721288,1474.4962124550102,1393.9006166287684,1542.0836307047527,1285.9762128817183,754.1989652516257,1532.4379436225238,1657.1137459300587,-1.0035993482110744e-6,-8.45748827154606e-7,1147.496569381419,1774.359014627323,1803.3446722005344,1751.561932516535,1051.0917548742432,1696.2163576641224,58.110610951688955,55.63246369345829,108.43007605519591,258.21049347987474,1495.92362467171,1663.8750504561353,1297.2629005948938,1800.294657167014,1525.276068125928,1652.131341928295,-2.235444719703216e-6,-2.2277696330724683e-6,1133.2636039034664,1054.7970892416406,1115.8265369131466,1077.4481160202831,327.45630156494695,99.14130406186334,157.52039572633637,114.08832516887648,1057.50981545791,1055.5973615546989,160.80946528585855,23.635852807956486,193.35226805425998,71.64263666142652,1774.91762433362,1416.3969481076426,-1.7468334832515014e-6,-2.166263614845546e-6,1581.8885988530508,1399.4332142351907,-1.5899895132547955e-6,-1.6144440600214548e-6,1517.875136196013,1493.261299221384,853.1918067597325,896.6029938898005,1314.1063270636719,1105.1826069259453,1107.160499885634,1108.9330881549229]
# 1.1669544712546729
# 462-329
# This is Ipopt version 3.12.1, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:   104266
# Number of nonzeros in inequality constraint Jacobian.:    35816
# Number of nonzeros in Lagrangian Hessian.............:       74
#
# Total number of variables............................:    35890
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:    10238
# Total number of inequality constraints...............:    35816
#         inequality constraints with only lower bounds:    35816
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 1.10e+03 1.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  2.9003594e-02 1.10e+03 1.00e+00  -1.0 4.34e+02    -  4.16e-05 4.16e-05h  1
#    2  6.7981397e-01 1.10e+03 2.35e+00  -1.0 1.94e+03    -  1.84e-05 1.68e-04h  1
#    3  2.9756341e+00 1.10e+03 2.95e+00  -1.0 2.68e+03    -  1.30e-04 3.48e-04h  1
#    4  1.0480065e+01 1.10e+03 3.10e+00  -1.0 3.03e+03    -  2.57e-04 9.62e-04f  1
#    5  3.1028304e+01 1.10e+03 3.32e+00  -1.0 3.16e+03    -  7.09e-04 2.54e-03f  1
#    6  1.0276807e+02 1.09e+03 3.58e+00  -1.0 3.26e+03    -  1.96e-03 8.81e-03f  1
#    7  4.5196647e+02 1.04e+03 4.47e+00  -1.0 3.27e+03    -  8.33e-03 4.31e-02f  1
#    8  5.9353875e+03 3.02e+02 8.64e+00  -1.0 2.96e+03    -  3.43e-02 7.09e-01f  1
#    9  5.9868870e+03 2.86e+02 8.17e+00  -1.0 4.67e+03    -  8.62e-02 5.32e-02f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  6.2241470e+03 2.48e+02 7.08e+00  -1.0 1.53e+03    -  1.21e-01 1.34e-01f  1
#   11  6.6932728e+03 1.88e+02 5.37e+00  -1.0 1.10e+03    -  2.17e-01 2.42e-01f  1
#   12  7.2986373e+03 1.26e+02 3.57e+00  -1.0 4.62e+02    -  5.25e-01 3.31e-01f  1
#   13  8.3716088e+03 4.69e+01 1.35e+00  -1.0 3.60e+02    -  1.45e-01 6.27e-01f  1
#   14  8.4713504e+03 2.39e+01 7.00e-01  -1.0 1.88e+03    -  9.05e-03 4.92e-01f  1
#   15  8.4354471e+03 2.38e+01 6.98e-01  -1.0 2.84e+04    -  1.14e-02 3.47e-03f  1
#   16  8.4200873e+03 2.36e+01 6.93e-01  -1.0 8.99e+03    -  2.74e-02 5.32e-03f  1
#   17  8.3766263e+03 2.34e+01 6.85e-01  -1.0 1.35e+04    -  2.59e-02 1.07e-02f  1
#   18  8.3592832e+03 2.30e+01 6.74e-01  -1.0 3.44e+03    -  5.81e-02 1.55e-02f  1
#   19  8.3133363e+03 2.18e+01 6.39e-01  -1.0 4.49e+03    -  1.94e-02 5.30e-02f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20  8.2656748e+03 2.16e+01 6.34e-01  -1.0 2.33e+04    -  4.84e-03 8.06e-03f  1
#   21  8.2655507e+03 2.15e+01 6.30e-01  -1.0 2.02e+03    -  4.15e-02 4.17e-03f  1
#   22  8.2683355e+03 2.10e+01 6.13e-01  -1.0 1.83e+03    -  9.85e-02 2.41e-02f  1
#   23  8.2009118e+03 1.79e+01 5.25e-01  -1.0 3.19e+03    -  2.14e-02 1.49e-01f  1
#   24  8.1471329e+03 1.76e+01 5.14e-01  -1.0 7.51e+03    -  2.61e-02 1.93e-02f  1
#   25  8.1033215e+03 1.74e+01 5.09e-01  -1.0 1.35e+04    -  7.72e-03 9.93e-03f  1
#   26  8.0646281e+03 1.73e+01 5.05e-01  -1.0 2.07e+04    -  2.37e-02 7.22e-03f  1
#   27  8.0478242e+03 1.70e+01 4.97e-01  -1.0 4.25e+03    -  4.03e-02 1.44e-02f  1
#   28  7.9266604e+03 1.63e+01 4.79e-01  -1.0 1.18e+04    -  4.28e-03 3.87e-02f  1
#   29  7.7672769e+03 1.60e+01 4.70e-01  -1.0 2.22e+04    -  1.08e-02 1.98e-02f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   30  7.7454161e+03 1.60e+01 4.68e-01  -1.0 3.61e+04    -  1.55e-02 2.54e-03f  1
#   31  7.6737987e+03 1.58e+01 4.64e-01  -1.0 3.34e+04    -  1.21e-02 8.52e-03f  1
#   32  7.6525460e+03 1.57e+01 4.60e-01  -1.0 1.42e+04    -  6.02e-02 6.62e-03f  1
#   33  7.6815472e+03 1.49e+01 4.33e-01  -1.0 9.69e+02    -  1.06e-01 5.55e-02f  1
#   34  7.7882526e+03 1.17e+01 3.43e-01  -1.0 1.41e+03    -  3.51e-02 2.16e-01f  1
#   35  7.7890119e+03 1.16e+01 3.40e-01  -1.0 2.69e+03    -  5.03e-02 8.14e-03f  1
#   36  7.7815502e+03 1.10e+01 3.24e-01  -1.0 5.88e+03    -  1.88e-02 4.71e-02f  1
#   37  7.7782693e+03 1.09e+01 3.20e-01  -1.0 6.80e+03    -  2.49e-02 1.31e-02f  1
#   38  7.7923472e+03 1.06e+01 3.08e-01  -1.0 4.56e+02    -  5.23e-01 2.41e-02f  1
#   39  8.2913527e+03 3.80e+00 1.13e-01  -1.0 4.62e+02    -  1.90e-01 6.42e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   40  8.3986414e+03 2.78e+00 8.42e-02  -1.0 1.23e+03    -  1.37e-01 2.69e-01f  1
#   41  8.4277316e+03 2.53e+00 7.65e-02  -1.0 1.03e+03    -  8.82e-01 8.81e-02f  1
#   42  8.8629861e+03 8.31e-10 2.66e-02  -1.0 7.10e+02    -  1.76e-01 1.00e+00f  1
#   43  6.0442967e+03 1.29e-10 2.66e-02  -2.5 9.32e+02    -  5.75e-01 8.46e-01f  1
#   44  5.5462829e+03 2.54e-10 8.16e-02  -2.5 2.12e+02    -  4.38e-01 8.41e-01f  1
#   45  5.4449441e+03 3.78e-10 5.43e-02  -2.5 4.23e+01    -  6.43e-01 1.00e+00f  1
#   46  5.4438760e+03 1.07e-10 1.60e-02  -2.5 3.43e+00    -  8.14e-01 1.00e+00f  1
#   47  5.3646342e+03 8.95e-11 2.30e-02  -3.8 2.86e+01    -  6.22e-01 8.34e-01f  1
#   48  5.3489351e+03 2.00e-10 3.38e-02  -3.8 4.63e+00    -  7.68e-01 9.96e-01f  1
#   49  5.3488646e+03 2.84e-11 7.51e-03  -3.8 9.58e-02    -  7.76e-01 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   50  5.3488633e+03 3.47e-11 1.50e-09  -3.8 6.12e-03    -  1.00e+00 1.00e+00f  1
#   51  5.3440675e+03 2.21e-11 1.82e-03  -5.7 1.57e+00    -  7.74e-01 9.10e-01f  1
#   52  5.3435947e+03 2.41e-11 5.18e-04  -5.7 1.40e-01    -  6.79e-01 1.00e+00f  1
#   53  5.3435947e+03 3.37e-11 1.84e-11  -5.7 1.84e-03    -  1.00e+00 1.00e+00h  1
#   54  5.3435293e+03 2.98e-11 1.74e-06  -8.6 1.95e-02    -  9.85e-01 1.00e+00f  1
#   55  5.3435293e+03 2.86e-11 2.51e-14  -8.6 6.30e-06    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 55
#
#                                    (scaled)                 (unscaled)
# Objective...............:   5.3435293251565217e+03    5.3435293251565217e+03
# Dual infeasibility......:   2.5091040356528538e-14    2.5091040356528538e-14
# Constraint violation....:   2.8600550939853214e-11    2.8600550939853214e-11
# Complementarity.........:   2.5782720784515268e-09    2.5782720784515268e-09
# Overall NLP error.......:   2.5782720784515268e-09    2.5782720784515268e-09
#
#
# Number of objective function evaluations             = 56
# Number of objective gradient evaluations             = 56
# Number of equality constraint evaluations            = 56
# Number of inequality constraint evaluations          = 56
# Number of equality constraint Jacobian evaluations   = 56
# Number of inequality constraint Jacobian evaluations = 56
# Number of Lagrangian Hessian evaluations             = 55
# Total CPU secs in IPOPT (w/o function evaluations)   =     20.312
# Total CPU secs in NLP function evaluations           =      0.172
#
# EXIT: Optimal Solution Found.
# [1001.9604588401254,1225.1103226172556,45.157249397769256,46.370658504569235,3.1915800100238934,-8.443562694175185e-7,1000.9160221815533,1225.110326662058,143.44049931225754,110.61824666305333,39.8799954637768,60.77193358421705,-1.4917497428635955e-6,-1.3871163410293591e-6,1388.9826553791318,1390.8745003560518,1837.8412819204887,1837.9809663002452,312.35912814942765,573.0652943318983,59.75001284126575,33.809739773750124,331.09666531093444,563.2490799358136,-9.885371713033422e-7,-1.0166700617901086e-6,1661.6285138821288,2470.1379686008054,900.0931357692945,1560.003768802637,1661.6285084806493,2470.13796317028,3.6307710595973703,2.9918306022157544,3.028340711272276,7.142686140290893,333.3642270563813,559.3927644910842,1661.628514976958,2470.1379693700924,870.1743776726111,1552.5561070533295,-2.2365690764663915e-6,-2.263238251787746e-6,1329.5938003924348,1329.5937954182693,698.0800741633544,693.8190564111784,49.20066792736913,9.357113604662972,20.8756492843658,7.610662291184639,931.3933723424302,776.003997555269,7.8516415753435265,2.139071642494105,7.352066274589668,2.3273792445043813,353.49377320504846,128.06979224434173,-1.8573421132825738e-6,-2.202967877927184e-6,2066.4708752629317,1677.8522496684604,-1.5829014502018207e-6,-1.641612260634457e-6,1451.0912652403103,1451.0912602640174,673.26494739464,673.2649424178952,319.2346237149456,114.90529737012379,1011.0784011836288,557.7164092460403]
# 1.1723699126454084
# 462-329
# This is Ipopt version 3.12.1, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:   104266
# Number of nonzeros in inequality constraint Jacobian.:    35816
# Number of nonzeros in Lagrangian Hessian.............:       74
#
# Total number of variables............................:    35890
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:    10238
# Total number of inequality constraints...............:    35816
#         inequality constraints with only lower bounds:    35816
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 1.24e+03 1.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  2.4896257e-02 1.24e+03 1.00e+00  -1.0 2.77e+02    -  3.58e-05 3.58e-05h  1
#    2  6.6707516e-01 1.24e+03 2.30e+00  -1.0 1.67e+03    -  1.70e-05 1.40e-04h  1
#    3  2.9617463e+00 1.24e+03 2.90e+00  -1.0 2.26e+03    -  1.05e-04 2.91e-04h  1
#    4  1.1313295e+01 1.24e+03 3.14e+00  -1.0 2.54e+03    -  2.32e-04 8.66e-04f  1
#    5  3.4125798e+01 1.23e+03 3.29e+00  -1.0 2.67e+03    -  6.86e-04 2.22e-03f  1
#    6  1.0544001e+02 1.23e+03 3.38e+00  -1.0 2.67e+03    -  1.62e-03 6.90e-03f  1
#    7  3.4151603e+02 1.20e+03 3.56e+00  -1.0 2.62e+03    -  6.58e-03 2.31e-02f  1
#    8  1.0278087e+04 2.45e-07 2.00e+01  -1.0 2.45e+03    -  2.01e-02 1.00e+00h  1
#    9  1.0177311e+04 2.12e-07 1.88e+01  -1.0 5.11e+03    -  7.30e-02 6.18e-02f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  1.0135195e+04 1.64e-07 1.69e+01  -1.0 1.28e+03    -  2.20e-01 1.02e-01f  1
#   11  1.0190673e+04 5.32e-08 1.22e+01  -1.0 7.65e+02    -  2.22e-01 2.79e-01f  1
#   12  1.0383769e+04 3.29e-08 7.43e+00  -1.0 3.38e+02    -  4.73e-01 3.88e-01f  1
#   13  1.0803648e+04 7.25e-08 3.25e+00  -1.0 2.05e+02    -  1.63e-01 5.64e-01f  1
#   14  1.0666340e+04 6.76e-08 2.68e+00  -1.0 2.49e+03    -  6.02e-03 1.78e-01f  1
#   15  1.0591259e+04 6.74e-08 2.65e+00  -1.0 1.78e+04    -  1.71e-02 8.84e-03f  1
#   16  1.0560885e+04 6.72e-08 2.64e+00  -1.0 1.69e+04    -  3.31e-02 4.80e-03f  1
#   17  1.0494264e+04 6.67e-08 2.60e+00  -1.0 1.71e+04    -  1.01e-01 1.50e-02f  1
#   18  1.0507162e+04 6.57e-08 2.51e+00  -1.0 6.34e+02    -  6.33e-02 3.29e-02f  1
#   19  1.0533262e+04 6.40e-08 2.37e+00  -1.0 6.67e+02    -  7.75e-02 5.61e-02f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20  1.0498695e+04 6.05e-08 2.11e+00  -1.0 3.32e+03    -  8.28e-03 1.12e-01f  1
#   21  1.0493433e+04 6.03e-08 2.10e+00  -1.0 4.20e+03    -  2.04e-02 4.86e-03f  1
#   22  1.0429543e+04 5.99e-08 2.06e+00  -1.0 1.83e+04    -  5.57e-03 1.54e-02f  1
#   23  1.0410502e+04 5.97e-08 2.05e+00  -1.0 1.40e+04    -  7.26e-03 5.70e-03f  1
#   24  1.0397723e+04 5.94e-08 2.03e+00  -1.0 5.41e+03    -  4.77e-02 8.61e-03f  1
#   25  1.0337135e+04 5.82e-08 1.96e+00  -1.0 7.12e+03    -  3.90e-03 3.84e-02f  1
#   26  1.0132368e+04 5.67e-08 1.86e+00  -1.0 1.74e+04    -  1.71e-02 4.96e-02f  1
#   27  1.0077161e+04 5.65e-08 1.85e+00  -1.0 4.42e+04    -  9.64e-03 3.80e-03f  1
#   28  1.0042690e+04 5.64e-08 1.84e+00  -1.0 2.80e+04    -  1.06e-02 4.19e-03f  1
#   29  1.0003987e+04 5.62e-08 1.83e+00  -1.0 1.27e+04    -  2.44e-02 8.28e-03f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   30  9.9673685e+03 5.56e-08 1.80e+00  -1.0 1.41e+04    -  4.32e-02 1.84e-02f  1
#   31  9.9664109e+03 5.51e-08 1.77e+00  -1.0 4.04e+03    -  9.47e-02 1.59e-02f  1
#   32  1.0026935e+04 5.20e-08 1.59e+00  -1.0 5.91e+02    -  7.64e-02 9.99e-02f  1
#   33  1.0043153e+04 5.09e-08 1.53e+00  -1.0 1.48e+03    -  2.46e-02 3.61e-02f  1
#   34  1.0117464e+04 4.71e-08 1.34e+00  -1.0 9.72e+02    -  3.93e-02 1.29e-01f  1
#   35  1.0185867e+04 4.39e-08 1.18e+00  -1.0 2.82e+02    -  4.97e-01 1.10e-01f  1
#   36  1.0313514e+04 3.92e-08 9.79e-01  -1.0 4.55e+02    -  8.59e-02 1.73e-01f  1
#   37  1.0139411e+04 3.56e-08 8.69e-01  -1.7 3.21e+02    -  4.30e-02 1.17e-01f  1
#   38  9.9624393e+03 3.19e-08 7.49e-01  -1.7 2.63e+02    -  2.02e-01 1.32e-01f  1
#   39  9.8451388e+03 2.96e-08 6.85e-01  -1.7 1.72e+03    -  2.90e-02 9.06e-02f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   40  9.7240896e+03 2.71e-08 6.07e-01  -1.7 4.26e+02    -  2.17e-01 1.05e-01f  1
#   41  9.2095807e+03 1.66e-08 3.28e-01  -1.7 2.46e+02    -  1.76e-01 4.81e-01f  1
#   42  8.5753450e+03 2.74e-09 4.22e-02  -1.7 8.39e+01    -  4.71e-01 1.00e+00f  1
#   43  8.4992175e+03 2.40e-09 3.66e-02  -2.5 1.66e+02    -  1.33e-01 1.19e-01f  1
#   44  8.1205558e+03 7.57e-10 1.17e-02  -2.5 1.55e+02    -  6.81e-01 6.63e-01f  1
#   45  7.9264497e+03 2.99e-10 5.33e-02  -3.8 7.85e+02    -  4.12e-02 5.98e-01f  1
#   46  7.9004047e+03 2.41e-10 1.97e-02  -3.8 3.43e+02    -  3.77e-01 1.92e-01f  1
#   47  7.8484334e+03 1.34e-10 4.36e-02  -3.8 6.98e+01    -  1.57e-01 4.68e-01f  1
#   48  7.8439108e+03 1.37e-10 4.79e-02  -3.8 8.54e+02    -  5.98e-03 7.00e-02f  1
#   49  7.8079777e+03 1.63e-10 7.31e-02  -3.8 2.95e+01    -  1.83e-01 6.45e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   50  7.8033085e+03 1.60e-10 2.62e-02  -3.8 8.85e+00    -  6.57e-01 2.29e-01f  1
#   51  7.7876043e+03 1.27e-10 2.84e-02  -3.8 1.07e+01    -  5.95e-01 9.90e-01f  1
#   52  7.7873611e+03 7.94e-11 5.39e-02  -3.8 3.00e+00    -  2.23e-01 1.00e+00f  1
#   53  7.7873574e+03 2.09e-11 1.50e-09  -3.8 5.00e-01    -  1.00e+00 1.00e+00f  1
#   54  7.7828676e+03 1.57e-11 2.89e-03  -5.7 2.11e+00    -  7.70e-01 8.58e-01f  1
#   55  7.7821213e+03 2.77e-11 1.27e-03  -5.7 3.83e-01    -  8.28e-01 1.00e+00f  1
#   56  7.7821213e+03 1.69e-11 1.84e-11  -5.7 2.31e-03    -  1.00e+00 1.00e+00h  1
#   57  7.7820564e+03 2.17e-11 2.04e-06  -8.6 2.59e-02    -  9.92e-01 9.99e-01f  1
#   58  7.7820563e+03 2.18e-11 2.51e-14  -8.6 3.06e-05    -  1.00e+00 1.00e+00f  1
#
# Number of Iterations....: 58
#
#                                    (scaled)                 (unscaled)
# Objective...............:   7.7820563286473052e+03    7.7820563286473052e+03
# Dual infeasibility......:   2.5091040356528538e-14    2.5091040356528538e-14
# Constraint violation....:   2.1828830136697878e-11    2.1828830136697878e-11
# Complementarity.........:   2.5220808949516207e-09    2.5220808949516207e-09
# Overall NLP error.......:   2.5220808949516207e-09    2.5220808949516207e-09
#
#
# Number of objective function evaluations             = 59
# Number of objective gradient evaluations             = 59
# Number of equality constraint evaluations            = 59
# Number of inequality constraint evaluations          = 59
# Number of equality constraint Jacobian evaluations   = 59
# Number of inequality constraint Jacobian evaluations = 59
# Number of Lagrangian Hessian evaluations             = 58
# Total CPU secs in IPOPT (w/o function evaluations)   =     20.512
# Total CPU secs in NLP function evaluations           =      0.208
#
# EXIT: Optimal Solution Found.
# [922.8659467500845,1371.4703486773165,745.7907023706558,656.7437353798329,280.3978459476167,-7.269562628345654e-7,924.009106668627,1524.358396683052,2395.515111797599,1503.0053660354706,497.1417166981261,494.6526992866835,-1.5105923828607088e-6,-1.3103178836695793e-6,963.8520701010737,1098.5412362842042,2031.5066933867129,2066.6034297843116,1174.1005414842093,1369.4357348066485,1437.6800781640936,518.351186033084,1034.560961846938,1459.4904122033015,-9.943864282491762e-7,-8.124501046856197e-7,1484.0087631606348,1396.372267738286,1386.3827431651716,1768.9332208490305,1342.0658361099402,1220.9298327439872,53.91186452621006,8.046823617884282,147.12037793413262,180.04652740111524,1034.2509840013013,1558.2424527566843,1456.0273124472405,1284.0277001839033,1217.396743667554,1723.2018140626456,-2.229021753119854e-6,-2.241268029324246e-6,976.141009617122,935.7323028330661,876.4540579565672,889.543315897228,178.8918492287776,35.65852705484418,177.73487021221334,168.12652959879333,1051.6888729133093,988.4460930328577,132.32521594764853,21.450833957381395,78.49601953487831,70.81646640188531,1179.0684002335067,1076.8155199027944,-1.7855641734476146e-6,-2.1661181152327003e-6,1485.5333055531007,1048.3894816410589,-1.5833335278433286e-6,-1.6326221778796877e-6,1423.438655081351,1423.4386501323625,688.2951682338519,688.2951632844296,897.670587090508,870.9212414037436,878.0341818496037,660.2910346766629]
# 1.1542264219695402
# 462-329
# This is Ipopt version 3.12.1, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:   104266
# Number of nonzeros in inequality constraint Jacobian.:    35816
# Number of nonzeros in Lagrangian Hessian.............:       74
#
# Total number of variables............................:    35890
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:    10238
# Total number of inequality constraints...............:    35816
#         inequality constraints with only lower bounds:    35816
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 1.09e+03 1.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  2.6943710e-02 1.09e+03 1.00e+00  -1.0 2.55e+02    -  3.88e-05 3.88e-05h  1
#    2  5.5703765e-01 1.09e+03 2.29e+00  -1.0 1.54e+03    -  2.05e-05 1.52e-04h  1
#    3  2.4303786e+00 1.09e+03 2.94e+00  -1.0 1.87e+03    -  1.12e-04 3.39e-04h  1
#    4  9.0276344e+00 1.09e+03 3.18e+00  -1.0 1.97e+03    -  2.99e-04 9.87e-04f  1
#    5  2.8782430e+01 1.08e+03 3.27e+00  -1.0 2.03e+03    -  7.26e-04 2.72e-03f  1
#    6  9.8465960e+01 1.07e+03 3.62e+00  -1.0 2.02e+03    -  2.19e-03 9.59e-03f  1
#    7  4.4677271e+02 1.02e+03 4.48e+00  -1.0 1.96e+03    -  6.72e-03 4.88e-02f  1
#    8  7.1866887e+03 1.32e-07 1.21e+01  -1.0 1.67e+03    -  4.01e-02 1.00e+00f  1
#    9  7.1209494e+03 1.17e-07 1.14e+01  -1.0 5.11e+03    -  1.27e-01 5.13e-02f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  7.1169783e+03 7.17e-08 9.46e+00  -1.0 7.71e+02    -  3.45e-01 1.71e-01f  1
#   11  7.3441240e+03 2.97e-08 5.70e+00  -1.0 2.35e+02    -  4.53e-01 3.96e-01f  1
#   12  7.8643358e+03 4.92e-08 2.04e+00  -1.0 1.91e+02    -  2.06e-01 6.43e-01f  1
#   13  7.8674535e+03 4.60e-08 1.76e+00  -1.0 2.03e+03    -  6.03e-03 1.40e-01f  1
#   14  7.8183873e+03 4.57e-08 1.74e+00  -1.0 1.71e+04    -  1.31e-02 9.94e-03f  1
#   15  7.8114967e+03 4.56e-08 1.73e+00  -1.0 3.93e+03    -  1.67e-02 4.56e-03f  1
#   16  7.7539481e+03 4.53e-08 1.71e+00  -1.0 1.80e+04    -  4.84e-03 1.24e-02f  1
#   17  7.7385096e+03 4.52e-08 1.70e+00  -1.0 1.30e+04    -  1.24e-02 4.87e-03f  1
#   18  7.7547839e+03 4.46e-08 1.66e+00  -1.0 2.53e+02    -  1.48e-01 2.68e-02f  1
#   19  7.7997387e+03 4.28e-08 1.53e+00  -1.0 5.17e+02    -  9.50e-02 7.78e-02f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20  7.7387557e+03 4.14e-08 1.44e+00  -1.0 6.47e+03    -  1.87e-03 5.71e-02f  1
#   21  7.7292198e+03 4.14e-08 1.44e+00  -1.0 1.10e+04    -  1.11e-02 3.14e-03f  1
#   22  7.7052120e+03 4.11e-08 1.42e+00  -1.0 5.60e+03    -  1.48e-02 1.13e-02f  1
#   23  7.6665433e+03 4.07e-08 1.39e+00  -1.0 8.15e+03    -  4.08e-02 1.89e-02f  1
#   24  7.6712180e+03 4.02e-08 1.37e+00  -1.0 1.01e+03    -  2.54e-02 1.84e-02f  1
#   25  7.5737904e+03 3.98e-08 1.34e+00  -1.0 2.11e+04    -  1.38e-03 2.13e-02f  1
#   26  7.5693163e+03 3.97e-08 1.34e+00  -1.0 1.25e+04    -  1.44e-02 1.85e-03f  1
#   27  7.5368456e+03 3.94e-08 1.32e+00  -1.0 9.15e+03    -  5.17e-03 1.38e-02f  1
#   28  7.4735254e+03 3.90e-08 1.29e+00  -1.0 2.16e+04    -  8.41e-02 1.96e-02f  1
#   29  7.3913846e+03 3.86e-08 1.27e+00  -1.0 3.39e+04    -  1.83e-02 1.55e-02f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   30  7.3933274e+03 3.85e-08 1.27e+00  -1.0 1.49e+03    -  2.64e-01 3.98e-03f  1
#   31  7.5259250e+03 3.49e-08 1.08e+00  -1.0 2.91e+02    -  4.52e-01 1.59e-01f  1
#   32  7.9116062e+03 2.60e-08 6.18e-01  -1.0 4.26e+02    -  5.53e-02 4.18e-01f  1
#   33  7.8380723e+03 2.50e-08 5.88e-01  -1.7 8.23e+02    -  5.15e-02 4.74e-02f  1
#   34  7.7144770e+03 2.32e-08 5.30e-01  -1.7 2.14e+02    -  3.66e-01 8.63e-02f  1
#   35  7.3545592e+03 1.84e-08 3.96e-01  -1.7 2.55e+02    -  3.39e-01 2.51e-01f  1
#   36  6.9907794e+03 1.36e-08 2.76e-01  -1.7 2.47e+02    -  8.12e-01 3.10e-01f  1
#   37  6.7390065e+03 1.05e-08 2.00e-01  -1.7 1.83e+02    -  2.52e-01 2.73e-01f  1
#   38  6.4812940e+03 7.06e-09 1.23e-01  -1.7 2.01e+02    -  2.06e-01 3.79e-01f  1
#   39  5.9133551e+03 3.38e-09 5.79e-02  -2.5 2.44e+02    -  1.92e-01 5.54e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   40  5.4949838e+03 5.03e-10 1.09e-02  -2.5 1.19e+02    -  8.41e-01 8.97e-01f  1
#   41  5.3871102e+03 1.51e-10 3.52e-02  -3.8 4.75e+01    -  5.06e-01 7.27e-01f  1
#   42  5.3560082e+03 1.82e-10 4.74e-02  -3.8 2.56e+01    -  5.32e-01 7.62e-01f  1
#   43  5.3462242e+03 8.42e-11 4.12e-02  -3.8 1.17e+01    -  5.92e-01 1.00e+00f  1
#   44  5.3462088e+03 2.64e-11 1.47e-03  -3.8 2.53e+00    -  9.37e-01 1.00e+00f  1
#   45  5.3412003e+03 1.84e-11 1.00e-03  -5.7 3.24e+00    -  8.27e-01 9.53e-01f  1
#   46  5.3409540e+03 1.66e-11 4.23e-04  -5.7 2.87e-01    -  5.74e-01 1.00e+00f  1
#   47  5.3409539e+03 1.54e-11 1.85e-04  -5.7 1.46e-02    -  9.70e-01 1.00e+00h  1
#   48  5.3409539e+03 1.37e-11 1.84e-11  -5.7 7.07e-03    -  1.00e+00 1.00e+00h  1
#   49  5.3408888e+03 2.42e-11 5.80e-06  -8.6 4.46e-02    -  9.13e-01 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   50  5.3408888e+03 1.98e-11 2.51e-14  -8.6 1.10e-03    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 50
#
#                                    (scaled)                 (unscaled)
# ...
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 1.37e+03 1.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  2.2710807e-02 1.37e+03 1.00e+00  -1.0 3.24e+02    -  3.30e-05 3.30e-05h  1
#    2  5.1349870e-01 1.37e+03 2.31e+00  -1.0 1.78e+03    -  1.49e-05 1.30e-04h  1
#    3  2.1646225e+00 1.37e+03 2.91e+00  -1.0 2.27e+03    -  9.92e-05 2.66e-04h  1
#    4  8.1920409e+00 1.37e+03 3.13e+00  -1.0 2.49e+03    -  2.11e-04 8.04e-04f  1
#    5  2.6310756e+01 1.37e+03 3.39e+00  -1.0 2.63e+03    -  6.27e-04 2.27e-03f  1
#    6  7.8391514e+01 1.36e+03 3.41e+00  -1.0 2.67e+03    -  1.99e-03 6.46e-03f  1
#    7  3.1004504e+02 1.32e+03 3.94e+00  -1.0 2.64e+03    -  5.07e-03 2.91e-02f  1
#    8  8.0445366e+03 1.49e-07 1.88e+01  -1.0 2.46e+03    -  2.52e-02 1.00e+00h  1
#    9  7.9739012e+03 1.30e-07 1.77e+01  -1.0 5.73e+03    -  7.08e-02 5.83e-02f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  7.9699750e+03 9.93e-08 1.59e+01  -1.0 7.54e+02    -  2.13e-01 1.02e-01f  1
#   11  8.0884182e+03 3.16e-08 1.11e+01  -1.0 4.33e+02    -  2.78e-01 3.03e-01f  1
#   12  8.3503207e+03 3.93e-08 6.26e+00  -1.0 1.94e+02    -  4.26e-01 4.34e-01f  1
#   13  8.6421239e+03 4.46e-08 3.80e+00  -1.0 1.67e+02    -  1.39e-01 3.90e-01f  1
#   14  8.6228528e+03 4.25e-08 3.16e+00  -1.0 2.29e+03    -  8.01e-03 1.72e-01f  1
#   15  8.5164891e+03 4.18e-08 3.02e+00  -1.0 7.93e+03    -  3.79e-02 4.67e-02f  1
#   16  8.4831261e+03 4.17e-08 3.00e+00  -1.0 1.67e+04    -  2.37e-02 5.56e-03f  1
#   17  8.4638956e+03 4.15e-08 2.96e+00  -1.0 6.29e+03    -  5.14e-02 1.28e-02f  1
#   18  8.3618323e+03 4.04e-08 2.77e+00  -1.0 7.51e+03    -  7.23e-02 6.61e-02f  1
#   19  8.3015312e+03 4.02e-08 2.74e+00  -1.0 2.14e+04    -  1.07e-02 1.09e-02f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20  8.2946508e+03 4.01e-08 2.72e+00  -1.0 5.83e+03    -  7.42e-02 6.78e-03f  1
#   21  8.3394256e+03 3.86e-08 2.49e+00  -1.0 4.99e+02    -  6.18e-02 8.57e-02f  1
#   22  8.3090601e+03 3.75e-08 2.33e+00  -1.0 3.73e+03    -  8.55e-03 6.30e-02f  1
#   23  8.3048561e+03 3.74e-08 2.32e+00  -1.0 3.65e+03    -  2.36e-02 5.53e-03f  1
#   24  8.2251469e+03 3.71e-08 2.27e+00  -1.0 1.70e+04    -  3.69e-03 1.82e-02f  1
#   25  8.2119075e+03 3.70e-08 2.26e+00  -1.0 1.27e+04    -  6.36e-03 4.12e-03f  1
#   26  8.1924259e+03 3.69e-08 2.25e+00  -1.0 9.66e+03    -  4.31e-02 8.29e-03f  1
#   27  8.1377048e+03 3.64e-08 2.17e+00  -1.0 8.80e+03    -  3.65e-03 3.51e-02f  1
#   28  7.9117171e+03 3.51e-08 1.99e+00  -1.0 1.38e+04    -  2.11e-02 8.09e-02f  1
#   29  7.9012489e+03 3.51e-08 1.99e+00  -1.0 2.54e+04    -  6.76e-03 1.04e-03f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   30  7.8261751e+03 3.49e-08 1.97e+00  -1.0 2.60e+04    -  1.45e-02 7.22e-03f  1
#   31  7.7598548e+03 3.48e-08 1.96e+00  -1.0 2.65e+04    -  7.92e-02 8.99e-03f  1
#   32  7.7576477e+03 3.44e-08 1.92e+00  -1.0 4.01e+03    -  2.38e-01 2.63e-02f  1
#   33  7.8255717e+03 3.29e-08 1.74e+00  -1.0 4.82e+02    -  3.57e-02 9.01e-02f  1
#   34  8.0689061e+03 2.76e-08 1.19e+00  -1.0 2.36e+02    -  4.82e-01 3.19e-01f  1
#   35  8.2957532e+03 2.27e-08 8.30e-01  -1.0 4.30e+02    -  5.06e-02 3.00e-01f  1
#   36  8.2406050e+03 2.21e-08 8.02e-01  -1.7 9.12e+02    -  4.76e-02 3.39e-02f  1
#   37  8.1159958e+03 2.07e-08 7.30e-01  -1.7 2.92e+02    -  2.19e-01 8.24e-02f  1
#   38  7.9527304e+03 1.89e-08 6.55e-01  -1.7 1.85e+03    -  3.43e-02 1.06e-01f  1
#   39  7.8267413e+03 1.75e-08 5.72e-01  -1.7 2.61e+02    -  8.23e-01 9.38e-02f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   40  6.7047429e+03 6.43e-09 1.23e-01  -1.7 1.99e+02    -  2.80e-01 7.89e-01f  1
#   41  5.8706610e+03 1.02e-09 5.51e-02  -2.5 2.43e+02    -  3.00e-01 8.96e-01f  1
#   42  5.8457404e+03 8.21e-10 2.41e-02  -2.5 3.59e+02    -  4.75e-01 2.01e-01f  1
#   43  5.8161800e+03 6.98e-10 2.20e-02  -3.8 2.50e+02    -  8.39e-02 1.52e-01f  1
#   44  5.7275186e+03 3.30e-10 1.57e-02  -3.8 5.57e+01    -  6.34e-01 5.40e-01f  1
#   45  5.6657605e+03 1.56e-10 1.24e-02  -3.8 2.72e+01    -  6.38e-01 7.99e-01f  1
#   46  5.6509448e+03 1.23e-10 3.61e-02  -3.8 5.89e+00    -  6.72e-01 9.32e-01f  1
#   47  5.6498317e+03 1.72e-10 1.16e-02  -3.8 9.78e-01    -  8.90e-01 1.00e+00f  1
#   48  5.6498293e+03 4.08e-11 1.50e-09  -3.8 1.24e-01    -  1.00e+00 1.00e+00f  1
#   49  5.6455433e+03 3.39e-11 5.53e-04  -5.7 1.55e+00    -  8.21e-01 8.15e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   50  5.6448645e+03 3.16e-11 6.16e-03  -5.7 2.98e-01    -  6.39e-01 6.99e-01f  1
#   51  5.6445715e+03 3.48e-11 7.34e-03  -5.7 8.90e-02    -  6.27e-01 1.00e+00f  1
#   52  5.6445714e+03 3.30e-11 1.84e-11  -5.7 5.67e-04    -  1.00e+00 1.00e+00h  1
#   53  5.6445065e+03 2.29e-11 8.45e-05  -8.6 1.91e-02    -  9.37e-01 9.95e-01f  1
#   54  5.6445062e+03 2.82e-11 2.51e-14  -8.6 8.80e-05    -  1.00e+00 1.00e+00f  1
#
# Number of Iterations....: 54
#
#                                    (scaled)                 (unscaled)
# Objective...............:   5.6445061726748590e+03    5.6445061726748590e+03
# Dual infeasibility......:   2.5091040356528538e-14    2.5091040356528538e-14
# Constraint violation....:   2.8183734693290933e-11    2.8183734693290933e-11
# Complementarity.........:   2.6739510237906274e-09    2.6739510237906274e-09
# Overall NLP error.......:   2.6739510237906274e-09    2.6739510237906274e-09
#
#
# Number of objective function evaluations             = 55
# Number of objective gradient evaluations             = 55
# Number of equality constraint evaluations            = 55
# Number of inequality constraint evaluations          = 55
# Number of equality constraint Jacobian evaluations   = 55
# Number of inequality constraint Jacobian evaluations = 55
# Number of Lagrangian Hessian evaluations             = 54
# Total CPU secs in IPOPT (w/o function evaluations)   =     18.272
# Total CPU secs in NLP function evaluations           =      0.088
#
# EXIT: Optimal Solution Found.
# [927.8656089879825,867.6145297540746,216.50923722814727,230.82308783202492,49.044549730538655,-7.907182230857202e-7,971.3222321437557,865.63997666232,851.929691365438,731.4338673968286,221.36492108566952,394.30048029088056,-1.5043434848460833e-6,-1.377834754393298e-6,832.9258610762603,921.9382094450958,889.732339587086,935.5025135175058,895.9742395300716,905.1070072854823,394.48647550458674,353.1802015298226,895.9026466591087,840.9175273139363,-1.018316452807458e-6,-1.0141927095657995e-6,587.1000897737596,1311.3574244483304,1285.9375787499664,1731.5226751678617,571.6323551343871,1286.72491154857,34.24600080410454,28.892228018279013,37.98864160457362,62.30100342147897,827.9729824055619,761.7927168730415,625.414984690495,1296.1013225965294,1180.3500983369422,1683.610089547117,-2.2584210506896307e-6,-2.220183714697771e-6,1082.192764595987,1082.1927597266067,1097.2525813363586,1059.6088387278282,200.0732411327314,53.249107197433666,93.45750048437426,63.65104669035781,1146.0372835862247,1078.2977509520588,59.163518465239456,18.64063478632454,222.409217342694,70.72255872063823,929.5382636112274,216.0940116038938,-1.734053324238226e-6,-2.233720414479003e-6,1415.8618012071227,1214.4746388779854,-1.570883881145482e-6,-1.6676914649186916e-6,1653.8273315681022,1653.8273265858547,846.0516055565378,846.0516005738409,613.5204227660206,197.73950727902394,756.4057481914205,608.3376127684242]
# 1.1090109683696685
# 462-329
# This is Ipopt version 3.12.1, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:   104266
# Number of nonzeros in inequality constraint Jacobian.:    35816
# Number of nonzeros in Lagrangian Hessian.............:       74
#
# Total number of variables............................:    35890
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:    10238
# Total number of inequality constraints...............:    35816
#         inequality constraints with only lower bounds:    35816
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 1.47e+03 1.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  2.1590052e-02 1.47e+03 1.00e+00  -1.0 4.15e+02    -  3.11e-05 3.11e-05h  1
#    2  5.5122356e-01 1.47e+03 2.33e+00  -1.0 2.04e+03    -  1.38e-05 1.24e-04h  1
#    3  2.3638348e+00 1.47e+03 2.92e+00  -1.0 2.72e+03    -  9.49e-05 2.52e-04h  1
#    4  8.8945580e+00 1.47e+03 3.14e+00  -1.0 3.01e+03    -  1.93e-04 7.57e-04f  1
#    5  2.6160785e+01 1.47e+03 3.29e+00  -1.0 3.16e+03    -  6.09e-04 1.88e-03f  1
#    6  7.7813441e+01 1.46e+03 3.29e+00  -1.0 3.20e+03    -  1.51e-03 5.53e-03f  1
#    7  2.5336249e+02 1.43e+03 3.41e+00  -1.0 3.18e+03    -  4.59e-03 1.89e-02f  1
#    8  3.9928173e+03 8.42e+02 1.01e+01  -1.0 3.03e+03    -  1.74e-02 4.12e-01f  1
#    9  4.2931783e+03 7.87e+02 9.40e+00  -1.0 3.38e+03    -  5.71e-02 6.58e-02f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  4.7076061e+03 7.18e+02 8.56e+00  -1.0 1.42e+03    -  1.53e-01 8.71e-02f  1
#   11  5.7793440e+03 5.50e+02 6.56e+00  -1.0 1.30e+03    -  1.40e-01 2.35e-01f  1
#   12  7.1426471e+03 3.50e+02 4.18e+00  -1.0 1.00e+03    -  3.02e-01 3.63e-01h  1
#   13  8.9517320e+03 1.19e+02 1.43e+00  -1.0 6.38e+02    -  4.60e-01 6.60e-01h  1
#   14  9.2565542e+03 8.99e+01 1.08e+00  -1.0 6.85e+02    -  1.03e-02 2.45e-01f  1
#   15  9.1936461e+03 7.29e+01 8.79e-01  -1.0 4.16e+03    -  3.92e-02 1.90e-01f  1
#   16  9.0978125e+03 7.19e+01 8.68e-01  -1.0 2.08e+04    -  2.00e-02 1.27e-02f  1
#   17  9.0885697e+03 7.17e+01 8.64e-01  -1.0 9.95e+03    -  5.60e-02 3.47e-03f  1
#   18  9.0102965e+03 6.93e+01 8.35e-01  -1.0 1.03e+04    -  5.29e-02 3.29e-02f  1
#   19  8.9996924e+03 6.85e+01 8.26e-01  -1.0 3.83e+03    -  9.43e-03 1.15e-02f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20  8.9610342e+03 6.81e+01 8.20e-01  -1.0 2.46e+04    -  2.40e-03 6.96e-03f  1
#   21  8.9638400e+03 6.77e+01 8.15e-01  -1.0 1.36e+03    -  8.31e-02 4.80e-03f  1
#   22  9.0102772e+03 6.32e+01 7.61e-01  -1.0 1.08e+03    -  3.97e-02 6.69e-02f  1
#   23  8.9977909e+03 5.72e+01 6.90e-01  -1.0 4.64e+03    -  1.12e-02 9.45e-02f  1
#   24  8.9962658e+03 5.69e+01 6.85e-01  -1.0 3.49e+03    -  4.16e-02 6.22e-03f  1
#   25  8.9524689e+03 5.51e+01 6.65e-01  -1.0 5.46e+03    -  1.08e-02 3.04e-02f  1
#   26  8.8823096e+03 5.44e+01 6.56e-01  -1.0 2.06e+04    -  1.51e-02 1.37e-02f  1
#   27  8.8593591e+03 5.40e+01 6.51e-01  -1.0 1.47e+04    -  1.04e-02 6.44e-03f  1
#   28  8.8557110e+03 5.32e+01 6.41e-01  -1.0 3.57e+03    -  2.39e-02 1.55e-02f  1
#   29  8.6732191e+03 4.38e+01 5.29e-01  -1.0 8.87e+03    -  1.32e-02 1.78e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   30  8.6637148e+03 4.37e+01 5.28e-01  -1.0 3.36e+04    -  9.74e-03 1.24e-03f  1
#   31  8.6236216e+03 4.34e+01 5.25e-01  -1.0 2.17e+04    -  2.09e-02 6.56e-03f  1
#   32  8.5054313e+03 4.25e+01 5.14e-01  -1.0 2.34e+04    -  1.27e-02 2.03e-02f  1
#   33  8.5005473e+03 4.24e+01 5.12e-01  -1.0 9.85e+03    -  4.39e-02 2.55e-03f  1
#   34  8.5196683e+03 4.08e+01 4.92e-01  -1.0 1.27e+03    -  1.33e-01 3.75e-02f  1
#   35  8.6122394e+03 3.58e+01 4.32e-01  -1.0 1.08e+03    -  4.35e-02 1.24e-01f  1
#   36  8.6302385e+03 3.46e+01 4.18e-01  -1.0 1.32e+03    -  4.67e-02 3.13e-02f  1
#   37  8.6415848e+03 3.37e+01 4.07e-01  -1.0 3.27e+03    -  2.57e-02 2.59e-02f  1
#   38  8.6524013e+03 3.30e+01 3.98e-01  -1.0 2.75e+03    -  5.72e-01 2.17e-02f  1
#   39  9.4352602e+03 8.33e+00 1.03e-01  -1.0 4.54e+02    -  1.18e-01 7.48e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   40  9.5288851e+03 6.49e+00 8.24e-02  -1.0 1.03e+03    -  1.24e-01 2.21e-01f  1
#   41  9.5894536e+03 5.49e+00 7.30e-02  -1.0 2.26e+02    -  9.26e-01 1.54e-01f  1
#   42  9.8598576e+03 2.14e+00 2.75e-02  -1.0 8.07e+02    -  2.67e-01 6.11e-01f  1
#   43  1.0041368e+04 4.41e-10 7.56e-06  -1.0 2.09e+02    -  1.00e+00 1.00e+00h  1
#   44  7.3059361e+03 3.98e-10 2.32e-02  -1.7 8.22e+02    -  7.13e-01 9.73e-01f  1
#   45  6.7450045e+03 3.86e-10 4.08e-02  -2.5 1.99e+02    -  5.79e-01 8.18e-01f  1
#   46  6.6198881e+03 4.62e-10 4.32e-02  -2.5 6.44e+01    -  7.03e-01 1.00e+00f  1
#   47  6.6194083e+03 1.36e-10 2.83e-08  -2.5 7.74e+00    -  1.00e+00 1.00e+00f  1
#   48  6.5388107e+03 1.12e-10 1.93e-02  -3.8 2.49e+01    -  6.28e-01 8.53e-01f  1
#   49  6.5248985e+03 1.89e-10 3.32e-02  -3.8 4.12e+00    -  6.87e-01 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   50  6.5248832e+03 6.35e-11 1.18e-03  -3.8 1.38e+00    -  9.85e-01 1.00e+00f  1
#   51  6.5205124e+03 2.38e-11 6.49e-03  -5.7 2.78e+00    -  7.07e-01 8.33e-01f  1
#   52  6.5196327e+03 3.52e-11 6.69e-03  -5.7 1.12e+00    -  7.70e-01 1.00e+00f  1
#   53  6.5196326e+03 1.90e-11 1.84e-11  -5.7 1.43e-01    -  1.00e+00 1.00e+00f  1
#   54  6.5195676e+03 2.33e-11 6.75e-06  -8.6 5.27e-02    -  9.89e-01 9.99e-01f  1
#   55  6.5195675e+03 2.84e-11 2.51e-14  -8.6 4.14e-04    -  1.00e+00 1.00e+00f  1
#
# Number of Iterations....: 55
#
#                                    (scaled)                 (unscaled)
# Objective...............:   6.5195674823378786e+03    6.5195674823378786e+03
# Dual infeasibility......:   2.5091040356528538e-14    2.5091040356528538e-14
# Constraint violation....:   2.8443765909502535e-11    2.8443765909502535e-11
# Complementarity.........:   2.6645800358812482e-09    2.6645800358812482e-09
# Overall NLP error.......:   2.6645800358812482e-09    2.6645800358812482e-09
#
#
# Number of objective function evaluations             = 56
# Number of objective gradient evaluations             = 56
# Number of equality constraint evaluations            = 56
# Number of inequality constraint evaluations          = 56
# Number of equality constraint Jacobian evaluations   = 56
# Number of inequality constraint Jacobian evaluations = 56
# Number of Lagrangian Hessian evaluations             = 55
# Total CPU secs in IPOPT (w/o function evaluations)   =     18.196
# Total CPU secs in NLP function evaluations           =      0.200
#
# EXIT: Optimal Solution Found.
# [1013.6633991485822,1180.3935900020565,206.9474366811389,171.9170164676742,59.056115925557215,-7.503911665182867e-7,1046.6867245647684,1187.641717283381,746.4965966681045,458.7282153659982,229.05327366871467,362.1386223940723,-1.4999600711527964e-6,-1.3349989515183901e-6,1138.6891073481459,1163.5965201583049,1343.7473278035993,1371.9086133455096,870.6688328022815,1140.268455712722,283.4306613296452,111.14565007718002,838.8182817843467,1164.3230581646121,-9.837469344205711e-7,-9.312489907386162e-7,1247.881184372612,1925.1124170074118,1226.9142868688675,1846.4326590133696,1237.0435070298365,1924.3425106490552,3.5161297940539824,7.005301373563689,16.62727324798851,20.759177380855622,785.3694696970579,1169.662103113317,1238.3838204186657,1924.3425168758301,1144.4729742332906,1846.1631995228843,-2.228346625480606e-6,-2.2574406372014042e-6,1478.6160766035534,1485.9034564387118,801.4204237773188,787.4352339646209,176.8332487953662,12.703272234176989,106.48712677645263,24.169557625133326,1234.9564077777693,1074.9842613988467,12.564832491875057,4.103110863832886,29.43022231255759,17.58867410332696,698.9792837170969,495.9350172273342,-1.8429946465624737e-6,-2.1748252477979763e-6,2102.769000868146,1446.2061780314582,-1.5823945009511319e-6,-1.6473814442774204e-6,1872.6819952467952,1872.6819902798193,886.5884598050983,886.588454837475,609.0675126528056,394.61301527786475,1167.0787824457984,632.2267834790148]
# 1.1121481816693903

# %%
outfile = open("./results/poaDictAprWeekend.json", "w")

JSON.print(outfile, poaDictAprWeekend)

close(outfile)
