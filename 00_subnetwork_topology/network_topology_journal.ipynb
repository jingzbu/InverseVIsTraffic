# %%
from graphviz import Digraph

# %%
# cluster.py - http://www.graphviz.org/content/cluster

g = Digraph('G', filename='MA_highway_network_journal_topology')
g.body.extend(['rankdir=LR', 'size="16,12"'])

for i in range(75)[1:]:
    g.node('%s'%(i), fontsize='24', penwidth='3')


g.edge('1', '3', label='0', fontsize='24', penwidth='3')
g.edge('3', '1', label='1', fontsize='24', penwidth='3')

g.edge('1', '7', label='2', fontsize='24', penwidth='3')
g.edge('7', '1', label='3', fontsize='24', penwidth='3')

g.edge('1', '9', label='4', fontsize='24', penwidth='3')
g.edge('9', '1', label='5', fontsize='24', penwidth='3')
#################################################################

g.edge('2', '3', label='6', fontsize='24', penwidth='3')
g.edge('3', '2', label='7', fontsize='24', penwidth='3')
#################################################################

g.edge('3', '6', label='8', fontsize='24', penwidth='3')
g.edge('6', '3', label='9', fontsize='24', penwidth='3')

g.edge('3', '7', label='10', fontsize='24', penwidth='3')
g.edge('7', '3', label='11', fontsize='24', penwidth='3')
#################################################################

g.edge('4', '6', label='12', fontsize='24', penwidth='3')
g.edge('6', '4', label='13', fontsize='24', penwidth='3')

g.edge('4', '8', label='14', fontsize='24', penwidth='3')
g.edge('8', '4', label='16', fontsize='24', penwidth='3')
#################################################################

g.edge('5', '10', label='17', fontsize='24', penwidth='3')
g.edge('10', '5', label='15', fontsize='24', penwidth='3')

g.edge('5', '11', label='18', fontsize='24', penwidth='3')
g.edge('11', '5', label='19', fontsize='24', penwidth='3')
#################################################################

g.edge('6', '8', label='20', fontsize='24', penwidth='3')
g.edge('8', '6', label='21', fontsize='24', penwidth='3')

g.edge('6', '13', label='22', fontsize='24', penwidth='3')
g.edge('13', '6', label='23', fontsize='24', penwidth='3')

g.edge('6', '17', label='24', fontsize='24', penwidth='3')
g.edge('17', '6', label='25', fontsize='24', penwidth='3')
#################################################################

g.edge('7', '9', label='26', fontsize='24', penwidth='3')
g.edge('9', '7', label='27', fontsize='24', penwidth='3')

g.edge('7', '13', label='28', fontsize='24', penwidth='3')
g.edge('13', '7', label='29', fontsize='24', penwidth='3')
#################################################################

g.edge('8', '11', label='30', fontsize='24', penwidth='3')
g.edge('11', '8', label='31', fontsize='24', penwidth='3')

g.edge('8', '16', label='32', fontsize='24', penwidth='3')
g.edge('16', '8', label='33', fontsize='24', penwidth='3')
#################################################################

g.edge('9', '12', label='34', fontsize='24', penwidth='3')
g.edge('12', '9', label='35', fontsize='24', penwidth='3')

g.edge('9', '13', label='36', fontsize='24', penwidth='3')
g.edge('13', '9', label='37', fontsize='24', penwidth='3')
#################################################################

g.edge('10', '11', label='38', fontsize='24', penwidth='3')
g.edge('11', '10', label='39', fontsize='24', penwidth='3')

g.edge('10', '18', label='40', fontsize='24', penwidth='3')
g.edge('18', '10', label='41', fontsize='24', penwidth='3')

g.edge('10', '20', label='42', fontsize='24', penwidth='3')
g.edge('20', '10', label='43', fontsize='24', penwidth='3')
#################################################################

g.edge('11', '19', label='44', fontsize='24', penwidth='3')
g.edge('19', '11', label='46', fontsize='24', penwidth='3')
#################################################################

g.edge('13', '14', label='47', fontsize='24', penwidth='3')
g.edge('14', '13', label='45', fontsize='24', penwidth='3')

g.edge('13', '15', label='48', fontsize='24', penwidth='3')
g.edge('15', '13', label='50', fontsize='24', penwidth='3')
#################################################################

g.edge('14', '17', label='51', fontsize='24', penwidth='3')
g.edge('17', '14', label='49', fontsize='24', penwidth='3')

g.edge('14', '22', label='52', fontsize='24', penwidth='3')
g.edge('22', '14', label='53', fontsize='24', penwidth='3')
#################################################################

g.edge('16', '17', label='54', fontsize='24', penwidth='3')
g.edge('17', '16', label='56', fontsize='24', penwidth='3')

g.edge('16', '19', label='57', fontsize='24', penwidth='3')
g.edge('19', '16', label='55', fontsize='24', penwidth='3')

g.edge('16', '22', label='58', fontsize='24', penwidth='3')
g.edge('22', '16', label='59', fontsize='24', penwidth='3')
#################################################################

g.edge('17', '22', label='60', fontsize='24', penwidth='3')
g.edge('22', '17', label='61', fontsize='24', penwidth='3')
#################################################################

g.edge('18', '19', label='62', fontsize='24', penwidth='3')
g.edge('19', '18', label='63', fontsize='24', penwidth='3')

g.edge('18', '21', label='64', fontsize='24', penwidth='3')
g.edge('21', '18', label='65', fontsize='24', penwidth='3')
#################################################################

g.edge('19', '22', label='66', fontsize='24', penwidth='3')
g.edge('22', '19', label='68', fontsize='24', penwidth='3')
#################################################################

g.edge('20', '21', label='69', fontsize='24', penwidth='3')
g.edge('21', '20', label='67', fontsize='24', penwidth='3')

g.edge('20', '30', label='70', fontsize='24', penwidth='3')
g.edge('30', '20', label='71', fontsize='24', penwidth='3')

g.edge('20', '58', label='72', fontsize='24', penwidth='3')
g.edge('58', '20', label='73', fontsize='24', penwidth='3')
#################################################################

g.edge('21', '22', label='74', fontsize='24', penwidth='3')
g.edge('22', '21', label='75', fontsize='24', penwidth='3')

g.edge('21', '23', label='76', fontsize='24', penwidth='3')
g.edge('23', '21', label='77', fontsize='24', penwidth='3')
#################################################################

g.edge('22', '23', label='78', fontsize='24', penwidth='3')
g.edge('23', '22', label='79', fontsize='24', penwidth='3')

g.edge('22', '25', label='80', fontsize='24', penwidth='3')
g.edge('25', '22', label='81', fontsize='24', penwidth='3')

g.edge('22', '28', label='82', fontsize='24', penwidth='3')
g.edge('28', '22', label='83', fontsize='24', penwidth='3')

g.edge('22', '29', label='84', fontsize='24', penwidth='3')
g.edge('29', '22', label='85', fontsize='24', penwidth='3')

g.edge('22', '40', label='86', fontsize='24', penwidth='3')
g.edge('40', '22', label='87', fontsize='24', penwidth='3')
#################################################################

g.edge('23', '24', label='88', fontsize='24', penwidth='3')
g.edge('24', '23', label='89', fontsize='24', penwidth='3')

g.edge('23', '31', label='90', fontsize='24', penwidth='3')
g.edge('31', '23', label='91', fontsize='24', penwidth='3')
#################################################################

g.edge('24', '25', label='92', fontsize='24', penwidth='3')
g.edge('25', '24', label='93', fontsize='24', penwidth='3')

g.edge('24', '26', label='94', fontsize='24', penwidth='3')
g.edge('26', '24', label='95', fontsize='24', penwidth='3')

g.edge('24', '33', label='96', fontsize='24', penwidth='3')
g.edge('33', '24', label='97', fontsize='24', penwidth='3')
#################################################################

g.edge('25', '26', label='98', fontsize='24', penwidth='3')
g.edge('26', '25', label='99', fontsize='24', penwidth='3')
#################################################################

g.edge('26', '27', label='100', fontsize='24', penwidth='3')
g.edge('27', '26', label='101', fontsize='24', penwidth='3')

g.edge('26', '28', label='102', fontsize='24', penwidth='3')
g.edge('28', '26', label='103', fontsize='24', penwidth='3')
#################################################################

g.edge('27', '28', label='104', fontsize='24', penwidth='3')
g.edge('28', '27', label='105', fontsize='24', penwidth='3')

g.edge('27', '33', label='106', fontsize='24', penwidth='3')
g.edge('33', '27', label='107', fontsize='24', penwidth='3')

g.edge('27', '35', label='108', fontsize='24', penwidth='3')
g.edge('35', '27', label='109', fontsize='24', penwidth='3')
#################################################################

g.edge('28', '37', label='110', fontsize='24', penwidth='3')
g.edge('37', '28', label='111', fontsize='24', penwidth='3')
#################################################################

g.edge('29', '41', label='112', fontsize='24', penwidth='3')
g.edge('41', '29', label='113', fontsize='24', penwidth='3')

g.edge('29', '49', label='114', fontsize='24', penwidth='3')
g.edge('49', '29', label='115', fontsize='24', penwidth='3')
#################################################################

g.edge('30', '31', label='116', fontsize='24', penwidth='3')
g.edge('31', '30', label='117', fontsize='24', penwidth='3')

g.edge('30', '60', label='118', fontsize='24', penwidth='3')
g.edge('60', '30', label='119', fontsize='24', penwidth='3')
#################################################################

g.edge('31', '32', label='120', fontsize='24', penwidth='3')
g.edge('32', '31', label='121', fontsize='24', penwidth='3')

g.edge('31', '60', label='122', fontsize='24', penwidth='3')
g.edge('60', '31', label='123', fontsize='24', penwidth='3')
#################################################################

g.edge('32', '33', label='124', fontsize='24', penwidth='3')
g.edge('33', '32', label='125', fontsize='24', penwidth='3')

g.edge('32', '34', label='126', fontsize='24', penwidth='3')
g.edge('34', '32', label='127', fontsize='24', penwidth='3')

g.edge('32', '60', label='128', fontsize='24', penwidth='3')
g.edge('60', '32', label='129', fontsize='24', penwidth='3')
#################################################################

g.edge('33', '34', label='130', fontsize='24', penwidth='3')
g.edge('34', '33', label='131', fontsize='24', penwidth='3')
#################################################################

g.edge('34', '35', label='132', fontsize='24', penwidth='3')
g.edge('35', '34', label='133', fontsize='24', penwidth='3')

g.edge('34', '60', label='134', fontsize='24', penwidth='3')
g.edge('60', '34', label='135', fontsize='24', penwidth='3')
#################################################################

g.edge('35', '36', label='136', fontsize='24', penwidth='3')
g.edge('36', '35', label='137', fontsize='24', penwidth='3')

g.edge('35', '71', label='138', fontsize='24', penwidth='3')
g.edge('71', '35', label='139', fontsize='24', penwidth='3')
#################################################################

g.edge('36', '43', label='140', fontsize='24', penwidth='3')
g.edge('43', '36', label='141', fontsize='24', penwidth='3')

g.edge('36', '44', label='142', fontsize='24', penwidth='3')
g.edge('44', '36', label='143', fontsize='24', penwidth='3')

g.edge('36', '71', label='144', fontsize='24', penwidth='3')
g.edge('71', '36', label='145', fontsize='24', penwidth='3')
#################################################################

g.edge('37', '38', label='146', fontsize='24', penwidth='3')
g.edge('38', '37', label='147', fontsize='24', penwidth='3')

g.edge('37', '42', label='148', fontsize='24', penwidth='3')
g.edge('42', '37', label='149', fontsize='24', penwidth='3')
#################################################################

g.edge('38', '39', label='150', fontsize='24', penwidth='3')
g.edge('39', '38', label='151', fontsize='24', penwidth='3')

g.edge('38', '42', label='152', fontsize='24', penwidth='3')
g.edge('42', '38', label='153', fontsize='24', penwidth='3')
#################################################################

g.edge('39', '40', label='154', fontsize='24', penwidth='3')
g.edge('40', '39', label='155', fontsize='24', penwidth='3')

g.edge('39', '48', label='156', fontsize='24', penwidth='3')
g.edge('48', '39', label='157', fontsize='24', penwidth='3')
#################################################################

g.edge('40', '41', label='158', fontsize='24', penwidth='3')
g.edge('41', '40', label='159', fontsize='24', penwidth='3')

g.edge('40', '48', label='160', fontsize='24', penwidth='3')
g.edge('48', '40', label='161', fontsize='24', penwidth='3')
#################################################################

g.edge('41', '49', label='162', fontsize='24', penwidth='3')
g.edge('49', '41', label='163', fontsize='24', penwidth='3')
#################################################################

g.edge('42', '43', label='164', fontsize='24', penwidth='3')
g.edge('43', '42', label='165', fontsize='24', penwidth='3')

g.edge('42', '45', label='166', fontsize='24', penwidth='3')
g.edge('45', '42', label='167', fontsize='24', penwidth='3')
#################################################################

g.edge('43', '44', label='168', fontsize='24', penwidth='3')
g.edge('44', '43', label='169', fontsize='24', penwidth='3')

g.edge('43', '45', label='170', fontsize='24', penwidth='3')
g.edge('45', '43', label='171', fontsize='24', penwidth='3')
#################################################################

g.edge('44', '46', label='172', fontsize='24', penwidth='3')
g.edge('46', '44', label='173', fontsize='24', penwidth='3')

g.edge('44', '54', label='174', fontsize='24', penwidth='3')
g.edge('54', '44', label='175', fontsize='24', penwidth='3')
#################################################################

g.edge('45', '46', label='176', fontsize='24', penwidth='3')
g.edge('46', '45', label='177', fontsize='24', penwidth='3')

g.edge('45', '47', label='178', fontsize='24', penwidth='3')
g.edge('47', '45', label='179', fontsize='24', penwidth='3')
#################################################################

g.edge('46', '47', label='180', fontsize='24', penwidth='3')
g.edge('47', '46', label='181', fontsize='24', penwidth='3')

g.edge('46', '54', label='182', fontsize='24', penwidth='3')
g.edge('54', '46', label='183', fontsize='24', penwidth='3')
#################################################################

g.edge('47', '48', label='184', fontsize='24', penwidth='3')
g.edge('48', '47', label='185', fontsize='24', penwidth='3')

g.edge('47', '74', label='186', fontsize='24', penwidth='3')
g.edge('74', '47', label='187', fontsize='24', penwidth='3')
#################################################################

g.edge('48', '49', label='188', fontsize='24', penwidth='3')
g.edge('49', '48', label='189', fontsize='24', penwidth='3')

g.edge('48', '51', label='190', fontsize='24', penwidth='3')
g.edge('51', '48', label='191', fontsize='24', penwidth='3')

g.edge('48', '52', label='192', fontsize='24', penwidth='3')
g.edge('52', '48', label='193', fontsize='24', penwidth='3')

g.edge('48', '53', label='194', fontsize='24', penwidth='3')
g.edge('53', '48', label='195', fontsize='24', penwidth='3')

g.edge('48', '54', label='196', fontsize='24', penwidth='3')
g.edge('54', '48', label='197', fontsize='24', penwidth='3')

g.edge('48', '74', label='198', fontsize='24', penwidth='3')
g.edge('74', '48', label='199', fontsize='24', penwidth='3')
#################################################################

g.edge('49', '50', label='200', fontsize='24', penwidth='3')
g.edge('50', '49', label='201', fontsize='24', penwidth='3')

g.edge('49', '73', label='201', fontsize='24', penwidth='3')
g.edge('73', '49', label='203', fontsize='24', penwidth='3')
#################################################################

g.edge('50', '51', label='204', fontsize='24', penwidth='3')
g.edge('51', '50', label='205', fontsize='24', penwidth='3')

g.edge('50', '73', label='206', fontsize='24', penwidth='3')
g.edge('73', '50', label='207', fontsize='24', penwidth='3')
#################################################################

g.edge('51', '52', label='208', fontsize='24', penwidth='3')
g.edge('52', '51', label='209', fontsize='24', penwidth='3')
#################################################################

g.edge('52', '53', label='210', fontsize='24', penwidth='3')
g.edge('53', '52', label='211', fontsize='24', penwidth='3')
#################################################################

g.edge('53', '54', label='212', fontsize='24', penwidth='3')
g.edge('54', '53', label='213', fontsize='24', penwidth='3')
#################################################################

g.edge('55', '57', label='214', fontsize='24', penwidth='3')
g.edge('57', '55', label='215', fontsize='24', penwidth='3')
#################################################################

g.edge('56', '57', label='216', fontsize='24', penwidth='3')
g.edge('57', '56', label='217', fontsize='24', penwidth='3')
#################################################################

g.edge('57', '58', label='218', fontsize='24', penwidth='3')
g.edge('58', '57', label='219', fontsize='24', penwidth='3')

g.edge('57', '59', label='220', fontsize='24', penwidth='3')
g.edge('59', '57', label='221', fontsize='24', penwidth='3')
#################################################################

g.edge('58', '59', label='222', fontsize='24', penwidth='3')
g.edge('59', '58', label='223', fontsize='24', penwidth='3')
#################################################################

g.edge('59', '60', label='224', fontsize='24', penwidth='3')
g.edge('60', '59', label='225', fontsize='24', penwidth='3')

g.edge('59', '72', label='226', fontsize='24', penwidth='3')
g.edge('72', '59', label='227', fontsize='24', penwidth='3')
#################################################################

g.edge('60', '61', label='228', fontsize='24', penwidth='3')
g.edge('61', '60', label='229', fontsize='24', penwidth='3')

g.edge('60', '63', label='230', fontsize='24', penwidth='3')
g.edge('63', '60', label='231', fontsize='24', penwidth='3')

g.edge('60', '65', label='232', fontsize='24', penwidth='3')
g.edge('65', '60', label='233', fontsize='24', penwidth='3')

g.edge('60', '67', label='234', fontsize='24', penwidth='3')
g.edge('67', '60', label='235', fontsize='24', penwidth='3')

g.edge('60', '69', label='236', fontsize='24', penwidth='3')
g.edge('69', '60', label='237', fontsize='24', penwidth='3')

g.edge('60', '71', label='238', fontsize='24', penwidth='3')
g.edge('71', '60', label='239', fontsize='24', penwidth='3')

g.edge('60', '72', label='240', fontsize='24', penwidth='3')
g.edge('72', '60', label='241', fontsize='24', penwidth='3')
#################################################################

g.edge('62', '63', label='242', fontsize='24', penwidth='3')
g.edge('63', '62', label='243', fontsize='24', penwidth='3')
#################################################################

g.edge('63', '65', label='244', fontsize='24', penwidth='3')
g.edge('65', '63', label='245', fontsize='24', penwidth='3')
#################################################################

g.edge('64', '65', label='246', fontsize='24', penwidth='3')
g.edge('65', '64', label='247', fontsize='24', penwidth='3')
#################################################################

g.edge('65', '66', label='248', fontsize='24', penwidth='3')
g.edge('66', '65', label='249', fontsize='24', penwidth='3')
#################################################################

g.edge('67', '68', label='250', fontsize='24', penwidth='3')
g.edge('68', '67', label='251', fontsize='24', penwidth='3')

g.edge('67', '69', label='252', fontsize='24', penwidth='3')
g.edge('69', '67', label='253', fontsize='24', penwidth='3')
#################################################################

g.edge('69', '70', label='254', fontsize='24', penwidth='3')
g.edge('70', '69', label='255', fontsize='24', penwidth='3')

g.edge('69', '71', label='256', fontsize='24', penwidth='3')
g.edge('71', '69', label='257', fontsize='24', penwidth='3')
#################################################################

g.view();
