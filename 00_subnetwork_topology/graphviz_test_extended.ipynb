# %%
from graphviz import Digraph

# %%
# cluster.py - http://www.graphviz.org/content/cluster

g = Digraph('G', filename='MA_highway_network_extended_topology')

g.node('9', fontsize='22')
g.node('3', fontsize='22')
g.node('4', fontsize='22')
g.node('7', fontsize='22')
g.node('20', fontsize='22')
g.node('8', fontsize='22')
g.node('1', fontsize='22')
g.node('14', fontsize='22')
g.node('12', fontsize='22')
g.node('6', fontsize='22')
g.node('16', fontsize='22')
g.node('15', fontsize='22')
g.node('17', fontsize='22')
g.node('10', fontsize='22')
g.node('13', fontsize='22')
g.node('11', fontsize='22')
g.node('5', fontsize='22')
g.node('2', fontsize='22')
g.node('18', fontsize='22')
g.node('19', fontsize='22')
g.node('21', fontsize='22')
g.node('22', fontsize='22')

g.edge('1', '2', label='0', fontsize='22')
g.edge('2', '1', label='1', fontsize='22')

g.edge('1', '3', label='2', fontsize='22')
g.edge('3', '1', label='3', fontsize='22')

g.edge('2', '3', label='4', fontsize='22')
g.edge('3', '2', label='5', fontsize='22')

g.edge('2', '4', label='6', fontsize='22')
g.edge('4', '2', label='7', fontsize='22')

g.edge('3', '6', label='8', fontsize='22')
g.edge('6', '3', label='9', fontsize='22')

g.edge('4', '6', label='10', fontsize='22')
g.edge('6', '4', label='11', fontsize='22')

g.edge('4', '7', label='12', fontsize='22')
g.edge('7', '4', label='13', fontsize='22')

g.edge('4', '18', label='14-1', fontsize='22')
g.edge('18', '4', label='15-1', fontsize='22')

g.edge('7', '18', label='15-2', fontsize='22')
g.edge('18', '7', label='14-2', fontsize='22')

g.edge('4', '5', label='16', fontsize='22')
g.edge('5', '4', label='17', fontsize='22')

g.edge('6', '7', label='18', fontsize='22')
g.edge('7', '6', label='19', fontsize='22')

g.edge('5', '8', label='20', fontsize='22')
g.edge('8', '5', label='21', fontsize='22')

g.edge('5', '9', label='22', fontsize='22')
g.edge('9', '5', label='23', fontsize='22')

g.edge('7', '9', label='24', fontsize='22')
g.edge('9', '7', label='25', fontsize='22')

g.edge('7', '11', label='26', fontsize='22')
g.edge('11', '7', label='27', fontsize='22')

g.edge('9', '10', label='28', fontsize='22')
g.edge('10', '9', label='29', fontsize='22')

g.edge('8', '10', label='30', fontsize='22')
g.edge('10', '8', label='31', fontsize='22')

g.edge('10', '11', label='32', fontsize='22')
g.edge('11', '10', label='33', fontsize='22')

g.edge('8', '12', label='34', fontsize='22')
g.edge('12', '8', label='35', fontsize='22')

g.edge('10', '13', label='36', fontsize='22')
g.edge('13', '10', label='37', fontsize='22')

g.edge('11', '14', label='38', fontsize='22')
g.edge('14', '11', label='39', fontsize='22')

g.edge('12', '13', label='40', fontsize='22')
g.edge('13', '12', label='41', fontsize='22')

g.edge('12', '19', label='42-1', fontsize='22')
g.edge('19', '12', label='43-1', fontsize='22')

g.edge('13', '19', label='43-2', fontsize='22')
g.edge('19', '13', label='42-2', fontsize='22')

g.edge('12', '20', label='44-1', fontsize='22')
g.edge('20', '12', label='45-1', fontsize='22')

g.edge('13', '20', label='45-2', fontsize='22')
g.edge('20', '13', label='44-2', fontsize='22')

g.edge('13', '14', label='46', fontsize='22')
g.edge('14', '13', label='47', fontsize='22')

g.edge('13', '21', label='48-1', fontsize='22')
g.edge('21', '13', label='49-1', fontsize='22')

g.edge('14', '21', label='49-2', fontsize='22')
g.edge('21', '14', label='48-2', fontsize='22')

g.edge('12', '15', label='50', fontsize='22')
g.edge('15', '12', label='51', fontsize='22')

g.edge('13', '15', label='52', fontsize='22')
g.edge('15', '13', label='53', fontsize='22')

g.edge('13', '16', label='54', fontsize='22')
g.edge('16', '13', label='55', fontsize='22')

g.edge('14', '16', label='56', fontsize='22')
g.edge('16', '14', label='57', fontsize='22')

g.edge('14', '22', label='58-1', fontsize='22')
g.edge('22', '14', label='59-1', fontsize='22')

g.edge('16', '22', label='59-2', fontsize='22')
g.edge('22', '16', label='58-2', fontsize='22')

g.edge('15', '17', label='60', fontsize='22')
g.edge('17', '15', label='61', fontsize='22')

g.edge('16', '17', label='62', fontsize='22')
g.edge('17', '16', label='63', fontsize='22')

g.view();

# %%
# cluster.py - http://www.graphviz.org/content/cluster

g = Digraph('G', filename='MA_highway_network_extended_topology')

g.node('12', fontsize='22')
g.node('14', fontsize='22')
g.node('13', fontsize='22')
g.node('9', fontsize='22')
g.node('1', fontsize='22')
g.node('6', fontsize='22')
g.node('7', fontsize='22')
g.node('3', fontsize='22')
g.node('4', fontsize='22')
g.node('20', fontsize='22')
g.node('8', fontsize='22')
g.node('16', fontsize='22')
g.node('15', fontsize='22')
g.node('17', fontsize='22')
g.node('10', fontsize='22')
g.node('11', fontsize='22')
g.node('5', fontsize='22')
g.node('2', fontsize='22')
g.node('18', fontsize='22')
g.node('19', fontsize='22')
g.node('21', fontsize='22')
g.node('22', fontsize='22')

g.edge('1', '2', label='0', fontsize='22')
g.edge('2', '1', label='1', fontsize='22')

g.edge('1', '3', label='2', fontsize='22')
g.edge('3', '1', label='3', fontsize='22')

g.edge('2', '3', label='4', fontsize='22')
g.edge('3', '2', label='5', fontsize='22')

g.edge('2', '4', label='6', fontsize='22')
g.edge('4', '2', label='7', fontsize='22')

g.edge('3', '6', label='8', fontsize='22')
g.edge('6', '3', label='9', fontsize='22')

g.edge('4', '6', label='10', fontsize='22')
g.edge('6', '4', label='11', fontsize='22')

g.edge('4', '7', label='12', fontsize='22')
g.edge('7', '4', label='13', fontsize='22')

g.edge('4', '18', label='14', fontsize='22')
g.edge('18', '4', label='16', fontsize='22')

g.edge('7', '18', label='17', fontsize='22')
g.edge('18', '7', label='15', fontsize='22')

g.edge('4', '5', label='18', fontsize='22')
g.edge('5', '4', label='19', fontsize='22')

g.edge('6', '7', label='20', fontsize='22')
g.edge('7', '6', label='21', fontsize='22')

g.edge('5', '8', label='22', fontsize='22')
g.edge('8', '5', label='23', fontsize='22')

g.edge('5', '9', label='24', fontsize='22')
g.edge('9', '5', label='25', fontsize='22')

g.edge('7', '9', label='26', fontsize='22')
g.edge('9', '7', label='27', fontsize='22')

g.edge('7', '11', label='28', fontsize='22')
g.edge('11', '7', label='29', fontsize='22')

g.edge('9', '10', label='30', fontsize='22')
g.edge('10', '9', label='31', fontsize='22')

g.edge('8', '10', label='32', fontsize='22')
g.edge('10', '8', label='33', fontsize='22')

g.edge('10', '11', label='34', fontsize='22')
g.edge('11', '10', label='35', fontsize='22')

g.edge('8', '12', label='36', fontsize='22')
g.edge('12', '8', label='37', fontsize='22')

g.edge('10', '13', label='38', fontsize='22')
g.edge('13', '10', label='39', fontsize='22')

g.edge('11', '14', label='40', fontsize='22')
g.edge('14', '11', label='41', fontsize='22')

g.edge('12', '13', label='42', fontsize='22')
g.edge('13', '12', label='43', fontsize='22')

g.edge('12', '19', label='44', fontsize='22')
g.edge('19', '12', label='46', fontsize='22')

g.edge('13', '19', label='47', fontsize='22')
g.edge('19', '13', label='45', fontsize='22')

g.edge('12', '20', label='48', fontsize='22')
g.edge('20', '12', label='50', fontsize='22')

g.edge('13', '20', label='51', fontsize='22')
g.edge('20', '13', label='49', fontsize='22')

g.edge('13', '14', label='52', fontsize='22')
g.edge('14', '13', label='53', fontsize='22')

g.edge('13', '21', label='54', fontsize='22')
g.edge('21', '13', label='56', fontsize='22')

g.edge('14', '21', label='57', fontsize='22')
g.edge('21', '14', label='55', fontsize='22')

g.edge('12', '15', label='58', fontsize='22')
g.edge('15', '12', label='59', fontsize='22')

g.edge('13', '15', label='60', fontsize='22')
g.edge('15', '13', label='61', fontsize='22')

g.edge('13', '16', label='62', fontsize='22')
g.edge('16', '13', label='63', fontsize='22')

g.edge('14', '16', label='64', fontsize='22')
g.edge('16', '14', label='65', fontsize='22')

g.edge('14', '22', label='66', fontsize='22')
g.edge('22', '14', label='68', fontsize='22')

g.edge('16', '22', label='69', fontsize='22')
g.edge('22', '16', label='67', fontsize='22')

g.edge('15', '17', label='70', fontsize='22')
g.edge('17', '15', label='71', fontsize='22')

g.edge('16', '17', label='72', fontsize='22')
g.edge('17', '16', label='73', fontsize='22')

g.view();

# %%
# !dot -Teps MA_highway_network_topology_1 -o MA_highway_network_topology_1_.eps

# %%
# !dot -Tgv detection_procedure > detection_procedure.gv

# %%
# !dot -Tgv The_Round_Table > The_Round_Table.gv
